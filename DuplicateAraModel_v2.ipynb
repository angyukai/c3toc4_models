# %%
import scobra
import pandas as pd
import suppFunctions as sf
from cobra import Metabolite
m1m2 = scobra.Model('AraLightDarkCore_DbMesophyll_v3.xls')
m = scobra.Model('AraLightDarkCore_ScrumPy.xls')

# %%
import suppFunctions as sf

# %% [markdown]
# ## M constraints

# %%
#constraint list

constraints_list = {'Photon_Light_tx':(0,None),
                   'Photon_Dark_tx':(0,0),
                   'GLC_Dark_tx':(0,0),
                   'GLC_Light_tx':(0,0),
                   'Sucrose_Dark_tx':(0,0),
                   'Sucrose_Light_tx':(0,0),
                   'TAG_Dark_tx':(0,0),
                   'TAG_Light_tx':(0,0),
                   'Starch_Dark_tx':(0,0),
                   'Starch_Light_tx':(0,0),
                   'NADPH_Dehydrogenase_Dark_p':(0,0),
                   'NADPH_Dehydrogenase_Light_p':(0,0),
                   'NADPHoxx_Light_tx':(0,0),
                    'NADPHoxx_Dark_tx':(0,0),
                    'Plastoquinol_Oxidase_Dark_p':(0,0),
                    'Plastoquinol_Oxidase_Light_p':(0,0),
                    'NH4_Light_tx':(0,0),
                    'NH4_Dark_tx':(0,0)
                   }

m.SetConstraints(constraints_list)


lightdic = {'Alanine_Light_biomass':-9.7,'Arginine_Light_biomass':-1.6,'Asparagine_Light_biomass':-10.1,'Aspartate_Light_biomass':-9.5,
'Glutamate_Light_biomass':-11.4,'Glutamine_Light_biomass':-33.2,'Glycine_Light_biomass':-0.7,'Serine_Light_biomass':-7.7,
'Tyrosine_Light_biomass':-0.6,'Histidine_Light_biomass':-0.4,'Isoleucine_Light_biomass':-1.2,'Leucine_Light_biomass':-1.2,
'Lysine_Light_biomass':-1.8,'Methionine_Light_biomass':-0.7,'Phenylalanine_Light_biomass':-1.1,'Threonine_Light_biomass':-5.6,
'Tryptophan_Light_biomass':-0.9,'Valine_Light_biomass':-2.4}

darkdic = {'Alanine_Dark_biomass':-9.7,'Arginine_Dark_biomass':-1.6,'Asparagine_Dark_biomass':-10.1,'Aspartate_Dark_biomass':-9.5,
'Glutamate_Dark_biomass':-11.4,'Glutamine_Dark_biomass':-33.2,'Glycine_Dark_biomass':-0.7,'Serine_Dark_biomass':-7.7,
'Tyrosine_Dark_biomass':-0.6,'Histidine_Dark_biomass':-0.4,'Isoleucine_Dark_biomass':-1.2,'Leucine_Dark_biomass':-1.2,
'Lysine_Dark_biomass':-1.8,'Methionine_Dark_biomass':-0.7,'Phenylalanine_Dark_biomass':-1.1,'Threonine_Dark_biomass':-5.6,
'Tryptophan_Dark_biomass':-0.9,'Valine_Dark_biomass':-2.4}

exclude_list = []

for i in lightdic.keys():
    exclude_list.append(i)

for i in darkdic.keys():
    exclude_list.append(i)

exclude_list.append('Sucrose_Light_biomass')
exclude_list.append('Sucrose_Dark_biomass')

list_b = m.Reactions('_biomass')

for i in list_b:
    check = sf.notInList(i, exclude_list)
    if check:
        m.SetConstraint(i,0,0)

m.SetReacsFixedRatio({"RXN-961_Dark_p":1, "RIBULOSE-BISPHOSPHATE-CARBOXYLASE-RXN_Dark_p":3})
m.SetReacsFixedRatio({"RXN-961_Light_p":1, "RIBULOSE-BISPHOSPHATE-CARBOXYLASE-RXN_Light_p":3})
m.SetReacsFixedRatio({"NO3_Light_tx":3, 'NO3_Dark_tx':2})

sucrose_light = 0.515625
sucrose_dark = sucrose_light/3
aaSucrose_ratio = 2.2


#takes into consideration day/night, aa/sucrose, aa percentage ratios.

for reac in lightdic:
    aa_ratio = lightdic[reac]
    m.SetConstraints({reac:((sucrose_light/aaSucrose_ratio)*aa_ratio/100,
                            (sucrose_light/aaSucrose_ratio)*aa_ratio/100)})

for reac in darkdic:
    aa_ratio = darkdic[reac]
    m.SetConstraints({reac:((sucrose_dark/aaSucrose_ratio)*aa_ratio/100,
                            (sucrose_dark/aaSucrose_ratio)*aa_ratio/100)})

# Setting ratios for NADPH and ATPase "The ratio of ATP maintenance cost:NADPH maintenance cost was as- sumed to be 3:1 "
#  'NADPHoxx' should be 0

#Set ATP and NADPH rxn to be None to 0. 
ATP_constraints = ['NADPHoxc', 'NADPHoxm', 'NADPHoxp']

for reac in ATP_constraints:
    nadph_d = reac+'_Light_tx'
    nadph_n = reac+'_Dark_tx'
    
    m.SetReacsFixedRatio({nadph_d:1,'ATPase_Light_tx':9})
    m.SetReacsFixedRatio({nadph_n:1,'ATPase_Dark_tx':9})

# m1m2.SetReacsFixedRatio({"Sucrose_Light_biomass":3, 'Sucrose_Dark_biomass':1})
m.SetConstraints({'Sucrose_Light_biomass':(-sucrose_light,-sucrose_light)})
m.SetConstraints({'Sucrose_Dark_biomass':(-sucrose_dark,-sucrose_dark)})
m.SetConstraints({'ATPase_Light_tx':(-7.5,-7.5)})
m.SetConstraints({'ATPase_Dark_tx':(-7.5,-7.5)})



#ATP maintenance should go in the direction that consumes ATP

#e.g. minimizing photon 
# m.SetObjDirec('Min')
# m.SetConstraints({'Photon_Light_tx':(170,170)})
m.MinFluxSolve()
# Out:
# optimal

# %% [markdown]
# ## M1M2 constraints

# %%
constraints = ['Photon_Dark_tx',
                   'GLC_Dark_tx',
                   'GLC_Light_tx',
                   'Sucrose_Dark_tx',
                   'Sucrose_Light_tx',
                   'TAG_Dark_tx',
                   'TAG_Light_tx',
                   'Starch_Dark_tx',
                   'Starch_Light_tx',
                   'NADPH_Dehydrogenase_Dark_p',
                   'NADPH_Dehydrogenase_Light_p',
                   'NADPHoxx_Light_tx',
                    'NADPHoxx_Dark_tx',
                    'Plastoquinol_Oxidase_Dark_p',
                    'Plastoquinol_Oxidase_Light_p',
                    'NH4_Light_tx',
                    'NH4_Dark_tx']

for tx in constraints:
    reac = tx+'_M1'
    m1m2.SetConstraint(reac,0,0)

for tx in constraints:
    reac = tx+'_M2'
    m1m2.SetConstraint(reac,0,0)

# %%
#Setting biomasses to 0

lightdic = {'Alanine_Light_biomass':-9.7,'Arginine_Light_biomass':-1.6,'Asparagine_Light_biomass':-10.1,'Aspartate_Light_biomass':-9.5,
'Glutamate_Light_biomass':-11.4,'Glutamine_Light_biomass':-33.2,'Glycine_Light_biomass':-0.7,'Serine_Light_biomass':-7.7,
'Tyrosine_Light_biomass':-0.6,'Histidine_Light_biomass':-0.4,'Isoleucine_Light_biomass':-1.2,'Leucine_Light_biomass':-1.2,
'Lysine_Light_biomass':-1.8,'Methionine_Light_biomass':-0.7,'Phenylalanine_Light_biomass':-1.1,'Threonine_Light_biomass':-5.6,
'Tryptophan_Light_biomass':-0.9,'Valine_Light_biomass':-2.4}

darkdic = {'Alanine_Dark_biomass':-9.7,'Arginine_Dark_biomass':-1.6,'Asparagine_Dark_biomass':-10.1,'Aspartate_Dark_biomass':-9.5,
'Glutamate_Dark_biomass':-11.4,'Glutamine_Dark_biomass':-33.2,'Glycine_Dark_biomass':-0.7,'Serine_Dark_biomass':-7.7,
'Tyrosine_Dark_biomass':-0.6,'Histidine_Dark_biomass':-0.4,'Isoleucine_Dark_biomass':-1.2,'Leucine_Dark_biomass':-1.2,
'Lysine_Dark_biomass':-1.8,'Methionine_Dark_biomass':-0.7,'Phenylalanine_Dark_biomass':-1.1,'Threonine_Dark_biomass':-5.6,
'Tryptophan_Dark_biomass':-0.9,'Valine_Dark_biomass':-2.4}



exclude_list = []

for aa in lightdic.keys():
    M1 = aa+'_M1'
    exclude_list.append(M1)
    M2 = aa+'_M2'
    exclude_list.append(M2)

for aa in darkdic.keys():
    M1 = aa+'_M1'
    exclude_list.append(M1)
    M2 = aa+'_M2'
    exclude_list.append(M2)

exclude_list.append('Sucrose_Light_biomass_M1')
exclude_list.append('Sucrose_Light_biomass_M2')
exclude_list.append('Sucrose_Dark_biomass_M1')
exclude_list.append('Sucrose_Dark_biomass_M2')

list_b = m1m2.Reactions('_biomass')

for i in list_b:
    check = sf.notInList(i, exclude_list)
    if check:
        m1m2.SetConstraint(i,0,0)

# %%
m1m2.SetReacsFixedRatio({"RXN-961_Dark_p_M1":1, "RIBULOSE-BISPHOSPHATE-CARBOXYLASE-RXN_Dark_p_M1":3})
m1m2.SetReacsFixedRatio({"RXN-961_Dark_p_M2":1, "RIBULOSE-BISPHOSPHATE-CARBOXYLASE-RXN_Dark_p_M2":3})
m1m2.SetReacsFixedRatio({"RXN-961_Light_p_M1":1, "RIBULOSE-BISPHOSPHATE-CARBOXYLASE-RXN_Light_p_M1":3})
m1m2.SetReacsFixedRatio({"RXN-961_Light_p_M2":1, "RIBULOSE-BISPHOSPHATE-CARBOXYLASE-RXN_Light_p_M2":3})
m1m2.SetReacsFixedRatio({"NO3_Light_tx_M1":3, 'NO3_Dark_tx_M1':2})
m1m2.SetReacsFixedRatio({"NO3_Light_tx_M2":3, 'NO3_Dark_tx_M2':2})

#Set ATP and NADPH rxn to be None to 0. 
ATP_constraints = ['NADPHoxc', 'NADPHoxm', 'NADPHoxp']

for reac in ATP_constraints:
    nadph_d = reac+'_Light_tx_M1'
    nadph_n = reac+'_Dark_tx_M1'
    
    m1m2.SetReacsFixedRatio({nadph_d:1,'ATPase_Light_tx_M1':9})
    m1m2.SetReacsFixedRatio({nadph_n:1,'ATPase_Dark_tx_M1':9})
    
for reac in ATP_constraints:
    nadph_d = reac+'_Light_tx_M2'
    nadph_n = reac+'_Dark_tx_M2'
    
    m1m2.SetReacsFixedRatio({nadph_d:1,'ATPase_Light_tx_M2':9})
    m1m2.SetReacsFixedRatio({nadph_n:1,'ATPase_Dark_tx_M2':9})

# %% [markdown]
# ## Problematic constraints (amino acids and sucrose)

# %%
# '''Set fixed ratio constraits for amino acids and sucrose'''
# for reac in lightdic.keys():
#     M1reac = reac+'_M1'
#     M2reac = reac+'_M2'
#     m1m2.SetReacsFixedRatio({M1reac:1,'Sucrose_Light_biomass_M1':2.2})
#     m1m2.SetReacsFixedRatio({M2reac:1,'Sucrose_Light_biomass_M2':2.2})

# for reac in darkdic.keys():
#     M1reac = reac+'_M1'
#     M2reac = reac+'_M2'
#     m1m2.SetReacsFixedRatio({M1reac:1,'Sucrose_Dark_biomass_M1':2.2})
#     m1m2.SetReacsFixedRatio({M2reac:1,'Sucrose_Dark_biomass_M2':2.2})

# %%
sucrose_light_M1 = 0.515625
sucrose_dark_M1 = sucrose_light_M1/3
sucrose_light_M2 = 0.515625
sucrose_dark_M2 = sucrose_light_M2/3
aaSucrose_ratio = 2.2

# m1m2.DelReaction('Sucrose_Light_biomass_M1')
# m1m2.DelReaction('Sucrose_Dark_biomass_M1')
m1m2.SetConstraints({'Sucrose_Light_biomass_M1':(-sucrose_light_M1,-sucrose_light_M1)})
m1m2.SetConstraints({'Sucrose_Dark_biomass_M1':(-sucrose_dark_M1,-sucrose_dark_M1)})
m1m2.SetConstraints({'Sucrose_Light_biomass_M2':(-sucrose_light_M2,-sucrose_light_M2)})
m1m2.SetConstraints({'Sucrose_Dark_biomass_M2':(-sucrose_dark_M2,-sucrose_dark_M2)})

# #takes into consideration day/night, aa/sucrose, aa percentage ratios.

#setting aa ratio for M1
for reac in lightdic:
    aa_ratio = lightdic[reac]
    m1m2.SetConstraints({reac+'_M1':((sucrose_light_M1/aaSucrose_ratio)*aa_ratio/100,
                            (sucrose_light_M1/aaSucrose_ratio)*aa_ratio/100)})
for reac in darkdic:
    aa_ratio = darkdic[reac]
    m1m2.SetConstraints({reac+'_M1':((sucrose_light_M1/aaSucrose_ratio)*aa_ratio/100,
                            (sucrose_light_M1/aaSucrose_ratio)*aa_ratio/100)})
#setting aa ratio for M2
for reac in lightdic:
    aa_ratio = lightdic[reac]
    m1m2.SetConstraints({reac+'_M2':((sucrose_light_M2/aaSucrose_ratio)*aa_ratio/100,
                            (sucrose_light_M2/aaSucrose_ratio)*aa_ratio/100)})
for reac in darkdic:
    aa_ratio = darkdic[reac]
    m1m2.SetConstraints({reac+'_M2':((sucrose_dark_M2/aaSucrose_ratio)*aa_ratio/100,
                            (sucrose_dark_M2/aaSucrose_ratio)*aa_ratio/100)})
    

# m1m2.SetConstraints({'Photon_Light_tx_M1':(300,300)})
# m1m2.SetConstraints({'Photon_Light_tx_M2':(300,300)})
m1m2.SetReacsFixedRatio({'Photon_Light_tx_M1':1,'Photon_Light_tx_M2':1})

m1m2.SetConstraints({'ATPase_Light_tx_M1':(-7.5,-7.5)})
m1m2.SetConstraints({'ATPase_Dark_tx_M1':(-7.5,-7.5)})
m1m2.SetConstraints({'ATPase_Light_tx_M2':(-7.5,-7.5)})
m1m2.SetConstraints({'ATPase_Dark_tx_M2':(-7.5,-7.5)})

# %% [markdown]
# ## Cutting link for M1M2

# %%
m1m2.SetConstraints({'Sucrose_Light_M1M2':(0,0)})
m1m2.SetConstraints({'Sucrose_Dark_M1M2':(0,0)})

AA_met = ['GLY','GLN','MET','LEU','HIS','VAL','ILE',
         'L-ALPHA-ALANINE','L-ASPARTATE','SER','TYR','LYS','PHE',
         'ARG','TRP','GLT','ASN','THR']


for aa in AA_met:
    m1m2.SetConstraints({aa+'_Light_M1M2':(0,0)})

for aa in AA_met:
    m1m2.SetConstraints({aa+'_Dark_M1M2':(0,0)})

# %% [markdown]
# ## Meddling with reactions

# %%
# m1m2.SetObjDirec('Max')
# m1m2.SetObjective('Sucrose_Light_biomass_M1')
# # m1m2.SetObjective('Sucrose_Dark_biomass_M1')
# m1m2.SetObjective('Sucrose_Light_biomass_M2')
# m1m2.SetObjective('Sucrose_Dark_biomass_M2')
# m1m2.SetConstraints({'Photon_Light_tx_M1':(170,170)})
# m1m2.SetObjective('Photon_Light_tx_M1')
# m1m2.SetObjective('Sucrose_Light_M1M2')
# m1m2.SetObjective('Sucrose_Dark_M1M2')

m1m2.MinFluxSolve()
# Out:
# optimal

# %%
sol_M1M2 = m1m2.GetSol(IncZeroes=True)
sol_M = m.GetSol(IncZeroes=True)

sf.visualizeDataCategories(sol_M1M2,sol_M,writeData=False)
# Out:
# GLYCOLYSIS
#                                  M         M1         M2
# Hexokinase_Lt_c           0.000000   0.000000   0.000000
# Hexokinase_Dk_c           0.000000   0.000000   0.000000
# Hexokinase_Lt_p           0.000000   0.000000   0.000000
# Hexokinase_Dk_p           0.000000   0.000000   0.000000
# Hexose_P_Isomerase_Lt_c   0.000000   0.000000   0.000000
# Hexose_P_Isomerase_Dk_c   0.000000   0.000000   0.000000
# Hexose_P_Isomerase_Lt_p  -1.197543  -1.237770  -1.194131
# Hexose_P_Isomerase_Dk_p  -1.197543  -1.237770  -1.194131
# PFK_Lt_c                  0.000000   0.000000   0.000000
# PFK_Dk_c                  0.000000   0.000000   0.000000
# PFK_Lt_p                  0.000000   0.000000   0.000000
# PFK_Dk_p                  0.020568   0.070987   0.017307
# F16_Aldolase             -0.687500  -0.687500  -0.687500
# F16_Aldolase_Dk_c         0.171875   0.171875   0.171875
# F16_Aldolase_Lt_p        -7.810181  -8.226164  -7.807975
# F16_Aldolase_Dk_p         0.020568   0.070987   0.017307
# Triose_P_Isomerase_Lt_c   0.687500   0.687500   0.687500
# Triose_P_Isomerase_Dk_c  -0.192443  -0.242862  -0.189182
# Triose_P_Isomerase_Lt_p  14.414694  15.202370  14.413694
# Triose_P_Isomerase_Dk_c   0.000000   0.000000   0.000000
# GAPDH_Lt_c                0.000000   0.000000   0.000000
# GAPDH_Dk_c                0.692202   0.757638   0.687159
# GAPDH_Lt_p               -0.001562   0.000000   0.000000
# GAPDH_Dk_p                0.010284   0.035493   0.008653
# PG_Kinase_Lt_c            0.000000   0.000000   0.000000
# PG_Kinase_Dk_c           -0.692202  -0.757638  -0.687159
# PG_Kinase_Lt_p           38.370100  40.316676  38.369304
# PG_Kinase_Dk_p           -0.010284  -0.035493  -0.008653
# PG_Mutase_Lt_c            0.237500   0.417891   0.237500
# PG_Mutase_Dk_c            0.692202   0.757638   0.687159
# PG_Mutase_Lt_p            0.034297   0.024375   0.016250
# PG_Mutase_Dk_p            0.010284   0.035493   0.008653
# Enolase_Lt_c              0.237500   0.417891   0.237500
# Enolase_Dk_c              0.692202   0.757638   0.687159
# Enolase_Lt_p              0.034297   0.024375   0.016250
# Enolase_Dk_p              0.010284   0.035493   0.008653
# Pyruvate_Kinase_Lt_c      0.000000   0.063047   0.000000
# Pyruvate_Kinase_Dk_c      0.692202   0.757638   0.687159
# Pyruvate_Kinase_Lt_p      0.018047   0.000000   0.000000
# Pyruvate_Kinase_Dk_p      0.010284   0.035493   0.008653
#
#
# TCA
#                                M        M1        M2
# PyruvateDH_Lt_m         0.000000  0.000000  0.000000
# PyruvateDH_Dk_m         0.703932  0.767585  0.704836
# PyruvateDH_Lt_p         0.000000  0.000000  0.000000
# PyruvateDH_Dk_p         0.000937  0.002812  0.000937
# Citrate_Synthase_Lt_m   0.000000  0.000000  0.000000
# Citrate_Synthase_Dk_m   0.703932  0.767585  0.704836
# Citrate_Synthase_Lt_x   0.000000  0.000000  0.000000
# Citrate_Synthase_Dk_x   0.000000  0.000000  0.000000
# Aconitase_Light_Lt_m    0.109531  0.000000  0.000000
# Aconitase_Dk_m          0.594400  0.655553  0.595305
# Aconitase_Light_Lt_c    0.000000  0.112031  0.109531
# Aconitase_Dk_c          0.000000  0.000000  0.000000
# IsocitrateDH_Lt_m       0.000000  0.000000  0.000000
# IsocitrateDH_Dk_m       0.000000  0.000000  0.000000
# 2-oxoglutarateDH_Lt_m   0.000000  0.000000  0.000000
# 2-oxoglutarateDH_Dk_m   0.559557  0.551022  0.560461
# SuccinateTK_Lt_m        0.000000  0.000000  0.000000
# SuccinateTK_Dk_m        0.559557  0.551022  0.560461
# Fumarase_Lt_m           0.000000  0.000000  0.000000
# Fumarase_Dk_m           0.559557  0.551022  0.560461
# Fumarase_Lt_c           0.006250  0.009375  0.006250
# Fumarase_Dk_c           0.000000  0.000000  0.000000
# Malate_DH_Lt_m          2.119887  1.914144  0.000000
# Malate_DH_Dk_m          1.365871  1.379310  1.367680
# Malate_DH_Lt_p          0.000000  0.000000  0.000000
# Malate_DH_Dk_p         -0.012159 -0.041118 -0.010528
# Malate_DH_Lt_c          0.472500  0.710156  0.472500
# Malate_DH_Dk_c         -0.692202 -0.757638 -0.687159
# Malate_DH_Lt_x          2.405208  2.570433  2.380035
# Malate_DH_Dk_x          0.000000  0.000000  0.000000
#
#
# PPP
#                                   M         M1         M2
# Hexose_P_Isomerase_Lt_p   -1.197543  -1.237770  -1.194131
# Hexose_P_Isomerase_Dk_p   -0.614632  -0.543829  -0.617592
# Hexose_P_Isomerase_Lt_c    0.000000   0.000000   0.000000
# Hexose_P_Isomerase_Dk_c    0.171875   0.171875   0.171875
# Transadolase_Lt_p          0.000000   0.000000   0.000000
# Transadolase_Dk_p          0.317600   0.307408   0.317449
# 1_Transketolase_Lt_p       6.604513   6.976206   6.605719
# 1_Transketolase_Dk_p      -0.317600  -0.307408  -0.317449
# 2_Transketolase_Lt_p      -6.612638  -6.988394  -6.613844
# 2_Transketolase_Dk_p       0.317600   0.307408   0.317449
# Epimerase_Lt_p           -13.217151 -13.964600 -13.219563
# Epimerase_Dk_p             0.099067   0.109259   0.099217
# Epimerase_Lt_c             0.000000   0.000000   0.000000
# Epimerase_Dk_c             0.536133   0.505557   0.535681
# R5P_Isomerase_Lt_p         6.600451   6.970113   6.601656
# R5P_Isomerase_Dk_p        -0.317600  -0.307408  -0.317449
# R5P_Isomerase_Lt_c         0.000000   0.000000   0.000000
# R5P_Isomerase_Dk_c         0.000000   0.000000   0.000000
# G6PDH1_Lt_p                0.000000   0.000000   0.000000
# G6PDH1_Dk_p                0.416667   0.416667   0.416667
# G6PDH1_Lt_c                0.000000   0.000000   0.000000
# G6PDH1_Dk_c                0.536133   0.505557   0.535681
# G6PDH2_Lt_p                0.000000   0.000000   0.000000
# G6PDH2_Dk_p                0.416667   0.416667   0.416667
# G6PDH2_Lt_c                0.000000   0.000000   0.000000
# G6PDH2_Dk_c                0.536133   0.505557   0.535681
# GLCNATE6P-DH_Lt_c          0.000000   0.000000   0.000000
# GLCNATE6P-DH_Dk_c          0.536133   0.505557   0.535681
# GLCNATE6P-DH_p_Lt_p        0.000000   0.000000   0.000000
# GLCNATE6P-DH_Dk_p          0.416667   0.416667   0.416667
#
#
# ETC
#                          M        M1        M2
# Complex_I_Lt_m    4.583142  4.515280  2.463707
# Complex_I_Dk_m    4.583142  4.515280  2.463707
# Complex II_Lt_m   4.583142  4.515280  2.463707
# Complex_II_Dk_m   3.204893  3.326751  3.209414
# Complex_III_Lt_m  2.291571  2.257640  1.231854
# Complex_III_Dk_m  1.602446  1.663375  1.604707
# Complex_IV_Lt_m   0.000000  0.000000  0.000000
# Complex_IV_Dk_m   0.559557  0.551022  0.560461
# AOX1              0.000000  0.000000  0.000000
# AOX1              0.000000  0.000000  0.000000
# AOX2              0.000000  0.000000  0.000000
# AOX2              0.000000  0.000000  0.000000
#
#
# PHOTOSYSTEMS
#                                     M          M1          M2
# PS-II_Lt_p                  24.332493   25.906845   26.241649
# PS-II_Dk_p                   0.000000    0.000000    0.000000
# PQuinol-PCyanin-Reduc_Lt_p  48.664986   51.813691   52.483298
# PQuinol-PCyanin-Reduc_Dk_p   0.000000    0.000000    0.000000
# PS-I_Lt_p                   97.329972  103.627382  102.288167
# PS-I_Dk_p                    0.000000    0.000000    0.000000
# Ferredoxin-Oxidase_Lt_p     44.383606   46.493805   46.023606
# Ferredoxin-Oxidase_Dk_p      0.000000    0.000000    0.000000
# Cyclic-PS_Lt_p               0.000000    0.000000    0.000000
# Cyclic-PS_Dk_p               0.000000    0.000000    0.000000

# %%
m1m2.PrintSol()
# Out:
# Photon_Light_tx_M2: 207.254763991
# Photon_Light_tx_M1: 207.254763991
# RXN490-3650_Light_p_M1: 103.627381995
# RXN490-3650_Light_p_M2: 102.288167077
# PLASTOQUINOL--PLASTOCYANIN-REDUCTASE-RXN_Light_p_M2: 52.4832984569
# PLASTOQUINOL--PLASTOCYANIN-REDUCTASE-RXN_Light_p_M1: 51.8136909977
# 1.18.1.2-RXN_Light_p_M1: 46.4938049861
# 1.18.1.2-RXN_Light_p_M2: 46.0236057384
# PHOSGLYPHOS-RXN_Light_p_M1: 40.3166755907
# 1.2.1.13-RXN_Light_p_M1: 40.3166755907
# PHOSGLYPHOS-RXN_Light_p_M2: 38.3693038336
# 1.2.1.13-RXN_Light_p_M2: 38.3693038336
# PSII-RXN_Light_p_M2: 26.2416492285
# PSII-RXN_Light_p_M1: 25.9068454989
# Plastidial_ATP_Synthase_Light_p_M2: 22.4928421958
# Plastidial_ATP_Synthase_Light_p_M1: 22.2058675705
# PHOSPHORIBULOKINASE-RXN_Light_p_M1: 20.9347130928
# O2_Light_pc_M1: 20.256500559
# PHOSPHORIBULOKINASE-RXN_Light_p_M2: 19.821218989
# O2_Light_pc_M2: 17.9044214182
# RIBULOSE-BISPHOSPHATE-CARBOXYLASE-RXN_Light_p_M1: 15.7010348196
# CO2_Light_pc_M1: -15.6625973196
# TRIOSEPISOMERIZATION-RXN_Light_p_M1: 15.2023699882
# RIBULOSE-BISPHOSPHATE-CARBOXYLASE-RXN_Light_p_M2: 14.8659142418
# CO2_Light_pc_M2: -14.8393517418
# O2_Light_tx_M1: -14.5486878705
# TRIOSEPISOMERIZATION-RXN_Light_p_M2: 14.4136935436
# RIBULP3EPIM-RXN_Light_p_M1: -13.9646003952
# O2_Light_tx_M2: -13.3615821806
# CO2_Light_tx_M1: 13.304273808
# RIBULP3EPIM-RXN_Light_p_M2: -13.2195626594
# CO2_Light_tx_M2: 12.5036134306
# Pi_H+_Light_mc_M1: -8.41900407672
# ATP_ADP_Light_mc_M1: 8.30931657672
# F16BDEPHOS-RXN_Light_p_M1: 8.2261635406
# F16ALDOLASE-RXN_Light_p_M1: -8.2261635406
# F16BDEPHOS-RXN_Light_p_M2: 7.80797471395
# F16ALDOLASE-RXN_Light_p_M2: -7.80797471395
# ATPase_Light_tx_M2: -7.5
# ATPase_Light_tx_M1: -7.5
# ATPase_Dark_tx_M2: -7.5
# ATPase_Dark_tx_M1: -7.5
# ATP_ADP_Dark_mc_M1: 7.3691458838
# Pi_H+_Dark_mc_M1: -7.3093802588
# Pi_H+_Dark_mc_M2: -7.13750968097
# ATP_ADP_Dark_mc_M2: 7.13750968097
# 2TRANSKETO-RXN_Light_p_M1: -6.9883939476
# SEDOHEPTULOSE-BISPHOSPHATASE-RXN_Light_p_M1: 6.9762064476
# SEDOBISALDOL-RXN_Light_p_M1: 6.9762064476
# 1TRANSKETO-RXN_Light_p_M1: 6.9762064476
# RIB5PISOM-RXN_Light_p_M1: 6.9701126976
# 2TRANSKETO-RXN_Light_p_M2: -6.61384382968
# SEDOHEPTULOSE-BISPHOSPHATASE-RXN_Light_p_M2: 6.60571882968
# SEDOBISALDOL-RXN_Light_p_M2: 6.60571882968
# 1TRANSKETO-RXN_Light_p_M2: 6.60571882968
# RIB5PISOM-RXN_Light_p_M2: 6.60165632968
# ATP_ADP_Pi_Light_pc_M2: 5.62227519442
# RXN-969_Light_x_M1: 5.2336782732
# RXN-961_Light_p_M1: 5.2336782732
# Glycolate_Light_xc_M1: -5.2336782732
# Glycolate_Light_pc_M1: 5.2336782732
# GPH-RXN_Light_p_M1: 5.2336782732
# GLY_Light_xc_M1: 5.2336782732
# MALATE-DEHYDROGENASE-NADP+-RXN_Light_p_M1: 5.21488981211
# OAA_MAL_Light_pc_M1: -5.20738981211
# GLY_Light_mc_M1: -5.1971157732
# GLY_Light_xc_M2: 4.95530474726
# RXN-969_Light_x_M2: 4.95530474726
# RXN-961_Light_p_M2: 4.95530474726
# Glycolate_Light_xc_M2: -4.95530474726
# Glycolate_Light_pc_M2: 4.95530474726
# GPH-RXN_Light_p_M2: 4.95530474726
# GLY_Light_mc_M2: -4.92397662226
# NADH-DEHYDROG-A-RXN_Light_m_M1: 4.51528043711
# 1.10.2.2-RXN_Light_m_M1: 4.51528043711
# Pi_H+_Light_mc_M2: -3.79031855558
# ATP_ADP_Light_mc_M2: 3.71719355558
# Mitochondrial_ATP_Synthase_Light_m_M1: 3.67338002944
# CO2_Light_mc_M1: 3.43446934493
# 1.10.2.2-RXN_Dark_m_M1: 3.32675074101
# CO2_Light_mc_M2: 3.29704039446
# 1.10.2.2-RXN_Dark_m_M2: 3.2094143613
# GLUTAMATE-SYNTHASE-FERREDOXIN-RXN_Light_p_M1: 3.1809797616
# 2KG_MAL_Light_pc_M1: -3.1401985116
# GLT_MAL_Light_pc_M1: 3.1326985116
# MALATE-DEHYDROGENASE-NADP+-RXN_Light_p_M2: 2.95581643613
# OAA_MAL_Light_pc_M2: -2.95081643613
# CO2_Dark_tx_M1: -2.92005505801
# O2_Dark_tx_M1: 2.91337537051
# GLUTAMATE-SYNTHASE-FERREDOXIN-RXN_Light_p_M2: 2.88151956113
# O2_Dark_tx_M2: 2.85470718065
# 2KG_MAL_Light_pc_M2: -2.85433206113
# GLT_MAL_Light_pc_M2: 2.84933206113
# CO2_Dark_tx_M2: -2.83080093065
# NADH-DEHYDROG-A-RXN_Dark_m_M1: 2.77572871781
# Mehler_Reaction_Light_p_M2: 2.67842983674
# O2_Light_mc_M1: -2.67430688522
# GLYCINE-AMINOTRANSFERASE-RXN_Light_x_M1: 2.6632453866
# GLT_Light_xc_M1: -2.6632453866
# 2-KETOGLUTARATE_Light_xc_M1: 2.6632453866
# NADH-DEHYDROG-A-RXN_Dark_m_M2: 2.64895336404
# O2_Light_xc_M1: -2.6168391366
# CATAL-RXN_Light_x_M1: 2.6168391366
# GLUTAMINESYN-RXN_Light_m_M1: 2.6011360116
# GLN_GLU_Light_mc_M1: 2.6011360116
# GCVMULTI-RXN_Light_m_M1: 2.6011360116
# SER_Light_mc_M1: 2.5959797616
# GLYOHMETRANS-RXN_Light_m_M1: -2.5959797616
# GLYCINE-AMINOTRANSFERASE-RXN_Light_x_M2: 2.57526956113
# GLT_Light_xc_M2: -2.57526956113
# 2-KETOGLUTARATE_Light_xc_M2: 2.57526956113
# SER_Light_xc_M1: -2.5704328866
# SERINE-GLYOXYLATE-AMINOTRANSFERASE-RXN_Light_x_M1: 2.5704328866
# OAA_Light_xc_M1: 2.5704328866
# MAL_Light_xc_M1: -2.5704328866
# MALATE-DEH-RXN_Light_x_M1: 2.5704328866
# HYDROXYPYRUVATE-REDUCTASE-RXN-(NAD)_Light_x_M1: 2.5704328866
# Glycerate_Light_xc_M1: 2.5704328866
# GLYCERATE_Light_pc_M1: -2.5704328866
# GLY3KIN-RXN_Light_p_M1: 2.5704328866
# GLN_GLU_Light_pc_M1: -2.5233235116
# O2_Light_xc_M2: -2.47765237363
# CATAL-RXN_Light_x_M2: 2.47765237363
# NADH-DEHYDROG-A-RXN_Light_m_M2: 2.46370706113
# GLUTAMINESYN-RXN_Light_m_M2: 2.46370706113
# GLN_GLU_Light_mc_M2: 2.46370706113
# GCVMULTI-RXN_Light_m_M2: 2.46370706113
# 1.10.2.2-RXN_Light_m_M2: 2.46370706113
# SER_Light_mc_M2: 2.46026956113
# GLYOHMETRANS-RXN_Light_m_M2: -2.46026956113
# GLN_GLU_Light_pc_M2: -2.38589456113
# SER_Light_xc_M2: -2.38003518613
# SERINE-GLYOXYLATE-AMINOTRANSFERASE-RXN_Light_x_M2: 2.38003518613
# OAA_Light_xc_M2: 2.38003518613
# MAL_Light_xc_M2: -2.38003518613
# MALATE-DEH-RXN_Light_x_M2: 2.38003518613
# HYDROXYPYRUVATE-REDUCTASE-RXN-(NAD)_Light_x_M2: 2.38003518613
# Glycerate_Light_xc_M2: 2.38003518613
# GLYCERATE_Light_pc_M2: -2.38003518613
# GLY3KIN-RXN_Light_p_M2: 2.38003518613
# Mitochondrial_ATP_Synthase_Dark_m_M1: 2.29864545353
# CYTOCHROME-C-OXIDASE-RXN_Light_m_M1: 2.25764021856
# Mitochondrial_ATP_Synthase_Dark_m_M2: 2.20099539457
# CO2_Dark_mc_M1: 2.16998675474
# CO2_Dark_mc_M2: 2.11460689035
# Mitochondrial_ATP_Synthase_Light_m_M2: 2.08467520557
# O2_Dark_mc_M1: -2.08004203717
# O2_Dark_mc_M2: -2.02137384731
# OAA_MAL_Light_mc_M1: 1.91414442551
# MALATE-DEH-RXN_Light_m_M1: 1.91414442551
# GAP_Pi_Light_pc_M1: 1.792890625
# CYTOCHROME-C-OXIDASE-RXN_Dark_m_M1: 1.66337537051
# O2_Light_mc_M2: -1.64852019723
# GAP_Pi_Light_pc_M2: 1.6125
# H+_ATPase_Light_c_M1: 1.611
# CYTOCHROME-C-OXIDASE-RXN_Dark_m_M2: 1.60470718065
# 1.2.1.9-RXN_Light_c_M2: 1.55588541667
# 1.2.1.9-RXN_Light_c_M1: 1.55276041667
# MALATE-DEH-RXN_Dark_m_M1: 1.3793096714
# MALATE-DEH-RXN_Dark_m_M2: 1.36767980702
# SUPEROX-DISMUT-RXN_Light_p_M2: 1.33921491837
# RXN-3522_Light_p_M2: 1.33921491837
# RXN-3521_Light_p_M2: 1.33921491837
# H+_ATPase_Light_c_M2: 1.32384375
# GAP_3PGA_Light_pc_M2: 1.31838541667
# ATP_ADP_Pi_Light_pc_M1: 1.25426154828
# PGLUCISOM-RXN_Light_p_M1: -1.237769593
# CYTOCHROME-C-OXIDASE-RXN_Light_m_M2: 1.23185353056
# PGLUCISOM-RXN_Light_p_M2: -1.19413088427
# GAP_3PGA_Light_pc_M1: 1.13486979167
# H+_ATPase_Dark_c_M1: 0.97353125
# G6P_Pi_Dark_pc_M2: 0.879430959704
# G6P_Pi_Dark_pc_M1: 0.849306696732
# NADPHoxp_Light_tx_M2: -0.833333333333
# NADPHoxp_Light_tx_M1: -0.833333333333
# NADPHoxp_Dark_tx_M2: -0.833333333333
# NADPHoxp_Dark_tx_M1: -0.833333333333
# NADPHoxm_Light_tx_M2: -0.833333333333
# NADPHoxm_Light_tx_M1: -0.833333333333
# NADPHoxm_Dark_tx_M2: -0.833333333333
# NADPHoxm_Dark_tx_M1: -0.833333333333
# NADPHoxc_Light_tx_M2: -0.833333333333
# NADPHoxc_Light_tx_M1: -0.833333333333
# NADPHoxc_Dark_tx_M2: -0.833333333333
# NADPHoxc_Dark_tx_M1: -0.833333333333
# ISOCITDEH-RXN_Light_m_M2: 0.833333333333
# ISOCITDEH-RXN_Light_m_M1: 0.833333333333
# ISOCITDEH-RXN_Dark_m_M2: 0.833333333333
# ISOCITDEH-RXN_Dark_m_M1: 0.833333333333
# 2KG_ISOCITRATE_Light_mc_M2: 0.833333333333
# 2KG_ISOCITRATE_Light_mc_M1: 0.833333333333
# RXN1F-66_Light_p_M2: -0.813020738995
# RXN-7679_Light_p_M2: 0.813020738995
# RXN-7678-(NADP)_Light_p_M2: 0.813020738995
# RXN-7677_Light_p_M2: 0.813020738995
# RXN-7676_Light_p_M2: 0.813020738995
# RXN-7674_Light_p_M2: 0.813020738995
# PYRUVDEH-RXN_Dark_m_M1: 0.767584523202
# PYRUVATE_H+_Dark_mc_M1: -0.767584523202
# CITSYN-RXN_Dark_m_M1: 0.767584523202
# PHOSGLYPHOS-RXN_Dark_c_M1: -0.757637995602
# PEPDEPHOS-RXN_Dark_c_M1: 0.757637995602
# MALATE-DEH-RXN_Dark_c_M1: -0.757637995602
# GAPOXNPHOSPHN-RXN_Dark_c_M1: 0.757637995602
# 3PGAREARR-RXN_Dark_c_M1: 0.757637995602
# 2PGADEHYDRAT-RXN_Dark_c_M1: 0.757637995602
# Phloem_Loading_Light_c_M2: 0.74953125
# Phloem_Loading_Light_c_M1: 0.74953125
# INORGPYROPHOSPHAT-RXN_Light_p_M1: 0.739488343001
# ISOCITDEH-RXN_Light_c_M2: -0.723802083333
# Starch_LightDark_M1: 0.722144593001
# RXN0-5184_Dark_p_M1: 0.722144593001
# PHOSPHOGLUCMUT-RXN_Light_p_M1: -0.722144593001
# PHOSPHOGLUCMUT-RXN_Dark_p_M1: 0.722144593001
# GLYCOGENSYN-RXN_Light_p_M1: 0.722144593001
# GLUC1PADENYLTRANS-RXN_Light_p_M1: 0.722144593001
# ISOCITDEH-RXN_Light_c_M1: -0.721302083333
# MALATE-DEH-RXN_Light_c_M1: 0.71015625
# NITRITE_Light_pc_M1: -0.7096875
# NITRATE-REDUCTASE-NADH-RXN_Light_c_M1: 0.7096875
# FERREDOXIN--NITRITE-REDUCTASE-RXN_Light_p_M1: 0.7096875
# PYRUVDEH-RXN_Dark_m_M2: 0.704835997259
# PYRUVATE_H+_Dark_mc_M2: -0.704835997259
# CITSYN-RXN_Dark_m_M2: 0.704835997259
# INORGPYROPHOSPHAT-RXN_Light_p_M2: 0.691005884275
# TRIOSEPISOMERIZATION-RXN_Light_c_M1: 0.6875
# F16ALDOLASE-RXN_Light_c_M1: -0.6875
# TRIOSEPISOMERIZATION-RXN_Light_c_M2: 0.6875
# SUCROSE-PHOSPHATE-SYNTHASE-RXN_Light_c_M2: 0.6875
# SUCROSE-PHOSPHATASE-RXN_Light_c_M2: 0.6875
# F16BDEPHOS-RXN_Light_c_M2: 0.6875
# F16ALDOLASE-RXN_Light_c_M2: -0.6875
# SUCROSE-PHOSPHATE-SYNTHASE-RXN_Light_c_M1: 0.6875
# SUCROSE-PHOSPHATASE-RXN_Light_c_M1: 0.6875
# F16BDEPHOS-RXN_Light_c_M1: 0.6875
# PHOSGLYPHOS-RXN_Dark_c_M2: -0.687159222017
# PEPDEPHOS-RXN_Dark_c_M2: 0.687159222017
# MALATE-DEH-RXN_Dark_c_M2: -0.687159222017
# GAPOXNPHOSPHN-RXN_Dark_c_M2: 0.687159222017
# 3PGAREARR-RXN_Dark_c_M2: 0.687159222017
# 2PGADEHYDRAT-RXN_Dark_c_M2: 0.687159222017
# Starch_LightDark_M2: 0.678505884275
# RXN0-5184_Dark_p_M2: 0.678505884275
# PHOSPHOGLUCMUT-RXN_Light_p_M2: -0.678505884275
# PHOSPHOGLUCMUT-RXN_Dark_p_M2: 0.678505884275
# GLYCOGENSYN-RXN_Light_p_M2: 0.678505884275
# GLUC1PADENYLTRANS-RXN_Light_p_M2: 0.678505884275
# GLUTAMINESYN-RXN_Light_p_M1: 0.66375
# OAA_MAL_Dark_mc_M2: 0.662843809759
# ACONITATEHYDR-RXN_Dark_m_M1: 0.655553273202
# ACONITATEDEHYDR-RXN_Dark_m_M1: 0.655553273202
# H+_ATPase_Dark_c_M2: 0.62834375
# PGLUCISOM-RXN_Dark_p_M2: -0.617591742096
# ACONITATEHYDR-RXN_Dark_m_M2: 0.595304747259
# ACONITATEDEHYDR-RXN_Dark_m_M2: 0.595304747259
# SUCCINATE-DEHYDROGENASE-UBIQUINONE-RXN_Dark_m_M2: 0.560460997259
# SUCCCOASYN-RXN_Dark_m_M2: 0.560460997259
# FUMHYDR-RXN_Dark_m_M2: 0.560460997259
# 2OXOGLUTARATEDEH-RXN_Dark_m_M2: 0.560460997259
# OAA_MAL_Dark_mc_M1: 0.551959523202
# SUCCINATE-DEHYDROGENASE-UBIQUINONE-RXN_Dark_m_M1: 0.551022023202
# SUCCCOASYN-RXN_Dark_m_M1: 0.551022023202
# FUMHYDR-RXN_Dark_m_M1: 0.551022023202
# 2OXOGLUTARATEDEH-RXN_Dark_m_M1: 0.551022023202
# PGLUCISOM-RXN_Dark_p_M1: -0.543828770398
# X5P_Pi_Dark_pc_M2: -0.535680959704
# RIBULP3EPIM-RXN_Dark_c_M2: 0.535680959704
# GLU6PDEHYDROG-RXN_Dark_c_M2: 0.535680959704
# 6PGLUCONOLACT-RXN_Dark_c_M2: 0.535680959704
# 6PGLUCONDEHYDROG-RXN_Dark_c_M2: 0.535680959704
# UDPKIN-RXN_Light_c_M2: 0.515625
# UDPKIN-RXN_Light_c_M1: 0.515625
# Sucrose_Light_biomass_M2: -0.515625
# Sucrose_Light_biomass_M1: -0.515625
# PHOSPHOGLUCMUT-RXN_Light_c_M2: -0.515625
# PHOSPHOGLUCMUT-RXN_Light_c_M1: -0.515625
# GLUC1PURIDYLTRANS-RXN_Light_c_M2: 0.515625
# GLUC1PURIDYLTRANS-RXN_Light_c_M1: 0.515625
# G6P_Pi_Light_pc_M2: 0.515625
# G6P_Pi_Light_pc_M1: 0.515625
# X5P_Pi_Dark_pc_M1: -0.505556696732
# RIBULP3EPIM-RXN_Dark_c_M1: 0.505556696732
# GLU6PDEHYDROG-RXN_Dark_c_M1: 0.505556696732
# 6PGLUCONOLACT-RXN_Dark_c_M1: 0.505556696732
# 6PGLUCONDEHYDROG-RXN_Dark_c_M1: 0.505556696732
# GLUTAMINESYN-RXN_Light_p_M2: 0.4996875
# NITRITE_Light_pc_M2: -0.473125
# NITRATE-REDUCTASE-NADH-RXN_Light_c_M2: 0.473125
# FERREDOXIN--NITRITE-REDUCTASE-RXN_Light_p_M2: 0.473125
# MALATE-DEH-RXN_Light_c_M2: 0.4725
# NO3_Light_tx_M1: 0.4258125
# CO2_Dark_pc_M1: 0.422291666667
# CO2_Dark_pc_M2: 0.418541666667
# 3PGAREARR-RXN_Light_c_M1: 0.417890625
# 2PGADEHYDRAT-RXN_Light_c_M1: 0.417890625
# O2_Dark_pc_M2: -0.416666666667
# O2_Dark_pc_M1: -0.416666666667
# GLU6PDEHYDROG-RXN_Dark_p_M2: 0.416666666667
# GLU6PDEHYDROG-RXN_Dark_p_M1: 0.416666666667
# 6PGLUCONOLACT-RXN_Dark_p_M2: 0.416666666667
# 6PGLUCONOLACT-RXN_Dark_p_M1: 0.416666666667
# 6PGLUCONDEHYDROG-RXN_Dark_p_M2: 0.416666666667
# 6PGLUCONDEHYDROG-RXN_Dark_p_M1: 0.416666666667
# Phloem_Loading_Dark_c_M1: 0.40578125
# H+(PPi)_rev_Light_vc_M2: 0.3909375
# RXN0-5224_Light_c_M1: 0.35484375
# PEPCARBOX-RXN_Light_c_M1: 0.35484375
# GAP_Pi_Dark_pc_M1: 0.3429011904
# ASPAMINOTRANS-RXN_Light_c_M1: -0.3421875
# INORGPYROPHOSPHAT-RXN_Light_c_M1: 0.33953125
# GAP_Pi_Dark_pc_M2: 0.326102546532
# TRANSALDOL-RXN_Dark_p_M2: 0.31744920879
# RIB5PISOM-RXN_Dark_p_M2: -0.31744920879
# 2TRANSKETO-RXN_Dark_p_M2: 0.31744920879
# 1TRANSKETO-RXN_Dark_p_M2: -0.31744920879
# RIB5PISOM-RXN_Dark_p_M1: -0.3074077878
# TRANSALDOL-RXN_Dark_p_M1: 0.3074077878
# 2TRANSKETO-RXN_Dark_p_M1: 0.3074077878
# 1TRANSKETO-RXN_Dark_p_M1: -0.3074077878
# Nitrate_LightDark_M1: -0.283875
# NO3_Dark_tx_M1: 0.283875
# NITRATE_Light_vc_M1: 0.283875
# NO3_Light_tx_M2: 0.283875
# Phloem_Loading_Dark_c_M2: 0.24984375
# TRIOSEPISOMERIZATION-RXN_Dark_c_M1: -0.242861805201
# H+(ATP)_rev_Dark_vc_M1: 0.239015625
# ISOCITDEH-RXN_Dark_c_M2: -0.238028586074
# 2KG_ISOCITRATE_Dark_mc_M2: 0.238028586074
# 3PGAREARR-RXN_Light_c_M2: 0.2375
# 2PGADEHYDRAT-RXN_Light_c_M2: 0.2375
# RXN0-5224_Light_c_M2: 0.2375
# PEPCARBOX-RXN_Light_c_M2: 0.2375
# H+(PPi)_rev_Light_vc_M1: 0.2309375
# H+(ATP)_rev_Dark_vc_M2: 0.211609375
# ASP_LightDark_M1: 0.209296875
# Nitrate_LightDark_M2: -0.18925
# NO3_Dark_tx_M2: 0.18925
# NITRATE_Light_vc_M2: 0.18925
# TRIOSEPISOMERIZATION-RXN_Dark_c_M2: -0.189181675484
# ASPAMINOTRANS-RXN_Dark_c_M1: 0.18703125
# ISOCITDEH-RXN_Dark_c_M1: -0.177780060131
# 2KG_ISOCITRATE_Dark_mc_M1: 0.177780060131
# 2.7.1.90-RXN_Dark_c_M2: 0.171875
# F16ALDOLASE-RXN_Dark_c_M2: 0.171875
# PGLUCISOM-RXN_Dark_c_M2: 0.171875
# SUCROSE-SYNTHASE-RXN_Light_c_M2: -0.171875
# Fructose_LightDark_M2: 0.171875
# FRU_H+_rev_Light_vc_M2: 0.171875
# FRU_Dark_vc_M2: 0.171875
# UDPKIN-RXN_Dark_c_M2: 0.171875
# UDPKIN-RXN_Dark_c_M1: 0.171875
# Sucrose_Dark_biomass_M2: -0.171875
# Sucrose_Dark_biomass_M1: -0.171875
# SUCROSE-SYNTHASE-RXN_Light_c_M1: -0.171875
# SUCROSE-SYNTHASE-RXN_Dark_c_M2: 0.171875
# SUCROSE-SYNTHASE-RXN_Dark_c_M1: 0.171875
# PHOSPHOGLUCMUT-RXN_Dark_c_M2: -0.171875
# PHOSPHOGLUCMUT-RXN_Dark_c_M1: -0.171875
# GLUC1PURIDYLTRANS-RXN_Dark_c_M2: 0.171875
# GLUC1PURIDYLTRANS-RXN_Dark_c_M1: 0.171875
# Fructose_LightDark_M1: 0.171875
# FRU_H+_rev_Light_vc_M1: 0.171875
# FRU_Dark_vc_M1: 0.171875
# 2.7.1.90-RXN_Dark_c_M1: 0.171875
# PGLUCISOM-RXN_Dark_c_M1: 0.171875
# F16ALDOLASE-RXN_Dark_c_M1: 0.171875
# 2KG_MAL_Dark_mc_M1: 0.164296875
# INORGPYROPHOSPHAT-RXN_Light_c_M2: 0.16125
# NITRATE_H+_rev_Dark_vc_M1: 0.1419375
# ASPAMINOTRANS-RXN_Light_c_M2: -0.13921875
# MAL_CIT_Dark_mc_M1: -0.11203125
# Citrate_LightDark_M1: -0.11203125
# CIT_H+_rev_Dark_vc_M1: 0.11203125
# CIT_H+_Light_vc_M1: 0.11203125
# ACONITATEHYDR-RXN_Light_c_M1: 0.11203125
# ACONITATEDEHYDR-RXN_Light_c_M1: 0.11203125
# Malate_LightDark_M2: 0.10953125
# MAL_H+_rev_Light_vc_M2: 0.10953125
# MAL_H+_Dark_vc_M2: 0.10953125
# ACONITATEHYDR-RXN_Light_c_M2: 0.10953125
# ACONITATEDEHYDR-RXN_Light_c_M2: 0.10953125
# MAL_CIT_Dark_mc_M2: -0.10953125
# Citrate_LightDark_M2: -0.10953125
# CIT_H+_rev_Dark_vc_M2: 0.10953125
# CIT_H+_Light_vc_M2: 0.10953125
# RIBULP3EPIM-RXN_Dark_p_M1: 0.109258878867
# RIBULP3EPIM-RXN_Dark_p_M2: 0.0992174578765
# NITRATE_H+_rev_Dark_vc_M2: 0.094625
# Glutamine_Light_biomass_M2: -0.0778125
# Glutamine_Light_biomass_M1: -0.0778125
# Glutamine_Dark_biomass_M1: -0.0778125
# GLUTAMINESYN-RXN_Dark_m_M1: 0.0778125
# GLN_GLU_Dark_mc_M1: 0.0778125
# F16ALDOLASE-RXN_Dark_p_M1: 0.0709868052014
# DHAP_Pi_Dark_pc_M1: 0.0709868052014
# 6PFRUCTPHOS-RXN_Dark_p_M1: 0.0709868052014
# PEPDEPHOS-RXN_Light_c_M1: 0.063046875
# OAA_Pi_Dark_mc_M1: 0.059765625
# GLUTAMATE-DEHYDROGENASE-RXN_Dark_m_M1: 0.059765625
# PRO_GLU_Dark_mc_M1: 0.059765625
# PRO_Dark_mc_M1: -0.059765625
# L-ASPARTATE_Light_pc_M1: -0.05578125
# ADENYL-KIN-RXN_Light_m_M1: 0.05484375
# ATP_AMP_Light_mc_M1: 0.05484375
# NH3_Light_pc_M1: 0.04734375
# ASNSYNA-RXN_Light_c_M1: 0.04734375
# ASPARTATEKIN-RXN_Light_p_M1: 0.04640625
# ASPARTATE-SEMIALDEHYDE-DEHYDROGENASE-RXN_Light_p_M1: 0.04640625
# ASP_LightDark_M2: 0.042265625
# OAA_MAL_Dark_pc_M1: -0.0411184026007
# MALATE-DEH-RXN_Dark_p_M1: -0.0411184026007
# PYRUVATE_Light_pc_M1: -0.0403125
# L-ASPARTATE_Light_pc_M2: -0.038125
# HOMOSERKIN-RXN_Light_p_M1: 0.03796875
# HOMOSERDEHYDROG-RXN-(NADP)_Light_p_M1: 0.03796875
# GLY_LightDark_M1: 0.037734375
# ATP_AMP_Light_mc_M2: 0.0365625
# ADENYL-KIN-RXN_Light_m_M2: 0.0365625
# PHOSGLYPHOS-RXN_Dark_p_M1: -0.0354934026007
# PEPDEPHOS-RXN_Dark_p_M1: 0.0354934026007
# GAPOXNPHOSPHN-RXN_Dark_p_M1: 0.0354934026007
# 3PGAREARR-RXN_Dark_p_M1: 0.0354934026007
# 2PGADEHYDRAT-RXN_Dark_p_M1: 0.0354934026007
# 2KG_MAL_Dark_mc_M2: 0.03484375
# ASPAMINOTRANS-RXN_Dark_c_M2: 0.03484375
# THRESYN-RXN_Light_p_M1: 0.0346875
# PYRUVATE_Dark_pc_M1: 0.0326809026007
# GLY_LightDark_M2: 0.0325
# ASPARTATEKIN-RXN_Light_p_M2: 0.031875
# ASPARTATE-SEMIALDEHYDE-DEHYDROGENASE-RXN_Light_p_M2: 0.031875
# ASNSYNA-RXN_Light_c_M2: 0.0315625
# DSERDEAM-RXN_Light_c_M2: 0.0315625
# 5.1.1.18-RXN_Light_c_M2: 0.0315625
# SER_Light_pc_M2: -0.030625
# ALANINE-AMINOTRANSFERASE-RXN_Light_c_M2: -0.0303125
# Malate_LightDark_M1: 0.02953125
# MAL_H+_rev_Light_vc_M1: 0.02953125
# MAL_H+_Dark_vc_M1: 0.02953125
# THR_Light_pc_M1: 0.0290625
# CYSTATHIONINE-BETA-LYASE-RXN_Light_p_M2: 0.0278125
# Glutamate_Light_biomass_M2: -0.02671875
# Glutamate_Light_biomass_M1: -0.02671875
# Glutamate_Dark_biomass_M1: -0.02671875
# HOMOSERKIN-RXN_Light_p_M2: 0.02625
# Glutamine_Dark_biomass_M2: -0.0259375
# GLUTAMINESYN-RXN_Dark_m_M2: 0.0259375
# GLN_GLU_Dark_mc_M2: 0.0259375
# CYSTATHIONINE-BETA-SYNTHASE-RXN_Light_p_M2: 0.025625
# 3PGAREARR-RXN_Light_p_M1: 0.024375
# 2PGADEHYDRAT-RXN_Light_p_M1: 0.024375
# THRESYN-RXN_Light_p_M2: 0.0240625
# Asparagine_Light_biomass_M2: -0.023671875
# Asparagine_Light_biomass_M1: -0.023671875
# Asparagine_Dark_biomass_M1: -0.023671875
# ASN_LightDark_M1: 0.023671875
# Alanine_Light_biomass_M2: -0.022734375
# Alanine_Light_biomass_M1: -0.022734375
# Alanine_Dark_biomass_M1: -0.022734375
# ALANINE-AMINOTRANSFERASE-RXN_Light_c_M1: -0.022734375
# ALANINE-AMINOTRANSFERASE-RXN_Dark_c_M1: -0.022734375
# Aspartate_Light_biomass_M2: -0.022265625
# Aspartate_Light_biomass_M1: -0.022265625
# Aspartate_Dark_biomass_M1: -0.022265625
# HOMOSERDEHYDROG-RXN-(NADP)_Light_p_M2: 0.0209375
# THR_Light_pc_M2: 0.0203125
# THF_Dark_mc_M1: -0.018046875
# Serine_Light_biomass_M2: -0.018046875
# Serine_Light_biomass_M1: -0.018046875
# Serine_Dark_biomass_M1: -0.018046875
# METHYLENE-THF_Dark_mc_M1: 0.018046875
# GLY_Dark_mc_M1: -0.018046875
# GLYOHMETRANS-RXN_Dark_c_M1: -0.018046875
# GCVMULTI-RXN_Dark_m_M1: 0.018046875
# ADENYL-KIN-RXN_Light_p_M1: 0.01734375
# F16ALDOLASE-RXN_Dark_p_M2: 0.0173066754844
# DHAP_Pi_Dark_pc_M2: 0.0173066754844
# 6PFRUCTPHOS-RXN_Dark_p_M2: 0.0173066754844
# DIHYDROXYISOVALDEHYDRAT-RXN_Light_p_M1: 0.016875
# ACETOLACTSYN-RXN_Light_p_M1: 0.016875
# ACETOLACTREDUCTOISOM-RXN_Light_p_M1: 0.016875
# 3PGAREARR-RXN_Light_p_M2: 0.01625
# 2PGADEHYDRAT-RXN_Light_p_M2: 0.01625
# THF_Dark_mc_M2: -0.0159765625
# METHYLENE-THF_Dark_mc_M2: 0.0159765625
# GLY_Dark_mc_M2: -0.0159765625
# GLYOHMETRANS-RXN_Dark_c_M2: -0.0159765625
# GCVMULTI-RXN_Dark_m_M2: 0.0159765625
# VAL_Light_pc_M1: 0.0140625
# BRANCHED-CHAINAMINOTRANSFERVAL-RXN_Light_p_M1: -0.0140625
# THR_LightDark_M1: 0.013125
# Threonine_Light_biomass_M2: -0.013125
# Threonine_Light_biomass_M1: -0.013125
# Threonine_Dark_biomass_M1: -0.013125
# ADENYL-KIN-RXN_Light_p_M2: 0.0125
# SHIKIMATE-KINASE-RXN_Light_p_M1: 0.0121875
# SHIKIMATE-5-DEHYDROGENASE-RXN_Light_p_M1: 0.0121875
# DAHPSYN-RXN_Light_p_M1: 0.0121875
# CHORISMATE-SYNTHASE-RXN_Light_p_M1: 0.0121875
# 3-DEHYDROQUINATE-SYNTHASE-RXN_Light_p_M1: 0.0121875
# 3-DEHYDROQUINATE-DEHYDRATASE-RXN_Light_p_M1: 0.0121875
# 2.5.1.19-RXN_Light_p_M1: 0.0121875
# DIHYDROXYISOVALDEHYDRAT-RXN_Light_p_M2: 0.01125
# ACETOLACTSYN-RXN_Light_p_M2: 0.01125
# ACETOLACTREDUCTOISOM-RXN_Light_p_M2: 0.01125
# OAA_MAL_Dark_pc_M2: -0.0105283377422
# MALATE-DEH-RXN_Dark_p_M2: -0.0105283377422
# DSERDEAM-RXN_Dark_c_M2: 0.0099609375
# 5.1.1.18-RXN_Dark_c_M2: 0.0099609375
# NH3_Dark_mc_M2: -0.0099609375
# FUMHYDR-RXN_Light_c_M1: 0.009375
# Glutamate_Dark_biomass_M2: -0.00890625
# PHOSGLYPHOS-RXN_Dark_p_M2: -0.00865333774222
# PEPDEPHOS-RXN_Dark_p_M2: 0.00865333774222
# GAPOXNPHOSPHN-RXN_Dark_p_M2: 0.00865333774222
# 3PGAREARR-RXN_Dark_p_M2: 0.00865333774222
# 2PGADEHYDRAT-RXN_Dark_p_M2: 0.00865333774222
# VAL_Light_pc_M2: 0.0084375
# VAL_LightDark_M1: 0.0084375
# RXN-7737_Light_p_M1: 0.0084375
# LYS_Light_pc_M1: 0.0084375
# DIHYDROPICRED-RXN-(NAD)_Light_p_M1: 0.0084375
# DIHYDRODIPICSYN-RXN_Light_p_M1: 0.0084375
# DIAMINOPIMEPIM-RXN_Light_p_M1: 0.0084375
# DIAMINOPIMDECARB-RXN_Light_p_M1: 0.0084375
# BRANCHED-CHAINAMINOTRANSFERVAL-RXN_Light_p_M2: -0.0084375
# SHIKIMATE-KINASE-RXN_Light_p_M2: 0.008125
# SHIKIMATE-5-DEHYDROGENASE-RXN_Light_p_M2: 0.008125
# DAHPSYN-RXN_Light_p_M2: 0.008125
# CHORISMATE-SYNTHASE-RXN_Light_p_M2: 0.008125
# 3-DEHYDROQUINATE-SYNTHASE-RXN_Light_p_M2: 0.008125
# 3-DEHYDROQUINATE-DEHYDRATASE-RXN_Light_p_M2: 0.008125
# 2.5.1.19-RXN_Light_p_M2: 0.008125
# CHORISMATEMUT-RXN_Light_p_M1: 0.00796875
# Asparagine_Dark_biomass_M2: -0.007890625
# ASN_LightDark_M2: 0.007890625
# PYRUVATE_Dark_pc_M2: 0.00771583774222
# ALA_LightDark_M2: 0.007578125
# Alanine_Dark_biomass_M2: -0.007578125
# ORNCARBAMTRANSFER-RXN_Light_p_M1: 0.0075
# N-ACETYLGLUTPREDUCT-RXN_Light_p_M1: 0.0075
# L-CITRULLINE_Light_pc_M1: 0.0075
# GLUTAMATE-N-ACETYLTRANSFERASE-RXN_Light_p_M1: 0.0075
# ARGSUCCINSYN-RXN_Light_c_M1: 0.0075
# ARGSUCCINLYA-RXN_Light_c_M1: 0.0075
# ACETYLORNTRANSAM-RXN_Light_p_M1: 0.0075
# ACETYLGLUTKIN-RXN_Light_p_M1: 0.0075
# 6.3.4.16-RXN_Light_p_M1: 0.0075
# SER_Light_pc_M1: -0.0075
# ASPAMINOTRANS-RXN_Light_p_M1: 0.0075
# Aspartate_Dark_biomass_M2: -0.007421875
# FUMHYDR-RXN_Light_c_M2: 0.00625
# PRPPSYN-RXN_Light_p_M1: 0.00609375
# PREPHENATE-TRANSAMINE-RXN_Light_p_M1: 0.00609375
# ACETATE--COA-LIGASE-RXN_Light_p_M1: 0.00609375
# Serine_Dark_biomass_M2: -0.006015625
# RXN-7737_Light_p_M2: 0.005625
# LYS_Light_pc_M2: 0.005625
# DIHYDROPICRED-RXN-(NADP)_Light_p_M2: 0.005625
# DIHYDRODIPICSYN-RXN_Light_p_M2: 0.005625
# DIAMINOPIMEPIM-RXN_Light_p_M2: 0.005625
# DIAMINOPIMDECARB-RXN_Light_p_M2: 0.005625
# Valine_Light_biomass_M2: -0.005625
# Valine_Light_biomass_M1: -0.005625
# Valine_Dark_biomass_M1: -0.005625
# THREDEHYD-RXN_Light_p_M1: 0.005625
# ILE_Light_pc_M1: 0.005625
# DIHYDROXYMETVALDEHYDRAT-RXN_Light_p_M1: 0.005625
# BRANCHED-CHAINAMINOTRANSFERILEU-RXN_Light_p_M1: -0.005625
# ACETOOHBUTSYN-RXN_Light_p_M1: 0.005625
# ACETOOHBUTREDUCTOISOM-RXN_Light_p_M1: 0.005625
# PREPHENATE-TRANSAMINE-RXN_Light_p_M2: 0.0053125
# CHORISMATEMUT-RXN_Light_p_M2: 0.0053125
# HOMOSERDEHYDROG-RXN-(NAD)_Light_p_M2: 0.0053125
# THF_Light_mc_M1: -0.00515625
# METHYLENE-THF_Light_mc_M1: 0.00515625
# PHE_Light_pc_M1: 0.00515625
# CARBOXYCYCLOHEXADIENYL-DEHYDRATASE-RXN_Light_p_M1: 0.00515625
# ORNCARBAMTRANSFER-RXN_Light_p_M2: 0.005
# N-ACETYLGLUTPREDUCT-RXN_Light_p_M2: 0.005
# L-CITRULLINE_Light_pc_M2: 0.005
# GLUTAMATE-N-ACETYLTRANSFERASE-RXN_Light_p_M2: 0.005
# ARGSUCCINSYN-RXN_Light_c_M2: 0.005
# ARGSUCCINLYA-RXN_Light_c_M2: 0.005
# ACETYLORNTRANSAM-RXN_Light_p_M2: 0.005
# ACETYLGLUTKIN-RXN_Light_p_M2: 0.005
# 6.3.4.16-RXN_Light_p_M2: 0.005
# ACETATE--COA-LIGASE-RXN_Light_p_M2: 0.005
# ASPAMINOTRANS-RXN_Light_p_M2: 0.005
# Threonine_Dark_biomass_M2: -0.004375
# THR_LightDark_M2: 0.004375
# TRP_Light_pc_M1: 0.00421875
# RXN0-2382_Light_p_M1: 0.00421875
# RXN0-2381_Light_p_M1: 0.00421875
# PRTRANS-RXN_Light_p_M1: 0.00421875
# PRAISOM-RXN_Light_p_M1: 0.00421875
# Lysine_Light_biomass_M2: -0.00421875
# Lysine_Light_biomass_M1: -0.00421875
# Lysine_Dark_biomass_M1: -0.00421875
# LYS_LightDark_M1: 0.00421875
# IGPSYN-RXN_Light_p_M1: 0.00421875
# ANTHRANSYN-RXN_Light_p_M1: 0.00421875
# PRPPSYN-RXN_Light_p_M2: 0.0040625
# ARG_LightDark_M1: 0.00375
# Arginine_Light_biomass_M2: -0.00375
# Arginine_Light_biomass_M1: -0.00375
# Arginine_Dark_biomass_M1: -0.00375
# THREDEHYD-RXN_Light_p_M2: 0.00375
# ILE_Light_pc_M2: 0.00375
# DIHYDROXYMETVALDEHYDRAT-RXN_Light_p_M2: 0.00375
# BRANCHED-CHAINAMINOTRANSFERILEU-RXN_Light_p_M2: -0.00375
# ACETOOHBUTSYN-RXN_Light_p_M2: 0.00375
# ACETOOHBUTREDUCTOISOM-RXN_Light_p_M2: 0.00375
# PHE_Light_pc_M2: 0.0034375
# CARBOXYCYCLOHEXADIENYL-DEHYDRATASE-RXN_Light_p_M2: 0.0034375
# THF_Light_mc_M2: -0.0034375
# METHYLENE-THF_Light_mc_M2: 0.0034375
# SULFITE-REDUCTASE-FERREDOXIN-RXN_Light_p_M1: 0.00328125
# SULFATE-ADENYLYLTRANS-RXN_Light_p_M1: 0.00328125
# SO4_Light_tx_M1: 0.00328125
# SO4_Light_pc_M1: -0.00328125
# SERINE-O-ACETTRAN-RXN_Light_p_M1: 0.00328125
# HOMOCYSMETB12-RXN_Light_c_M1: 0.00328125
# HOMO-CYS_Light_pc_M1: 0.00328125
# GLUTATHIONE-REDUCT-NADPH-RXN_Light_p_M1: 0.00328125
# CYSTATHIONINE-BETA-LYASE-RXN_Light_p_M1: 0.00328125
# CYSPH-RXN_Light_p_M1: 0.00328125
# ACSERLY-RXN_Light_p_M1: 0.00328125
# 1.8.4.9-RXN_Light_p_M1: 0.00328125
# 1.5.1.20-RXN_Light_c_M1: 0.00328125
# VAL_LightDark_M2: 0.0028125
# TRP_Light_pc_M2: 0.0028125
# RXN0-2382_Light_p_M2: 0.0028125
# RXN0-2381_Light_p_M2: 0.0028125
# PRTRANS-RXN_Light_p_M2: 0.0028125
# PRAISOM-RXN_Light_p_M2: 0.0028125
# IGPSYN-RXN_Light_p_M2: 0.0028125
# ANTHRANSYN-RXN_Light_p_M2: 0.0028125
# VAL_Dark_pc_M1: -0.0028125
# TYR_Light_pc_M1: 0.0028125
# THREONINE-ALDOLASE-RXN_Light_c_M2: 0.0028125
# RXN66-3_Light_c_M2: 0.0028125
# RXN-8991_Light_p_M2: 0.0028125
# RXN-8991_Light_p_M1: 0.0028125
# RXN-8991_Dark_p_M1: 0.0028125
# RXN-7800_Light_p_M2: 0.0028125
# RXN-7800_Light_p_M1: 0.0028125
# RXN-7800_Dark_p_M1: 0.0028125
# PYRUVDEH-RXN_Dark_p_M1: 0.0028125
# Leucine_Light_biomass_M2: -0.0028125
# Leucine_Light_biomass_M1: -0.0028125
# Leucine_Dark_biomass_M1: -0.0028125
# LEU_Light_pc_M2: 0.0028125
# LEU_Light_pc_M1: 0.0028125
# LEU_Dark_pc_M1: 0.0028125
# Isoleucine_Light_biomass_M2: -0.0028125
# Isoleucine_Light_biomass_M1: -0.0028125
# Isoleucine_Dark_biomass_M1: -0.0028125
# ILE_LightDark_M1: 0.0028125
# BRANCHED-CHAINAMINOTRANSFERVAL-RXN_Dark_p_M1: 0.0028125
# BRANCHED-CHAINAMINOTRANSFERLEU-RXN_Light_p_M2: -0.0028125
# BRANCHED-CHAINAMINOTRANSFERLEU-RXN_Light_p_M1: -0.0028125
# BRANCHED-CHAINAMINOTRANSFERLEU-RXN_Dark_p_M1: -0.0028125
# ACET_Light_pc_M2: -0.0028125
# 3-ISOPROPYLMALISOM-RXN_Light_p_M2: 0.0028125
# 3-ISOPROPYLMALISOM-RXN_Light_p_M1: 0.0028125
# 3-ISOPROPYLMALISOM-RXN_Dark_p_M1: 0.0028125
# 3-ISOPROPYLMALDEHYDROG-RXN_Light_p_M2: 0.0028125
# 3-ISOPROPYLMALDEHYDROG-RXN_Light_p_M1: 0.0028125
# 3-ISOPROPYLMALDEHYDROG-RXN_Dark_p_M1: 0.0028125
# 2-ISOPROPYLMALATESYN-RXN_Light_p_M2: 0.0028125
# 2-ISOPROPYLMALATESYN-RXN_Light_p_M1: 0.0028125
# 2-ISOPROPYLMALATESYN-RXN_Dark_p_M1: 0.0028125
# THREONINE-ALDOLASE-RXN_Light_c_M1: 0.0028125
# RXN66-3_Light_c_M1: 0.0028125
# ACET_Light_pc_M1: -0.0028125
# Phenylalanine_Light_biomass_M2: -0.002578125
# Phenylalanine_Light_biomass_M1: -0.002578125
# Phenylalanine_Dark_biomass_M1: -0.002578125
# PHE_LightDark_M1: 0.002578125
# HOMOCYSMETB12-RXN_Light_c_M2: 0.0021875
# HOMO-CYS_Light_pc_M2: 0.0021875
# CYSPH-RXN_Light_p_M2: 0.0021875
# 1.5.1.20-RXN_Light_c_M2: 0.0021875
# SULFITE-REDUCTASE-FERREDOXIN-RXN_Light_p_M2: 0.0021875
# SULFATE-ADENYLYLTRANS-RXN_Light_p_M2: 0.0021875
# SO4_Light_tx_M2: 0.0021875
# SO4_Light_pc_M2: -0.0021875
# SERINE-O-ACETTRAN-RXN_Light_p_M2: 0.0021875
# GLUTATHIONE-REDUCT-NADPH-RXN_Light_p_M2: 0.0021875
# ACSERLY-RXN_Light_p_M2: 0.0021875
# 1.8.4.9-RXN_Light_p_M2: 0.0021875
# Tryptophan_Light_biomass_M2: -0.002109375
# Tryptophan_Light_biomass_M1: -0.002109375
# Tryptophan_Dark_biomass_M1: -0.002109375
# TRP_LightDark_M1: 0.002109375
# TYRAMINOTRANS-RXN_Light_p_M1: 0.001875
# PREPHENATEDEHYDROG-RXN_Light_p_M1: 0.001875
# Valine_Dark_biomass_M2: -0.001875
# THF_Light_pc_M1: 0.001875
# RXN-8001_Light_p_M1: 0.001875
# PRIBFAICARPISOM-RXN_Light_p_M1: 0.001875
# METHYLENETHFDEHYDROG-NADP-RXN_Light_c_M1: 0.001875
# METHENYLTHFCYCLOHYDRO-RXN_Light_c_M1: 0.001875
# IMPCYCLOHYDROLASE-RXN_Light_p_M1: 0.001875
# IMIDPHOSDEHYD-RXN_Light_p_M1: 0.001875
# HIS_Light_pc_M1: 0.001875
# HISTPRATPHYD-RXN_Light_p_M1: 0.001875
# HISTIDPHOS-RXN_Light_p_M1: 0.001875
# HISTCYCLOHYD-RXN_Light_p_M1: 0.001875
# HISTAMINOTRANS-RXN_Light_p_M1: 0.001875
# GLUTAMIDOTRANS-RXN_Light_p_M1: 0.001875
# GDPKIN-RXN_Light_p_M1: 0.001875
# FUM_Light_pc_M1: 0.001875
# ATPPHOSPHORIBOSYLTRANS-RXN_Light_p_M1: 0.001875
# AMPSYN-RXN_Light_p_M1: 0.001875
# AICARTRANSFORM-RXN_Light_p_M1: 0.001875
# ADENYLOSUCCINATE-SYNTHASE-RXN_Light_p_M1: 0.001875
# 10-FORMYL-THF_Light_pc_M1: -0.001875
# TYR_Light_pc_M2: 0.001875
# RXN-5682_Light_p_M2: 0.001875
# Methionine_Light_biomass_M2: -0.001640625
# Methionine_Light_biomass_M1: -0.001640625
# Methionine_Dark_biomass_M1: -0.001640625
# MET_LightDark_M1: 0.001640625
# Glycine_Light_biomass_M2: -0.001640625
# Glycine_Light_biomass_M1: -0.001640625
# Glycine_Dark_biomass_M1: -0.001640625
# Lysine_Dark_biomass_M2: -0.00140625
# LYS_LightDark_M2: 0.00140625
# Tyrosine_Light_biomass_M2: -0.00140625
# Tyrosine_Light_biomass_M1: -0.00140625
# Tyrosine_Dark_biomass_M1: -0.00140625
# TYR_LightDark_M1: 0.00140625
# THF_Light_pc_M2: 0.00125
# METHYLENETHFDEHYDROG-NADP-RXN_Light_c_M2: 0.00125
# METHENYLTHFCYCLOHYDRO-RXN_Light_c_M2: 0.00125
# 10-FORMYL-THF_Light_pc_M2: -0.00125
# RXN-8001_Light_p_M2: 0.00125
# PRIBFAICARPISOM-RXN_Light_p_M2: 0.00125
# IMPCYCLOHYDROLASE-RXN_Light_p_M2: 0.00125
# IMIDPHOSDEHYD-RXN_Light_p_M2: 0.00125
# HIS_Light_pc_M2: 0.00125
# HISTPRATPHYD-RXN_Light_p_M2: 0.00125
# HISTIDPHOS-RXN_Light_p_M2: 0.00125
# HISTCYCLOHYD-RXN_Light_p_M2: 0.00125
# HISTAMINOTRANS-RXN_Light_p_M2: 0.00125
# GLUTAMIDOTRANS-RXN_Light_p_M2: 0.00125
# GDPKIN-RXN_Light_p_M2: 0.00125
# FUM_Light_pc_M2: 0.00125
# Arginine_Dark_biomass_M2: -0.00125
# ATPPHOSPHORIBOSYLTRANS-RXN_Light_p_M2: 0.00125
# ARG_LightDark_M2: 0.00125
# AMPSYN-RXN_Light_p_M2: 0.00125
# AICARTRANSFORM-RXN_Light_p_M2: 0.00125
# ADENYLOSUCCINATE-SYNTHASE-RXN_Light_p_M2: 0.00125
# PYRUVATE_Light_pc_M2: -0.00124999999999
# VAL_Dark_pc_M2: -0.0009375
# RXN-8991_Dark_p_M2: 0.0009375
# RXN-7800_Dark_p_M2: 0.0009375
# PYRUVDEH-RXN_Dark_p_M2: 0.0009375
# Leucine_Dark_biomass_M2: -0.0009375
# LEU_Dark_pc_M2: 0.0009375
# Isoleucine_Dark_biomass_M2: -0.0009375
# ILE_LightDark_M2: 0.0009375
# Histidine_Light_biomass_M2: -0.0009375
# Histidine_Light_biomass_M1: -0.0009375
# Histidine_Dark_biomass_M1: -0.0009375
# HIS_LightDark_M1: 0.0009375
# BRANCHED-CHAINAMINOTRANSFERVAL-RXN_Dark_p_M2: 0.0009375
# BRANCHED-CHAINAMINOTRANSFERLEU-RXN_Dark_p_M2: -0.0009375
# 3-ISOPROPYLMALISOM-RXN_Dark_p_M2: 0.0009375
# 3-ISOPROPYLMALDEHYDROG-RXN_Dark_p_M2: 0.0009375
# 2-ISOPROPYLMALATESYN-RXN_Dark_p_M2: 0.0009375
# RXN-5682_Light_p_M1: 0.0009375
# Phenylalanine_Dark_biomass_M2: -0.000859375
# PHE_LightDark_M2: 0.000859375
# Tryptophan_Dark_biomass_M2: -0.000703125
# TRP_LightDark_M2: 0.000703125
# Methionine_Dark_biomass_M2: -0.000546875
# MET_LightDark_M2: 0.000546875
# Glycine_Dark_biomass_M2: -0.000546875
# Tyrosine_Dark_biomass_M2: -0.00046875
# TYR_LightDark_M2: 0.00046875
# HIS_LightDark_M2: 0.0003125
# Histidine_Dark_biomass_M2: -0.0003125

# %%
m1m2.PrintSol('Sucrose_Light_biomass_M2')
# Out:
# Sucrose_Light_biomass_M2: -0.515625

# %%
m1m2.PrintReactions('Sucrose_Light_biomass_M2')
m1m2.PrintReactions('Glycine_Light_biomass_M2')
# Out:
# Sucrose_Light_biomass_M2	 <-- Phloem-loading-cost_Light_c_M2 + SUCROSE_Light_c_M2
# Glycine_Light_biomass_M2	 <-- GLY_Light_c_M2 + Phloem-loading-cost_Light_c_M2

# %% [markdown]
# ## Adding/Deleting reactions (should usually be commented out)

# %%
# AA_met = ['GLY','GLN','MET','LEU','HIS','VAL','ILE',
#          'L-ALPHA-ALANINE','L-ASPARTATE','SER','TYR','LYS','PHE',
#          'ARG','TRP','GLT','ASN','THR']

# #transport AA from M1 to M2 LIGHT
# for met in AA_met:
#     m1m2.AddReaction(met+'_Light_M1M2',{met+'_Light_c_M1':-1,met+'_Light_c_M2':1},True)

# #transport AA from M1 to M2 DARK
# for met in AA_met:
#     m1m2.AddReaction(met+'_Dark_M1M2',{met+'_Dark_c_M1':-1,met+'_Dark_c_M2':1},True)

# m1m2.PrintReaction('GLN_Light_M1M2')
# m1m2.PrintReaction('GLN_Dark_M1M2')
# m1m2.PrintReaction('Sucrose_Light_M1M2')

# %%
## # m1m2.WriteModel('AraLightDarkCore_DbMesophyll_v1.xls', 'excel')
# m1m2.WriteModel('AraLightDarkCore_DbMesophyll_v3.xls', 'excel')
