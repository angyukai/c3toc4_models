# %%
import fluxtools.sbml_interface as si
import fluxtools.nlcm as nlcm
import fluxtools.reaction_networks as rn
from fluxtools.functions import Linear
from fluxtools.nlcm import NonlinearNetworkModel
from fluxtools import simplification

# m = si.fromSBMLFile('AraLightDarkCore_NADPME_v4-3.xml')

# %%
corn_net = si.fromSBMLFile('s3-model.XML')
reactions = corn_net.reactions.copy()
reaction_ids = reactions.keys()
reaction

# %%
reaction_ids

# %%
co2_scaling_factor =  0.001 # internal co2 units per microbar
o2_scaling_factor = 1e-4 # internal o2 units per microbar

####################################################################
# I. Import the SBML model as a SloppyCell network, and identify
# various components

corn_net = si.fromSBMLFile('s3-model.XML')
reactions = corn_net.reactions.copy()
reaction_ids = reactions.keys()
exchanges = [r for r in reaction_ids if 'sink' in r or 'tx' in r]

# At one time we relaxed the assumption of conservation of 
# cytosolic water and protons, but this is no longer necessary
nonconserved_ids = []

# For later reference, list parameters that need to be specified
all_parameters = ['bs_CO2_conductivity',
                  'rubisco_kc',
                  'rubisco_ko',
                  'rubisco_vomax_vcmax_ratio',
                  'pepc_kc',
                  'ms_CO2', 
                  'ms_oxygen', 
                  'bs_oxygen']

# External partial pressures may be treated either as variables or parameters,
# here, use parameters for simplicity in setting up elastic band models.       
basic_parameters = {'ms_oxygen': 200000. * o2_scaling_factor,
                    'ms_oxygen_chloroplast': 200000. * o2_scaling_factor,
                    'ms_CO2': 300. * co2_scaling_factor,
                    'ms_CO2_chloroplast': 300. * co2_scaling_factor
                    }

# Fix the kinetic parameters. Note these are currently treated as
# (usually fixed) variables, not hardwired parameters, because we
# might eventually allow them to take values within feasible ranges.

# In the following, the units are:
# bs_CO2_conductivity: flux units/ubar * (ubar/internal co2 unit) 
# bs_O2_conductivity: flux units/ubar * (ubar/internal O2 unit) 
# rubisco_kc: ubar * (internal co2 unit/ubar)
# rubisco_ko: ubar * (internal o2 unit/ubar)
# rubisco_vomax_vcmax_ratio: dimensionless
# pepc_kc: ubar * (internal co2 unit/ubar)

default_kinetic_parameters = {'bs_CO2_conductivity': 1.03e-3/co2_scaling_factor, 
                              'bs_O2_conductivity': 0.047*1.03e-3/o2_scaling_factor,
                              'rubisco_kc': 650. * co2_scaling_factor,
                              'rubisco_ko': 450000. * o2_scaling_factor,
                              'rubisco_vomax_vcmax_ratio': 0.2673, 
                              # (ko/(kc*S))       
                              'pepc_kc': 80. * co2_scaling_factor
                              }

default_max_light = 550. # uE m^{-2} s^{-1}

# %%
import fluxtools.reaction_networks as rn
stoichiometries = {'tx_A': {'A_ext': -1., 'A': 1.},
#                    'tx_B':{'B_ext':-1.,'B':1},
                   'R1': {'A': -1, 'B': 1},
                   'R2': {'A': -1, 'C': 1},
                   'R3': {'B': -1, 'D': 1},
                   'R4': {'C': -1, 'D': 1},
#                    'R5': {'C': -1, 'E': 1},
                   'sink1': {'D': -1},
                
                  }
net = rn.net_from_dict(stoichiometries)

from fluxtools.nlcm import NonlinearNetworkModel
model = NonlinearNetworkModel('example', net,
                              external_species_ids=('A_ext'))
model.set_objective('max_sink', '-1.0*sink1')
model.add_constraint('quadratic', 'R2/R1', 0.)
model.compile() 
model.set_bound('R1', (0., 3.))

model.compile() 
model.solve()

for i in stoichiometries:
    print i, model.soln[i]

# %%
## import fluxtools.reaction_networks as rn
stoichiometries = {'tx_A': {'A_ext': -1., 'A': 1.},
                   'tx_D':{'D_ext':-1.,'D':1.},
                   'tx_F':{'F_ext':-1.,'F':1.},
                   'R1':{'A': -1., 'B': 1},
                   'R2':{'B': -1., 'D':-1., 'E': 1.},
                   'R3':{'B': -1., 'F':-1., 'G': 1.},
                   'E_export': {'E': -1.},
                   'G_export': {'G': -1.},
                  }
                    
net = rn.net_from_dict(stoichiometries)

from fluxtools.nlcm import NonlinearNetworkModel
model = NonlinearNetworkModel('asdas', net, external_species_ids=('A_ext','D_ext','F_ext'))
model.set_objective('max_E_export', '-1.0*E_export')

model.add_constraint('R2_relationship', 'R2*tx_F - R3*tx_D', 0.)
# model.set_upper_bound('tx_a',100)
model.set_bound('tx_A', (0,1000))
model.set_bound('tx_D', (0.,100.))
model.set_bound('tx_F', (0,100))
model.set_bound('G_export',(0,100))
model.set_bound('E_export',(0,1000))
model.set_bound('R1',(0,1000))
model.set_bound('R2',(0,1000))
model.set_bound('R3',(0,1000))
# model.set_bound('R3',(0,0))
# model.set_bound('E_export',(0,))
# model.add_constraint('quadratic', 'R2-R3**2', 0.)
model.compile() 
model.solve()


model_list = ['tx_A','tx_D','tx_F','R1','R2','R3','E_export','G_export']
for i in model_list:
    print i, model.soln[i]
print type(model)
# Out:
# ---------------------------------------------------------------------------
# OptimizationFailure                       Traceback (most recent call last)
# <ipython-input-351-5bb45d1967c0> in <module>()
#      30 # model.add_constraint('quadratic', 'R2-R3**2', 0.)
#      31 model.compile()
# ---> 32 model.solve()
#      33
#      34
#
# /Users/yukai/anaconda2/lib/python2.7/site-packages/fluxtools/nlcm.pyc in solve(self, x0, options)
#     898
#     899         if self.status not in (0, 1):
# --> 900             raise OptimizationFailure('IPOPT exited with status %d' % self.status)
#     901
#     902         return self.x.copy()
#
# OptimizationFailure: IPOPT exited with status -2

# %%
simple_model, details = simplification.simplify(model)
# simple_model[0].compile()
simple_model.set_bound('tx_F',(50,50))
simple_model.set_bound('tx_D',(30,30))
# simple_model.set_bound('tx_A',(20,20))
simple_model.solve()
simple_model.soln
# simple_model[0].soln['R1']
# model_list = ['tx_A','tx_D','tx_F','R1','R2','R3','E_export','G_export']
# for i in model_list:
#     simple_model[0].soln[i]
# Out:
# {'E_export': 30.000000024884276,
#  'G_export': 50.00000000017863,
#  'R1': 80.000000025062903,
#  'R2': 30.000000024884276,
#  'R3': 50.00000000017863,
#  'tx_A': 80.000000025062903,
#  'tx_D': 30.0,
#  'tx_F': 50.0}

# %%
""" Test simplification based on linear subproblems. """ 

import numpy as np
import fluxtools.simplification as s
import fluxtools.nlcm as nlcm
import fluxtools.reaction_networks as rn

test_network = {'tx_A': {'A': 1},
                'R1': {'A': -1, 'B': 1, 'F': 1},
                'R3': {'F': -1, 'B': -1, 'C': 1},
                'R2': {'A': -1, 'F': 1, 'G': 1},
                'sink': {'F': -1, 'G': -1}}
test_network = rn.net_from_dict(test_network)
full_model = nlcm.NonlinearNetworkModel('simple_yet_problematic', 
                                        test_network)
full_model.add_constraint('equal_squares_0', 'R1**2 - R3**2', 0.)
full_model.add_constraint('equal_squares_1', 
                          'R1**2 - extra_var0**2 - extra_var1**2', 0.)
full_model.set_objective('max_tx_A', '-1.0*tx_A')
full_model.compile()
full_model.set_bounds({'tx_A': (0., 1000.),
                       'R1': (-1000., 1000.),
                       'R3': (-1000., 1000.),
                       'R2': (-1000., 1000.),
                       'sink': (0., 1000.),
                       'extra_var0': (-5., 5.),
                       'extra_var1': (-5., 5.)})
# Note extra_var1 is just there to ensure the number of
# variables is greater than the number of equality
# constraints.

# What should happen when this network is simplified:
# Reactions R1 and R3 are blocked because only R3
# produces/consumes metabolite C; their values should be fixed
# to zero. Constraints _conservation_B and equal_squares_0
# involve only R1 and R3, so they should be dropped from the
# problem. R3 participates in no other constraints and should
# be dropped from the problem in turn; R1 participates in
# equal_squares_1 and should be made a parameter with value 0.
#
# With R1 and R3 eliminated, the constraints conserving F and
# G become redundant, and one or the other should be
# eliminated.
#
# Finally, the variable bounds on tx_A and sink are mutually
# redundant, and one or the other should be relaxed; R2 is
# redundant given the remaining tx_A/sink constraint and it
# should be relaxed too.


simplified_model, details = s.simplify(full_model)

assert simplified_model.parameters['R1'] == 0.
assert 'R3' not in simplified_model.variables
assert 'R3' not in simplified_model.parameters
assert '_conservation_B' not in simplified_model.constraints.keys()
assert '_conservation_A' in simplified_model.constraints.keys()
assert 'equal_squares_1' in simplified_model.constraints.keys()
assert 'equal_squares_0' not in simplified_model.constraints.keys()
assert len({'_conservation_F',
            '_conservation_G'}.intersection(simplified_model.constraints.keys())) == 1
assert simplified_model.get_bounds('R2') == (None, None)
# Out:
# ({'R1': 0.0, 'R3': 0.0},
#  ['tx_A', 'R2'],
#  {'R2': ((-1000.0, 1000.0), (0.0, 1000.0), True),
#   'sink': ((0.0, 1000.0), (None, None), False),
#   'tx_A': ((0.0, 1000.0), (0.0, 1000.0), True)},
#  ['_conservation_C', '_conservation_B', 'equal_squares_0'],
#  ['_conservation_F'])

# %%
full_model.solve()
# Out:
# array([  1.63089109e-17,   1.00000000e+03,  -1.06242767e-19,
#          6.94358043e-05,   6.94358043e-05,   1.00000000e+03,
#          1.00000000e+03])

# %%
simplified_model.solve()
# Out:
# array([  1.00000001e+03,   6.30113992e-05,   6.30113992e-05,
#          1.00000000e+03,   1.00000001e+03])

# %%
testnet = si.fromSBMLFile('conversion-test2.xml')
reactions = testnet.reactions.copy()
reaction_ids = reactions.keys()
reaction_ids

# %%
testmodel = NonlinearNetworkModel('example', testnet)
testmodel.set_objective('max_R_Sucrose_Light_biomass_M2', 'R_Sucrose_Light_biomass_M2')
testmodel.add_constraint('Photons', 'R_Photojssan_Light_tx_M1/R_Photon_Light_tx_M2', 1)
testmodel.set_bound('R_Photonhsdja_Dark_tx_M1',(0,0))
testmodel.set_bound('R_Photon_Dark_tx_M2',(0,0))
testmodel.set_bound('R_Photon_Light_tx_M1',(0,1000))
testmodel.set_bound('R_Photon_Light_tx_M2',(0,1000))

testmodel.compile()
testmodel.solve()

# %%
import fluxtools.nlcm as nlcm
import fluxtools.reaction_networks as rn

test_network_raw = {'tx_A': {'A': 1},
                'R1': {'A': -1, 'B': 1, 'F': 1},
                'R3': {'F': -1, 'B': -1, 'C': 1},
                'R2': {'A': -1, 'F': 1, 'G': 1},
                'sink': {'F': -1, 'G': -1}}
test_network = rn.net_from_dict(test_network_raw)
full_model = nlcm.NonlinearNetworkModel('simple_yet_problematic', test_network)
full_model.add_constraint('equal_squares_0', 'R1**2 - R3**2', 0.)
full_model.add_constraint('equal_squares_1', 'R1**2 - extra_var0**2 - extra_var1**2', 0.)
full_model.set_objective('max_tx_A', '-1.0*tx_A')
full_model.compile()
full_model.set_bounds({'tx_A': (0., 60.),
                       'R1': (-1000., 1000.),
                       'R3': (-1000., 1000.),
                       'R2': (-1000., 1000.),
                       'sink': (60., 60.),
                       'extra_var0': (0., 50.),
                       'extra_var1': (0., 50.)})

full_model.solve()
for i in test_network_raw:
    print i, model.soln[i]

# %%
corn_net = si.fromSBMLFile('s3-model.XML')
reactions = corn_net.reactions.copy()
reaction_ids = reactions.keys()
# reaction_ids

# %%
net = NonlinearNetworkModel('example', corn_net)
s3model = nlcm.NonlinearNetworkModel('bla', net)
s3model.set_objective('CO2_consumption','-1.0*ms_tx_CARBON_DIOXIDE')
s3model.add_constraint('CO2_leakiness_constraint', 'ms_tx_CARBON_DIOXIDE-ms_tx_OXYGEN_MOLECULE**2',0.)


s3model.compile()
s3model.solve()

print 'CO2', s3model.soln['ms_tx_CARBON_DIOXIDE']
print 'O2', s3model.soln['ms_tx_OXYGEN_MOLECULE']
print '\n'
for i in reaction_ids:
    print i, s3model.soln[i]
# Out:
# CO2 -1.57590140246e-15
# O2 3.54452979118e-11
#
#
# ms_ADENOSYLHOMOCYSTEINASE_RXN 0.201686680718
# bs_ADENOSYLHOMOCYSTEINASE_RXN 0.176586691035
# ms_sink_GLN 0.194668481513
# bs_sink_GLN -0.194668481513
# ms_RXN_11654 0.0164239008899
# bs_RXN_11654 -0.0164239008896
# ms_sink_LINOLEIC_ACID 0.000206934751973
# bs_sink_LINOLEIC_ACID -0.000206934751995
# ms_PYRROLINECARBDEHYDROG_RXN 0.734429270479
# bs_PYRROLINECARBDEHYDROG_RXN 0.77934717832
# ms_sink_GLT 0.349475715621
# bs_sink_GLT -0.349475715621
# ms_PHOSPHOGLUCMUT_RXN_chloroplast -0.0243686872201
# bs_PHOSPHOGLUCMUT_RXN_chloroplast 0.0243686872201
# ms_AIRCARBOXY_RXN -0.0100768741323
# bs_AIRCARBOXY_RXN 0.0100768741321
# ms_sink_GLY 0.317470917101
# bs_sink_GLY -0.317470917101
# ms_RXN_6161 -0.196972977974
# bs_RXN_6161 -0.233954315654
# ms_CarbohydratesSink 0.00897486767927
# bs_CarbohydratesSink -0.00897486767733
# ms_peroxisome_glycolate_exchange -0.247985111091
# bs_peroxisome_glycolate_exchange -0.265662703044
# ms_sink_CPD_13612 -0.0743108192148
# bs_sink_CPD_13612 0.0743108192147
# ms__6PGLUCONOLACT_RXN -0.173715167171
# bs__6PGLUCONOLACT_RXN -0.0900775654847
# ms_tx_OXYGEN_MOLECULE 3.54452979118e-11
# ms_ETHANOLAMINE_KINASE_RXN -0.00904043957899
# bs_ETHANOLAMINE_KINASE_RXN 0.00904043957875
# ms_RXN_1685 0.116593019978
# bs_RXN_1685 0.184086020425
# ms_AICARSYN_RXN -0.0100768741323
# bs_AICARSYN_RXN 0.0100768741321
# ms_SUCCCOASYN_RXN_mitochondrion -0.218046801746
# bs_SUCCCOASYN_RXN_mitochondrion -0.227369793352
# ms_GLUTAMATE_SYNTHASE_NADH_RXN 0.459747109461
# bs_GLUTAMATE_SYNTHASE_NADH_RXN 0.51034342084
# ms_MALATE_DEH_RXN_peroxisome 0.13371078988
# bs_MALATE_DEH_RXN_peroxisome 0.119006631398
# ms_TRIOSEPISOMERIZATION_RXN -0.0352114867116
# bs_TRIOSEPISOMERIZATION_RXN 0.0975530542502
# ms_CytochromeBF6Complex_mod_chloroplast 0.237648300111
# bs_CytochromeBF6Complex_mod_chloroplast 0.235246717348
# ms_sink_MET -0.038704430739
# bs_sink_MET 0.038704430739
# ms_GenericNADPOxidase_mod -0.39253773268
# bs_GenericNADPOxidase_mod -0.168831112619
# ms_sink_PRO -0.00193632232772
# bs_sink_PRO 0.00193632232771
# ms_PHOSPHASERDECARB_RXN 0.330843565482
# bs_PHOSPHASERDECARB_RXN 0.335823959965
# ms_PRAISOM_RXN -0.0630577920964
# bs_PRAISOM_RXN 0.0630577920963
# ms_GABATRANSAM_RXN -0.346421268628
# bs_GABATRANSAM_RXN -0.387393143865
# ms_N_ACETYLGLUTPREDUCT_RXN 0.694985787331
# bs_N_ACETYLGLUTPREDUCT_RXN 0.666821574089
# ms_FARNESYLTRANSTRANSFERASE_RXN -0.0117533135375
# bs_FARNESYLTRANSTRANSFERASE_RXN 0.0117533135371
# ms_FERREDOXIN__NITRITE_REDUCTASE_RXN 0.0180471683568
# bs_FERREDOXIN__NITRITE_REDUCTASE_RXN -0.0180471683569
# ms_RXN_11501 0.482546550072
# bs_RXN_11501 0.479659758141
# ms_TYRAMINE_N_FERULOYLTRANSFERASE_RXN -0.0620003561423
# bs_TYRAMINE_N_FERULOYLTRANSFERASE_RXN 0.0620003561422
# ms_SAICARSYN_RXN -0.0100768741323
# bs_SAICARSYN_RXN 0.0100768741321
# ms_RXN_961_chloroplast -0.291837073472
# bs_RXN_961_chloroplast -0.221810740662
# ms_PHOSMANMUT_RXN 0.712012110803
# bs_PHOSMANMUT_RXN 0.643197983995
# ms_chloroplast_CO2_exchange 0.0699443009761
# bs_chloroplast_CO2_exchange 0.0110618840744
# ms_SHIKIMATE_KINASE_RXN -0.0700924105047
# bs_SHIKIMATE_KINASE_RXN 0.0700924105055
# ms_PGPPHOSPHA_RXN 0.0111998419506
# bs_PGPPHOSPHA_RXN -0.0111998419507
# ms_RXN0_6491_mod_mitochondrion -0.0100707362757
# bs_RXN0_6491_mod_mitochondrion 0.0100707362759
# ms_chloroplast_light_exchange 0.0016965113947
# ms_peroxisome_water_exchange 0.247985111091
# bs_peroxisome_water_exchange 0.265662703044
# ms_mitochondrion_succinate_exchange 0.641013526604
# bs_mitochondrion_succinate_exchange 0.610407658331
# ms_RXN_5682 0.0375908712617
# bs_RXN_5682 -0.0375908712617
# ms_RXN0_1132_mitochondrion 0.48310275339
# bs_RXN0_1132_mitochondrion 0.479017229984
# ms_mitochondrion_oxoglutarate_exchange 0.24471617729
# bs_mitochondrion_oxoglutarate_exchange 0.221627621415
# ms_sink_Homogalacturonan_monomer_equivalent 0.0338233976413
# bs_sink_Homogalacturonan_monomer_equivalent -0.0338233976413
# ms_ARGINASE_RXN -0.0527246039028
# bs_ARGINASE_RXN 0.0447044304138
# ms_ALDOSE1EPIM_RXN 0.660278235391
# bs_ALDOSE1EPIM_RXN 0.694931859407
# ms_GLUTSEMIALDEHYDROG_RXN 0.0831685605493
# bs_GLUTSEMIALDEHYDROG_RXN 0.0688005268291
# ms_SEDOBISALDOL_RXN_chloroplast -0.00932625660558
# bs_SEDOBISALDOL_RXN_chloroplast 0.00903594357982
# ms_XyloglucanSynthesis_mod -0.00914868210478
# bs_XyloglucanSynthesis_mod 0.00914868210479
# ms_HOMOSERDEHYDROG_RXN_HOMO_SER_NAD__L_ASPARTATE_SEMIALDEHYDE_NADH_PROTON_51_ 0.293894846314
# bs_HOMOSERDEHYDROG_RXN_HOMO_SER_NAD__L_ASPARTATE_SEMIALDEHYDE_NADH_PROTON_51_ 0.267474180008
# ms_PEPCARBOX_RXN 0.369378798168
# bs_PEPCARBOX_RXN 0.281718540988
# ms_LigninSink 0.00127077772445
# bs_LigninSink -0.00127077772427
# bs_tx_MG_2 -5.54346631113e-14
# ms_sink_COUMARYL_ALCOHOL -0.0225766542448
# bs_sink_COUMARYL_ALCOHOL 0.0225766542448
# ms_EC_3_5_2_9 -0.331876225947
# bs_EC_3_5_2_9 -0.327452544584
# ms_RXN_12200 -0.304485344638
# bs_RXN_12200 -0.265765972254
# ms_SERINE_GLYOXYLATE_AMINOTRANSFERASE_RXN_peroxisome 0.13371078988
# bs_SERINE_GLYOXYLATE_AMINOTRANSFERASE_RXN_peroxisome 0.119006631398
# ms_METHIONINE_S_METHYLTRANSFERASE_RXN 0.181258366662
# bs_METHIONINE_S_METHYLTRANSFERASE_RXN 0.197015005091
# ms_RXN_9633 -0.0114857046119
# bs_RXN_9633 0.0114857046097
# ms_EC_2_7_1_90 1.14671914958
# bs_EC_2_7_1_90 1.22912136493
# ms_RXN_9635 -0.0114857046118
# bs_RXN_9635 0.0114857046097
# ms_RXN_9634 -0.0114857046119
# bs_RXN_9634 0.0114857046097
# bs_tx_GLT -2.11624205287e-16
# ms_MYO_INOSITOL_1_KINASE_RXN 0.0826803729361
# bs_MYO_INOSITOL_1_KINASE_RXN 0.14443385006
# ms_XyloseTransfer_mod 0.00448025394551
# bs_XyloseTransfer_mod -0.0044802539445
# ms_RXN_821_mod 1.14311472246
# bs_RXN_821_mod 1.14930610396
# ms_Glycerol3POAcyltransferase_mod -0.000943316407986
# bs_Glycerol3POAcyltransferase_mod 0.000943316406607
# ms_LinolenoylLipase_mod -0.0126104329681
# bs_LinolenoylLipase_mod 0.0126104329679
# ms_SERINE_C_PALMITOYLTRANSFERASE_RXN 0.0468530101029
# bs_SERINE_C_PALMITOYLTRANSFERASE_RXN -0.0468530101032
# bs_tx_GLY -2.01370325955e-16
# ms_RXN0_366 0.000601316134515
# bs_RXN0_366 -0.000601316134377
# ms_SHIKIMATE_5_DEHYDROGENASE_RXN -0.0700924105048
# bs_SHIKIMATE_5_DEHYDROGENASE_RXN 0.0700924105055
# ms_EC_2_3_1_180 -0.000735648301452
# bs_EC_2_3_1_180 0.000735648297566
# bs_tx_ILE 5.7280292932e-15
# ms_CMPKI_RXN -0.263224832078
# bs_CMPKI_RXN -0.235712014247
# ms_chloroplast_glycolate_glycerate_exchange 0.156654539189
# bs_chloroplast_glycolate_glycerate_exchange 0.096062882089
# ms_IPPISOM_RXN 0.494666825844
# bs_IPPISOM_RXN 0.487504420155
# ms_PRTRANS_RXN -0.0630577920964
# bs_PRTRANS_RXN 0.0630577920963
# ms_sink_VAL 0.0327317184199
# bs_sink_VAL -0.0327317184199
# ms_ISOCIT_CLEAV_RXN 0.496840218887
# bs_ISOCIT_CLEAV_RXN 0.465076970398
# ms_MehlerReaction_chloroplast -0.0726551159465
# bs_MehlerReaction_chloroplast -0.0753555547166
# ms_PYRUVATEORTHOPHOSPHATE_DIKINASE_RXN_chloroplast -0.0165022028468
# bs_PYRUVATEORTHOPHOSPHATE_DIKINASE_RXN_chloroplast 0.00014284736831
# ms_DXS_RXN -0.00217386305365
# bs_DXS_RXN 0.0734883336225
# ms_ACETOLACTREDUCTOISOM_RXN 0.0504323106255
# bs_ACETOLACTREDUCTOISOM_RXN -0.0504323106244
# ms_RNAPolymerase_mod 0.0111366130813
# bs_RNAPolymerase_mod -0.0111366130813
# ms_DUTP_PYROP_RXN -0.0162008072234
# bs_DUTP_PYROP_RXN 0.0162008072234
# ms_MDHFerredoxinReduction_chloroplast -0.548052517077
# bs_MDHFerredoxinReduction_chloroplast -0.547459263213
# ms_sink__L_1_phosphatidyl_inositols_ 0.0404909654554
# bs_sink__L_1_phosphatidyl_inositols_ -0.0404909654554
# ms_GLUTDECARBOX_RXN 0.144173307717
# bs_GLUTDECARBOX_RXN 0.145330687933
# bs_tx_L_ASPARTATE -1.69397243409e-15
# ms_PYRROLINECARBREDUCT_RXN_PRO_NAD__L_DELTA1_PYRROLINE_5_CARBOXYLATE_NADH_PROTON_54_ 0.856885277544
# bs_PYRROLINECARBREDUCT_RXN_PRO_NAD__L_DELTA1_PYRROLINE_5_CARBOXYLATE_NADH_PROTON_54_ 0.85069389604
# ms_ACYLCOASYN_RXN_DODECANOATE_CO_A_ATP__LAUROYLCOA_CPD_PPI_AMP_45_ -0.118096676656
# bs_ACYLCOASYN_RXN_DODECANOATE_CO_A_ATP__LAUROYLCOA_CPD_PPI_AMP_45_ -0.144345371968
# ms_HISTIDPHOS_RXN -0.0129482508621
# bs_HISTIDPHOS_RXN 0.0129482508622
# ms_PRIBFAICARPISOM_RXN -0.0129482508622
# bs_PRIBFAICARPISOM_RXN 0.0129482508621
# ms_GLYOHMETRANS_RXN -0.0670516884747
# bs_GLYOHMETRANS_RXN 0.0670516884741
# ms_sink_OCTADEC_9_ENE_118_DIOIC_ACID 0.0400880591556
# bs_sink_OCTADEC_9_ENE_118_DIOIC_ACID -0.0400880591556
# ms_chloroplast_proton_exchange 0.490903184847
# bs_chloroplast_proton_exchange 0.403868857708
# ms_MALONYL_COA_ACP_TRANSACYL_RXN 0.32607176376
# bs_MALONYL_COA_ACP_TRANSACYL_RXN 0.340594049904
# ms_EC_3_1_3_25 0.123171338391
# bs_EC_3_1_3_25 0.103942884605
# ms_sink_1_4_alpha_D_Glucan_monomer_equivalent_chloroplast 0.0162457914687
# bs_sink_1_4_alpha_D_Glucan_monomer_equivalent_chloroplast -0.0162457914687
# bs_tx_THR 4.7669637286e-16
# ms_ACONITATEHYDR_RXN_mitochondrion 0.419940441698
# bs_ACONITATEHYDR_RXN_mitochondrion 0.386064148137
# ms_sink_TYR 0.098703503386
# bs_sink_TYR -0.098703503386
# ms_MYO_INOSITOL_1_PHOSPHATE_SYNTHASE_RXN_beta 0.217179304982
# bs_MYO_INOSITOL_1_PHOSPHATE_SYNTHASE_RXN_beta 0.146393523413
# ms_NucleicAcidSink 0.000109604578743
# bs_NucleicAcidSink -0.000109604578709
# ms_DNAPolymerase_mod -0.0162291948093
# bs_DNAPolymerase_mod 0.0162291948093
# ms_GammaGlutamyltransferase_mod -0.331876225947
# bs_GammaGlutamyltransferase_mod -0.327452544584
# ms_ArabinoseTransfer_mod 0.00196729099531
# bs_ArabinoseTransfer_mod -0.00196729099486
# ms_SEDOHEPTULOSE_BISPHOSPHATASE_RXN_chloroplast -0.00932625660558
# bs_SEDOHEPTULOSE_BISPHOSPHATASE_RXN_chloroplast 0.00903594357982
# ms_sink_Arabinoxylan_monomer_equivalent -0.0238558181853
# bs_sink_Arabinoxylan_monomer_equivalent 0.0238558181853
# ms__2TRANSKETO_RXN 0.0206739970235
# bs__2TRANSKETO_RXN -0.108604907909
# ms_sink_RNA_base_equivalent 0.0445464523251
# bs_sink_RNA_base_equivalent -0.0445464523251
# ms_sink_SINAPYL_ALCOHOL 0.0504229765427
# bs_sink_SINAPYL_ALCOHOL -0.0504229765427
# ms_PHOSPHOGLUCMUT_RXN 0.481651558455
# bs_PHOSPHOGLUCMUT_RXN 0.572879495931
# ms_GlucoseTransfer_mod 0.0116816877714
# bs_GlucoseTransfer_mod -0.0116816877688
# ms_MANNPISOM_RXN 0.712362130643
# bs_MANNPISOM_RXN 0.642847964156
# ms_mitochondrion_fumarate_exchange 0.300549234614
# bs_mitochondrion_fumarate_exchange 0.402770553469
# ms_MALATE_DEH_RXN 0.47449617257
# bs_MALATE_DEH_RXN 0.457694634258
# ms_sink_LYS 0.00353554058973
# bs_sink_LYS -0.00353554058974
# ms_MALIC_NADP_RXN 0.19946304171
# bs_MALIC_NADP_RXN 0.273540620145
# ms_NitrogenousBiomassSink 0.0036534859579
# bs_NitrogenousBiomassSink -0.00365348595717
# ms_MALATE_DEH_RXN_mitochondrion 0.291752344009
# ms_MYO_INOSITOL_1_PHOSPHATE_SYNTHASE_RXN_alpha -0.176688339527
# bs_MYO_INOSITOL_1_PHOSPHATE_SYNTHASE_RXN_alpha -0.186884488868
# ms_GlucomannanSynthase_mod 0.0352477434806
# bs_GlucomannanSynthase_mod -0.0352477434806
# ms_ALANINE__GLYOXYLATE_AMINOTRANSFERASE_RXN 0.369268986498
# bs_ALANINE__GLYOXYLATE_AMINOTRANSFERASE_RXN 0.411182242157
# ms_sink_PHOSPHATIDYLCHOLINE -0.00904043957889
# bs_sink_PHOSPHATIDYLCHOLINE 0.00904043957884
# ms_RXN0_1134_mitochondrion 0.48310275339
# bs_RXN0_1134_mitochondrion 0.479017229984
# ms_mitochondrion_pyruvate_exchange 0.48310275339
# bs_mitochondrion_pyruvate_exchange 0.479017229984
# ms_GLU6PDEHYDROG_RXN -0.173715167171
# bs_GLU6PDEHYDROG_RXN -0.0900775654846
# ms_chloroplast_glycolate_exchange -0.291837073472
# bs_chloroplast_glycolate_exchange -0.221810740662
# ms_CTPSYN_RXN -0.00503482011505
# bs_CTPSYN_RXN 0.00503482011499
# ms_sink_CELLULOSE_monomer_equivalent 0.0246190441974
# bs_sink_CELLULOSE_monomer_equivalent -0.0246190441974
# ms_chloroplast_TPT_G3P_exchange -0.410361314294
# bs_chloroplast_TPT_G3P_exchange -0.370720521011
# ms_RXN3O_1380 0.0742474889784
# bs_RXN3O_1380 -0.0742474889785
# ms_RXN0_2382 -0.0630577920964
# bs_RXN0_2382 0.0630577920963
# ms_RXN0_2381 -0.0630577920964
# bs_RXN0_2381 0.0630577920963
# ms_RXN_1461 0.116593019978
# bs_RXN_1461 0.184086020425
# ms_CDPKIN_RXN -0.0205868251789
# bs_CDPKIN_RXN -0.00176720047904
# ms_RXN0_1461 -0.0117533135375
# bs_RXN0_1461 0.0117533135371
# bs_tx_HIS 8.77438195163e-15
# ms_sink_TRP -0.0631701671135
# bs_sink_TRP 0.0631701671135
# ms_sink_CYS 0.344098313325
# bs_sink_CYS -0.344098313325
# ms_PGLUCISOM_RXN 0.562668213955
# bs_PGLUCISOM_RXN 0.610406029791
# ms_TotalBiomassSink 0.0158847215562
# bs_TotalBiomassSink -0.0158847215528
# ms_HOMOSERKIN_RXN 0.0177957984471
# bs_HOMOSERKIN_RXN -0.0177957984467
# ms_ADENYLOSUCCINATE_SYNTHASE_RXN 0.320287818272
# bs_ADENYLOSUCCINATE_SYNTHASE_RXN 0.3910521433
# ms_EC_1_2_1_9 -0.0775939063709
# bs_EC_1_2_1_9 -0.0623436190413
# ms_peroxisome_OAA_MAL_exchange 0.13371078988
# bs_peroxisome_OAA_MAL_exchange 0.119006631398
# ms_PGLYCDEHYDROG_RXN 0.134181872781
# bs_PGLYCDEHYDROG_RXN 0.223125874213
# ms_TRANSALDOL_RXN -0.0494184134813
# bs_TRANSALDOL_RXN -0.0385124974038
# ms_RXN_13158 0.0167324184267
# bs_RXN_13158 -0.0167324184258
# ms_ACONITATEDEHYDR_RXN_mitochondrion 0.421309704696
# bs_ACONITATEDEHYDR_RXN_mitochondrion 0.384694885139
# ms_sink_amylopectin_monomer_equivalent_chloroplast 0.00812289575133
# bs_sink_amylopectin_monomer_equivalent_chloroplast -0.00812289575133
# ms_GLUTKIN_RXN 0.0831685605493
# bs_GLUTKIN_RXN 0.0688005268291
# bs_tx_SUCROSE -7.28743528157e-15
# ms_AscorbateProduction_mod_mitochondrion 0.014386012895
# bs_AscorbateProduction_mod_mitochondrion -0.0143860128949
# ms_RXN0_1133_mitochondrion 0.48310275339
# bs_RXN0_1133_mitochondrion 0.479017229984
# ms_sink_SULFOQUINOVOSYLDIACYLGLYCEROL 0.0148374703443
# bs_sink_SULFOQUINOVOSYLDIACYLGLYCEROL -0.0148374703443
# ms_RXN0_882 -0.00217386305368
# bs_RXN0_882 0.0734883336224
# ms_RXN_9550 8.18063159788e-05
# bs_RXN_9550 -8.18063160327e-05
# ms_mitochondrion_citrate_exchange -0.0617930486937
# bs_mitochondrion_citrate_exchange -0.094322344845
# ms_RXN_3523_chloroplast 0.237698700565
# bs_RXN_3523_chloroplast 0.236051854248
# ms_mitochondrion_oxaloacetate_exchange 0.191350409381
# bs_mitochondrion_oxaloacetate_exchange 0.157722502553
# ms_RXN_7666 -0.00990651793246
# bs_RXN_7666 0.00990699415389
# ms_peroxisome_glutamate_exchange -0.38169590097
# bs_peroxisome_glutamate_exchange -0.384669334442
# ms_RXN_7664 -0.0099065179325
# bs_RXN_7664 0.00990699415385
# ms_RXN_7665 -0.00990651793248
# bs_RXN_7665 0.00990699415387
# ms_EC_1_18_1_2_chloroplast 0.190798870388
# bs_EC_1_18_1_2_chloroplast 0.19692631385
# ms_RXN_7663 -0.00990651793253
# bs_RXN_7663 0.00990699415382
# ms_GLYCERATE_DEHYDROGENASE_RXN_peroxisome 0.13371078988
# bs_GLYCERATE_DEHYDROGENASE_RXN_peroxisome 0.119006631398
# ms_DIAMINOPIMEPIM_RXN 0.00367455455033
# bs_DIAMINOPIMEPIM_RXN -0.00367455455036
# ms_sink_DNA_base_equivalent -0.0649167792372
# bs_sink_DNA_base_equivalent 0.0649167792371
# ms_BRANCHED_CHAINAMINOTRANSFERLEU_RXN -0.0167324184267
# bs_BRANCHED_CHAINAMINOTRANSFERLEU_RXN 0.0167324184258
# ms_DAHPSYN_RXN -0.0700924105047
# bs_DAHPSYN_RXN 0.0700924105055
# ms_XylanSynthase_mod -0.0162324899042
# bs_XylanSynthase_mod 0.0162324899042
# ms_EC_2_4_1_123 0.482546550072
# bs_EC_2_4_1_123 0.479659758141
# ms_GLUTATHIONE_PEROXIDASE_RXN -0.525336488264
# bs_GLUTATHIONE_PEROXIDASE_RXN -0.514146383416
# ms_peroxisome_oxoglutarate_exchange 0.38169590097
# bs_peroxisome_oxoglutarate_exchange 0.384669334442
# ms_F16ALDOLASE_RXN -0.0281422344228
# bs_F16ALDOLASE_RXN 0.116073145296
# ms_METHYLENETHFDEHYDROG_NADP_RXN -0.0331019991269
# bs_METHYLENETHFDEHYDROG_NADP_RXN 0.0331019991264
# ms__6PFRUCTPHOS_RXN -0.484505053054
# bs__6PFRUCTPHOS_RXN -0.432335699517
# ms_CARBPSYN_RXN -0.146141248408
# bs_CARBPSYN_RXN -0.0318979350252
# ms_CHORISMATE_SYNTHASE_RXN -0.0700924105048
# bs_CHORISMATE_SYNTHASE_RXN 0.0700924105055
# ms_ADPREDUCT_RXN 0.0162012456417
# bs_ADPREDUCT_RXN -0.0162012456417
# ms_FGAMSYN_RXN -0.0100768741324
# bs_FGAMSYN_RXN 0.0100768741321
# ms_F16ALDOLASE_RXN_chloroplast -0.0150424306145
# bs_F16ALDOLASE_RXN_chloroplast 0.0153327436402
# ms_AMPSYN_RXN 0.320287818272
# bs_AMPSYN_RXN 0.3910521433
# ms_PRPPSYN_RXN -0.0955523372321
# bs_PRPPSYN_RXN 0.0955523372321
# ms_EC_2_5_1_19 -0.0700924105048
# bs_EC_2_5_1_19 0.0700924105055
# ms_EC_5_1_3_15 0.606132351766
# bs_EC_5_1_3_15 0.666721987719
# ms_PhotosystemI_mod_chloroplast 0.547951716168
# bs_PhotosystemI_mod_chloroplast 0.545848989413
# ms_DTMPKI_RXN -0.0162008072234
# bs_DTMPKI_RXN 0.0162008072234
# ms_S_ADENMETSYN_RXN 0.201686680718
# bs_S_ADENMETSYN_RXN 0.176586691035
# ms_PHOSPHASERSYN_RXN 0.000784007786793
# bs_PHOSPHASERSYN_RXN -0.000784007787005
# ms_ORNITHINE_GLU_AMINOTRANSFORASE_RXN 0.651922892954
# bs_ORNITHINE_GLU_AMINOTRANSFORASE_RXN 0.709884468467
# ms_GLYOHMETRANS_RXN_mitochondrion -0.0694779472565
# bs_GLYOHMETRANS_RXN_mitochondrion -0.0639237600036
# ms_ASPARTATEKIN_RXN 0.0214703529974
# bs_ASPARTATEKIN_RXN -0.0214703529971
# ms_ISPH2_RXN_DELTA3_ISOPENTENYL_PP_NADP_WATER__HYDROXY_METHYL_BUTENYL_DIP_NADPH_PROTON_74_ -0.0328737284669
# bs_ISPH2_RXN_DELTA3_ISOPENTENYL_PP_NADP_WATER__HYDROXY_METHYL_BUTENYL_DIP_NADPH_PROTON_74_ -0.00175237251881
# ms_chloroplast_water_exchange -0.280753849534
# bs_chloroplast_water_exchange -0.264610711066
# ms_UGD_RXN 0.0197642702349
# bs_UGD_RXN -0.0197642702324
# ms_UREASE_RXN -0.0527246039028
# bs_UREASE_RXN 0.0447044304138
# ms_ACETYL_COA_ACETYLTRANSFER_RXN -0.0448393910964
# bs_ACETYL_COA_ACETYLTRANSFER_RXN -0.026475079474
# ms_CAFFEOYL_COA_O_METHYLTRANSFERASE_RXN 0.122846642633
# bs_CAFFEOYL_COA_O_METHYLTRANSFERASE_RXN 0.112447897231
# ms_EC_5_1_1_18 0.0216799936753
# bs_EC_5_1_1_18 0.216312039302
# ms_RXN_1382 0.330059557695
# bs_RXN_1382 0.336607967752
# ms_mitochondrion_malate_exchange -0.431763615463
# bs_mitochondrion_malate_exchange -0.464513691017
# ms_PRPPAMIDOTRANS_RXN -0.0100768741323
# bs_PRPPAMIDOTRANS_RXN 0.0100768741321
# ms_RXN0_5224 0.206602307037
# bs_RXN0_5224 0.266455848655
# ms_sink_ARG 0.0426415268811
# bs_sink_ARG -0.0426415268811
# ms_EC_6_2_1_12 0.457904495741
# bs_EC_6_2_1_12 0.483272184117
# ms_EC_2_7_1_150 0.102925638332
# bs_EC_2_7_1_150 0.124188563291
# ms_RXN_9537 -0.000735648301529
# bs_RXN_9537 0.000735648297488
# ms_IMPCYCLOHYDROLASE_RXN -0.0230251249945
# bs_IMPCYCLOHYDROLASE_RXN 0.0230251249943
# ms_RXN_1063 0.0400880591556
# bs_RXN_1063 -0.0400880591557
# ms_EC_2_7_1_159 0.102925808732
# bs_EC_2_7_1_159 0.124188518229
# ms_SPONTPRO_RXN 0.735091453503
# bs_SPONTPRO_RXN 0.778684995296
# ms_RXN_9531 -0.000735648301543
# bs_RXN_9531 0.000735648297474
# ms_CDPREDUCT_RXN -0.0161998207822
# bs_CDPREDUCT_RXN 0.0161998207822
# ms_ALANINE_AMINOTRANSFERASE_RXN 0.16298415458
# bs_ALANINE_AMINOTRANSFERASE_RXN 0.0798830249069
# ms_DGDPKIN_RXN -0.0162021224783
# bs_DGDPKIN_RXN 0.0162021224783
# bs_tx_GLUTATHIONE 2.45330086329e-15
# ms_GDPKIN_RXN 1.04346273765
# bs_GDPKIN_RXN 1.02308731872
# ms_CITSYN_RXN_mitochondrion 0.48310275339
# bs_CITSYN_RXN_mitochondrion 0.479017229984
# ms_ACETATE__COA_LIGASE_RXN -0.337797864954
# bs_ACETATE__COA_LIGASE_RXN -0.340579664811
# ms_RXN_13191 -0.0117533135374
# bs_RXN_13191 0.0117533135372
# ms_UTPHEXPURIDYLYLTRANS_RXN 0.267999311302
# bs_UTPHEXPURIDYLYLTRANS_RXN 0.258767933263
# bs_tx_NITRATE -5.41404246202e-15
# ms_EC_1_1_1_39 -0.370532032946
# bs_EC_1_1_1_39 -0.279203482433
# bs_tx__Pi_ -6.52491793527e-15
# ms_OrganicAcidsSink 0.000794236077846
# bs_OrganicAcidsSink -0.000794236077605
# ms_EC_2_4_1_46 -0.0592151623658
# bs_EC_2_4_1_46 0.0592151623656
# ms_THYMIDYLATESYN_RXN -0.0162008072234
# bs_THYMIDYLATESYN_RXN 0.0162008072234
# ms_sink_SER 0.39027105611
# bs_sink_SER -0.39027105611
# ms_OXALATE_OXIDASE_RXN -0.373626311846
# bs_OXALATE_OXIDASE_RXN -0.378923132446
# ms_RIBULOSE_BISPHOSPHATE_CARBOXYLASE_RXN_chloroplast 0.263858303656
# bs_RIBULOSE_BISPHOSPHATE_CARBOXYLASE_RXN_chloroplast 0.248918571402
# ms_HemicelluloseSink 0.00358994707172
# bs_HemicelluloseSink -0.00358994707092
# ms_GLURS_RXN -0.0940265083008
# bs_GLURS_RXN 0.0940265082963
# ms_SPHINGANINE_KINASE_RXN 0.0469163403393
# bs_SPHINGANINE_KINASE_RXN -0.0469163403394
# ms_RXN_9663 -0.000735648301495
# bs_RXN_9663 0.000735648297522
# ms_sink_THR 0.0995739724346
# bs_sink_THR -0.0995739724346
# ms_ISPH2_RXN_DELTA3_ISOPENTENYL_PP_NAD_WATER__HYDROXY_METHYL_BUTENYL_DIP_NADH_PROTON_72_ 0.537120004794
# bs_RXN1F_10 0.0117533135372
# ms_GLUTRNAREDUCT_RXN -0.0940265083008
# bs_GLUTRNAREDUCT_RXN 0.0940265082963
# ms_IMIDPHOSDEHYD_RXN -0.0129482508622
# bs_IMIDPHOSDEHYD_RXN 0.0129482508621
# ms_DIHYDROXYISOVALDEHYDRAT_RXN 0.0504323106255
# bs_DIHYDROXYISOVALDEHYDRAT_RXN -0.0504323106244
# ms_RXN_7710_mod_chloroplast 0.00812289575133
# bs_RXN_7710_mod_chloroplast -0.00812289575133
# ms_mitochondrion_isocitrate_exchange -0.882703420734
# bs_mitochondrion_isocitrate_exchange -0.835061562904
# bs_tx_L_ALPHA_ALANINE 1.28097783879e-15
# ms_ComplexV_mod_mitochondrion 1.38046019868
# bs_ComplexV_mod_mitochondrion 1.40285489158
# ms_F16BDEPHOS_RXN 0.690356330949
# bs_F16BDEPHOS_RXN 0.680712520122
# ms_EC_6_3_4_16 0.126408802607
# bs_EC_6_3_4_16 0.0436102073379
# ms_SULFITE_REDUCTASE_FERREDOXIN_RXN -0.0331697609823
# bs_SULFITE_REDUCTASE_FERREDOXIN_RXN 0.0331697609823
# ms_DSERDEAM_RXN 0.0216799936753
# bs_DSERDEAM_RXN 0.216312039302
# ms_RXN0_302 -0.00217386305367
# bs_RXN0_302 0.0734883336224
# ms_RXN_9516 -0.000735648301492
# bs_RXN_9516 0.000735648297525
# ms_RXN_9514 -0.000735648301463
# bs_RXN_9514 0.000735648297555
# ms_MALIC_NADP_RXN_chloroplast 0.19391400268
# bs_MALIC_NADP_RXN_chloroplast 0.237856687327
# ms_RXN_9518 -0.0007356483015
# bs_RXN_9518 0.000735648297517
# ms_RXN_2122 0.0400880591556
# bs_RXN_2122 -0.0400880591557
# ms_mitochondrion_proton_exchange 0.728422443686
# bs_mitochondrion_proton_exchange 0.697715657668
# ms_RXN_2121 0.0400880591556
# bs_RXN_2121 -0.0400880591557
# ms_EC_4_2_1_59 -0.000735648301532
# bs_EC_4_2_1_59 0.000735648297486
# ms_GDPREDUCT_RXN 0.0162021224783
# bs_GDPREDUCT_RXN -0.0162021224783
# ms_chloroplast_malate_exchange 0.0290725889108
# bs_chloroplast_malate_exchange 0.0404943036181
# ms_CombinedBiomassReaction 0.0158847215562
# bs_CombinedBiomassReaction -0.0158847215528
# ms_MMUM_RXN 0.181258366662
# bs_MMUM_RXN 0.197015005091
# ms_ASPCARBTRANS_RXN -0.0100707362757
# bs_ASPCARBTRANS_RXN 0.0100707362759
# bs_tx_ASN 1.96120655988e-15
# ms_XylogalacturonanSynthesis_mod -0.00454649439446
# bs_XylogalacturonanSynthesis_mod 0.00454649439448
# bs_tx_PROTON -3.86559107294e-17
# ms_DTDPKIN_RXN -0.0162008072234
# bs_DTDPKIN_RXN 0.0162008072234
# ms_UDP_ARABINOSE_4_EPIMERASE_RXN -0.02188852719
# bs_UDP_ARABINOSE_4_EPIMERASE_RXN 0.0218885271904
# ms_SUPEROX_DISMUT_RXN_chloroplast -0.0363275579732
# bs_SUPEROX_DISMUT_RXN_chloroplast -0.0376777773583
# ms_ADENYL_KIN_RXN_chloroplast -0.0165022028468
# bs_ADENYL_KIN_RXN_chloroplast 0.000142847368308
# ms_chloroplast_oxaloacetate_exchange 0.164841413769
# bs_chloroplast_oxaloacetate_exchange 0.197362383709
# bs_tx_SULFATE -1.22891221694e-14
# ms_RXN1F_72 -0.0117533135374
# bs_RXN1F_72 0.0117533135372
# ms_tx_CARBON_DIOXIDE -1.57590140246e-15
# ms_RXN_12195 0.226438186117
# bs_RXN_12195 0.25014463455
# ms_RXN_1841 0.000996210312404
# bs_RXN_1841 -0.000996210312178
# ms_GLUTATHIONE_REDUCT_NADPH_RXN 0.473137449812
# bs_GLUTATHIONE_REDUCT_NADPH_RXN 0.472280314629
# ms_sink_L_1_PHOSPHATIDYL_GLYCEROL 0.0111998419506
# bs_sink_L_1_PHOSPHATIDYL_GLYCEROL -0.0111998419507
# ms_RXN_12196 -0.0277652551802
# bs_RXN_12196 0.0134569693538
# ms_CYSTATHIONINE_BETA_LYASE_RXN -0.0381771961805
# bs_CYSTATHIONINE_BETA_LYASE_RXN 0.0381771961805
# ms_PSERTRANSAM_RXN 0.134181872781
# bs_PSERTRANSAM_RXN 0.223125874213
# ms_sink_STEARIC_ACID -0.0156038823815
# bs_sink_STEARIC_ACID 0.0156038823815
# ms_GART_RXN -0.0100768741323
# bs_GART_RXN 0.0100768741321
# ms__3_DEHYDROQUINATE_DEHYDRATASE_RXN -0.0700924105048
# bs__3_DEHYDROQUINATE_DEHYDRATASE_RXN 0.0700924105055
# ms_ARGSUCCINSYN_RXN -0.00966170952579
# bs_ARGSUCCINSYN_RXN 0.00164153603679
# ms_AbstractFreeGalactoseSynthesis 0.660780827981
# bs_AbstractFreeGalactoseSynthesis 0.694429266817
# ms_GMP_SYN_GLUT_RXN -0.00503931390278
# bs_GMP_SYN_GLUT_RXN 0.00503931390271
# ms_RXN_9644 -0.0122108959674
# bs_RXN_9644 0.012210895967
# ms_GLYRIBONUCSYN_RXN -0.0100768741323
# bs_GLYRIBONUCSYN_RXN 0.0100768741321
# ms_UDPREDUCT_RXN -0.0162008072234
# bs_UDPREDUCT_RXN 0.0162008072234
# ms_GLUTAMIDOTRANS_RXN -0.0129482508622
# bs_GLUTAMIDOTRANS_RXN 0.0129482508621
# ms_RXN_13163 -0.0167324184267
# bs_RXN_13163 0.0167324184258
# ms_GlucuronateTransfer_mod 0.000595931213911
# bs_GlucuronateTransfer_mod -0.000595931213767
# ms_sink__Galactosyl_galactosyl_diacyl_glycerols_ -0.0104393654331
# bs_sink__Galactosyl_galactosyl_diacyl_glycerols_ 0.0104393654331
# ms_ASPARTATE_SEMIALDEHYDE_DEHYDROGENASE_RXN 0.0214703529974
# bs_ASPARTATE_SEMIALDEHYDE_DEHYDROGENASE_RXN -0.0214703529971
# ms_SUCROSE_PHOSPHATE_SYNTHASE_RXN 0.140219580471
# bs_SUCROSE_PHOSPHATE_SYNTHASE_RXN 0.147878331625
# ms__3_OXOACYL_ACP_SYNTH_RXN_Palmitoyl_ACPs_MALONYL_ACP__3_oxo_stearoyl_ACPs_CARBON_DIOXIDE_ACP_67_ 0.331221301871
# bs__3_OXOACYL_ACP_SYNTH_RXN_Palmitoyl_ACPs_MALONYL_ACP__3_oxo_stearoyl_ACPs_CARBON_DIOXIDE_ACP_67_ 0.335444511822
# ms_PHOSPHORIBULOKINASE_RXN_chloroplast -0.0279787698168
# bs_PHOSPHORIBULOKINASE_RXN_chloroplast 0.0271078307395
# ms_DCDPKIN_RXN -0.0161998207822
# bs_DCDPKIN_RXN 0.0161998207822
# ms_RXN_7903 0.00410229304818
# bs_RXN_7903 -0.00410229305021
# ms_ComplexIV_mod_mitochondrion 0.295402632676
# bs_ComplexIV_mod_mitochondrion 0.28329554883
# ms_PORPHOBILSYNTH_RXN -0.0470132541504
# bs_PORPHOBILSYNTH_RXN 0.0470132541481
# ms_EC_1_1_1_34 -0.0448393910964
# bs_EC_1_1_1_34 -0.026475079474
# ms_mitochondrion_serine_exchange -0.0694779472565
# bs_mitochondrion_serine_exchange -0.0639237600036
# ms_DIHYDROPICRED_RXN_DELTA1_PIPERIDEINE_2_6_DICARBOXYLATE_NAD__2_3_DIHYDRODIPICOLINATE_NADH_PROTON_78_ 0.286834166572
# bs_DIHYDROPICRED_RXN_DELTA1_PIPERIDEINE_2_6_DICARBOXYLATE_NAD__2_3_DIHYDRODIPICOLINATE_NADH_PROTON_78_ 0.274534939894
# ms_TYROSINE_DECARBOXYLASE_RXN -0.0620003561423
# bs_TYROSINE_DECARBOXYLASE_RXN 0.0620003561422
# ms_CalloseSynthesis_mod 0.0300069176926
# bs_CalloseSynthesis_mod -0.0300069176926
# ms_ACETOLACTSYN_RXN 0.0504323106255
# bs_ACETOLACTSYN_RXN -0.0504323106244
# ms_ISOCITRATE_DEHYDROGENASE_NAD__RXN_mitochondrion -0.462762979036
# bs_ISOCITRATE_DEHYDROGENASE_NAD__RXN_mitochondrion -0.448997414767
# ms_CHORISMATEMUT_RXN -0.00703461840837
# bs_CHORISMATEMUT_RXN 0.00703461840924
# ms_tx__Light_ 0.0016965113947
# bs_tx__Light_ -0.0016965113947
# ms_mitochondrion_O2_exchange 0.295402632676
# bs_mitochondrion_O2_exchange 0.28329554883
# ms_RXN_7674 0.0322402876599
# bs_RXN_7674 -0.03224028766
# ms_RXN_1101 -0.0197542569188
# bs_RXN_1101 0.0197542569191
# ms_RXN_1103 -0.470795507121
# bs_RXN_1103 -0.470381172736
# ms_RXN_1102 -0.0197542569188
# bs_RXN_1102 0.0197542569191
# ms_RXN_1104 -0.115983397094
# bs_RXN_1104 -0.119311142769
# ms_PYRROLINECARBREDUCT_RXN_PRO_NADP__L_DELTA1_PYRROLINE_5_CARBOXYLATE_NADPH_PROTON_56_ 0.286891627938
# bs_PYRROLINECARBREDUCT_RXN_PRO_NADP__L_DELTA1_PYRROLINE_5_CARBOXYLATE_NADPH_PROTON_56_ 0.297950024896
# ms_sink_LINOLENIC_ACID -0.0135523969562
# bs_sink_LINOLENIC_ACID 0.0135523969562
# ms_SUCCINATE_SEMIALDEHYDE_DEHYDROGENASE_RXN 0.144173307717
# bs_SUCCINATE_SEMIALDEHYDE_DEHYDROGENASE_RXN 0.145330687933
# ms_GLYCOGENSYN_RXN_mod_chloroplast 0.0243686872201
# bs_GLYCOGENSYN_RXN_mod_chloroplast -0.0243686872201
# ms_ACETYL_COA_CARBOXYLTRANSFER_RXN -0.344423609193
# bs_ACETYL_COA_CARBOXYLTRANSFER_RXN -0.322243244014
# ms_PREPHENATE_TRANSAMINE_RXN -0.00703461840837
# bs_PREPHENATE_TRANSAMINE_RXN 0.00703461840924
# ms_INORGPYROPHOSPHAT_RXN_chloroplast 0.00786648437326
# bs_INORGPYROPHOSPHAT_RXN_chloroplast -0.0242258398518
# ms_RXN_MG_PROTOPORPHYRIN_METHYLESTER_SYN -0.0117533135374
# bs_RXN_MG_PROTOPORPHYRIN_METHYLESTER_SYN 0.0117533135372
# ms_N_ACETYLTRANSFER_RXN 0.265529590589
# bs_N_ACETYLTRANSFER_RXN 0.239569617566
# ms_ACETYLORNDEACET_RXN 0.265529590589
# bs_ACETYLORNDEACET_RXN 0.239569617567
# ms_RXN_13462 0.00367455455032
# bs_RXN_13462 -0.00367455455037
# ms_RXN_8389_mod 8.18063159699e-05
# bs_RXN_8389_mod -8.18063160415e-05
# ms_RXN1F_66 -0.0340870832648
# bs_RXN1F_66 0.0340866070433
# ms_GLYCINE_AMINOTRANSFERASE_RXN_peroxisome -0.38169590097
# bs_GLYCINE_AMINOTRANSFERASE_RXN_peroxisome -0.384669334442
# ms_GAPOXNPHOSPHN_RXN 0.0732802294215
# bs_GAPOXNPHOSPHN_RXN 0.0682668233663
# ms_RXN_12199 -0.405921762631
# bs_RXN_12199 -0.374118226129
# bs_tx_VAL 4.24567716675e-15
# ms_sink__D_Galactosyl_12_diacyl_glycerols_ -0.0487757969326
# bs_sink__D_Galactosyl_12_diacyl_glycerols_ 0.0487757969326
# ms_SUCROSE_PHOSPHATASE_RXN 0.140219580471
# bs_SUCROSE_PHOSPHATASE_RXN 0.147878331625
# ms_GlucuronoxylanSynthesis_mod 0.0343069534791
# bs_GlucuronoxylanSynthesis_mod -0.0343069534791
# ms_AMP_DEAMINASE_RXN 0.338273629364
# bs_AMP_DEAMINASE_RXN 0.373066332208
# ms_GLY3KIN_RXN_chloroplast 0.156654539189
# bs_GLY3KIN_RXN_chloroplast 0.096062882089
# ms_mitochondrion_ATP_ADP_exchange 1.16241339693
# bs_mitochondrion_ATP_ADP_exchange 1.17548509823
# ms_RXN_1781 0.202421041396
# bs_RXN_1781 0.195062935089
# ms_UDP_GLUCURONATE_4_EPIMERASE_RXN 0.0321973251897
# bs_UDP_GLUCURONATE_4_EPIMERASE_RXN -0.032197325189
# ms_sink_PHYTOSPINGOSINE 0.0742474889785
# bs_sink_PHYTOSPINGOSINE -0.0742474889785
# ms_RXN0_884_CPD_4211_NADP_WATER__HYDROXY_METHYL_BUTENYL_DIP_NADPH_PROTON_61_ -0.538206940047
# bs_RXN0_884_CPD_4211_NADP_WATER__HYDROXY_METHYL_BUTENYL_DIP_NADPH_PROTON_61_ -0.514247524491
# ms_DIPHOSPHOMEVALONTE_DECARBOXYLASE_RXN -0.0448393910964
# bs_DIPHOSPHOMEVALONTE_DECARBOXYLASE_RXN -0.026475079474
# ms_RXN_9549 0.0116115664024
# bs_RXN_9549 -0.0116115664027
# ms_THRESYN_RXN 0.0559729946276
# bs_THRESYN_RXN -0.0559729946272
# ms_mitochondrion_water_exchange -0.696538066909
# bs_mitochondrion_water_exchange -0.639327317803
# ms_AminoAcidSink 0.000365348595763
# bs_AminoAcidSink -0.000365348595745
# ms_GLUTDEHYD_RXN 0.955702351351
# bs_GLUTDEHYD_RXN 0.766651886521
# ms_OROTPDECARB_RXN -0.0100707362757
# bs_OROTPDECARB_RXN 0.0100707362759
# ms_RIB5PISOM_RXN_chloroplast -0.00932625660559
# bs_RIB5PISOM_RXN_chloroplast 0.00903594357982
# ms_IGPSYN_RXN -0.0630577920964
# bs_IGPSYN_RXN 0.0630577920963
# ms_OROPRIBTRANS_RXN -0.0100707362757
# bs_OROPRIBTRANS_RXN 0.0100707362759
# ms_sink_ASCORBATE 0.0143860128949
# bs_sink_ASCORBATE -0.0143860128949
# ms_BIOTIN_CARBOXYL_RXN 0.327788366471
# bs_BIOTIN_CARBOXYL_RXN 0.338878486706
# ms_sink_PHE -0.0328556600609
# bs_sink_PHE 0.0328556600609
# ms_HOMOCYSMETB12_RXN -0.0177488821245
# bs_HOMOCYSMETB12_RXN 0.0177488821244
# ms_UROGENIIISYN_RXN -0.0117533135376
# bs_UROGENIIISYN_RXN 0.0117533135371
# ms_EC_2_7_1_148 -0.00217386305366
# bs_EC_2_7_1_148 0.0734883336224
# ms_chloroplast_TPT_GAP_exchange 0.0231206059323
# bs_chloroplast_TPT_GAP_exchange -0.0337030363507
# ms_RXNQT_4141 0.014386012895
# bs_RXNQT_4141 -0.0143860128949
# ms_RXNQT_4142 0.014386012895
# bs_RXNQT_4142 -0.0143860128949
# ms_CARBOXYCYCLOHEXADIENYL_DEHYDRATASE_RXN -0.0446254896701
# bs_CARBOXYCYCLOHEXADIENYL_DEHYDRATASE_RXN 0.0446254896709
# ms_MannoseTransfer_mod 0.00108057406859
# bs_MannoseTransfer_mod -0.00108057406834
# ms__4_2_1_58_RXN -0.000735648301474
# bs__4_2_1_58_RXN 0.000735648297543
# ms_RXN_9548 -0.01558799766
# bs_RXN_9548 0.0155879976599
# ms_ComplexI_mod_mitochondrion 0.163523263874
# bs_ComplexI_mod_mitochondrion 0.187868509299
# ms_sink_Glucomannan_monomer_equivalent 0.0352477434806
# bs_sink_Glucomannan_monomer_equivalent -0.0352477434806
# ms_RXN0_884_CPD_4211_NAD_WATER__HYDROXY_METHYL_BUTENYL_DIP_NADH_PROTON_59_ 0.0317868006664
# bs_RXN0_884_CPD_4211_NAD_WATER__HYDROXY_METHYL_BUTENYL_DIP_NADH_PROTON_59_ 0.0384964178723
# ms_GALACTURIDYLYLTRANS_RXN 0.87482547416
# bs_GALACTURIDYLYLTRANS_RXN 0.915823684285
# ms_CDPDIGLYSYN_RXN 0.0524748151926
# bs_CDPDIGLYSYN_RXN -0.0524748151932
# ms_RXN_3521_chloroplast -0.0363275579732
# bs_RXN_3521_chloroplast -0.0376777773583
# ms_GPH_RXN_chloroplast -0.291837073472
# bs_GPH_RXN_chloroplast -0.221810740662
# ms_PROTOPORGENOXI_RXN -0.0117533135375
# bs_PROTOPORGENOXI_RXN 0.0117533135372
# ms_EC_2_3_3_8 0.0605524519401
# bs_EC_2_3_3_8 0.0955629415982
# ms_HomogalacturonanSynthesis_mod 0.0292769032468
# bs_HomogalacturonanSynthesis_mod -0.0292769032468
# ms_GalacturonateTransfer_mod 0.00292042194284
# bs_GalacturonateTransfer_mod -0.00292042194219
# ms_chloroplast_O2_exchange -0.209764609239
# bs_chloroplast_O2_exchange -0.141441031498
# ms_IMP_DEHYDROG_RXN -0.00503931390278
# bs_IMP_DEHYDROG_RXN 0.00503931390271
# ms_sink_OLEATE_CPD -0.0228958868543
# bs_sink_OLEATE_CPD 0.0228958868542
# ms_RXN_2981 -0.118096508426
# bs_RXN_2981 -0.144345020273
# ms_ASNSYNB_RXN 0.103566654754
# bs_ASNSYNB_RXN -0.103566654754
# ms_MALATE_DEHYDROGENASE_NADP__RXN_chloroplast 0.164841413769
# bs_MALATE_DEHYDROGENASE_NADP__RXN_chloroplast 0.197362383709
# ms_DIACYLGLYKIN_RXN 0.12963508823
# bs_DIACYLGLYKIN_RXN 0.0974796995168
# ms_GLUTAMATE_N_ACETYLTRANSFERASE_RXN 0.429456196742
# bs_GLUTAMATE_N_ACETYLTRANSFERASE_RXN 0.427251956523
# ms_ADENOSINE_KINASE_RXN 0.20376908329
# bs_ADENOSINE_KINASE_RXN 0.212481931159
# ms_CELLULOSE_SYNTHASE_mod 0.0353945683406
# bs_CELLULOSE_SYNTHASE_mod -0.0353945683363
# ms_EC_1_1_1_8 0.290125103628
# bs_EC_1_1_1_8 0.271243692358
# ms_ADENYL_KIN_RXN -0.189179872734
# bs_ADENYL_KIN_RXN -0.124389526741
# ms_HISTCYCLOHYD_RXN -0.0129482508622
# bs_HISTCYCLOHYD_RXN 0.0129482508621
# ms_RXN_6902 0.490594576345
# bs_RXN_6902 0.532723831798
# ms_ACETYLGLUTKIN_RXN 0.694985787331
# bs_ACETYLGLUTKIN_RXN 0.666821574089
# ms_EC_2_7_7_13 0.712012110803
# bs_EC_2_7_7_13 0.643197983995
# ms__1TRANSKETO_RXN_chloroplast -0.00932625660559
# bs__1TRANSKETO_RXN_chloroplast 0.00903594357982
# ms_SULFITE_OXIDASE_RXN 0.416501133672
# bs_SULFITE_OXIDASE_RXN 0.365379676958
# ms_RXN66_1 0.258897345086
# bs_RXN66_1 0.255438986603
# ms_METHENYLTHFCYCLOHYDRO_RXN -0.0331019991268
# bs_METHENYLTHFCYCLOHYDRO_RXN 0.0331019991264
# ms_RXN_969_peroxisome -0.247985111091
# bs_RXN_969_peroxisome -0.265662703044
# ms_RXN1F_20 -0.0117533135374
# bs_RXN1F_20 0.0117533135372
# ms_RXN_8287 0.482546550072
# bs_RXN_8287 0.479659758141
# ms_EC_2_3_1_133 0.238829125146
# bs_EC_2_3_1_133 0.231758986923
# ms_MALSYN_RXN 0.1270343288
# bs_MALSYN_RXN 0.0544316318293
# plasmodesmata_ms_NITRATE_bs_NITRATE 0.0180471683568
# plasmodesmata_ms_SUCROSE_bs_SUCROSE 0.322534716486
# plasmodesmata_ms_AMMONIA_bs_AMMONIA 0.679985530332
# plasmodesmata_ms_SULFATE_bs_SULFATE -0.018332290638
# plasmodesmata_ms_CO2_bs_CO2 0.460011988634
# plasmodesmata_ms_oxygen_bs_oxygen 0.126837923753
# plasmodesmata_ms_MG_2_bs_MG_2 -0.0117533135373
# plasmodesmata_ms_GLT_bs_GLT 0.301048568604
# plasmodesmata_ms__2_KETOGLUTARATE_bs__2_KETOGLUTARATE 0.17335034967
# plasmodesmata_ms_CYS_bs_CYS 0.31180337368
# plasmodesmata_ms_GLUTATHIONE_bs_GLUTATHIONE 0.027471388049
# plasmodesmata_ms_PROTON_bs_PROTON 0.831111942053

# %%
simpleS3, details = simplification.simplify(s3model)

# %%
print details
simpleS3.compile()
simpleS3.solve()
# Out:
# ({'bs_tx_L_ALPHA_ALANINE': 0.0, 'bs_tx_GLUTATHIONE': 0.0, 'bs_tx_PROTON': 0.0, 'bs_tx_LYS': 0.0, 'ms_tx_CARBON_DIOXIDE': 0.0, 'bs_tx_PHE': 0.0, 'bs_tx_SUCROSE': 0.0, 'bs_tx_WATER': 0.0, 'bs_tx_ILE': 0.0, 'bs_tx_VAL': 0.0, 'bs_tx_ASN': 0.0, 'bs_tx_CPD_397': 0.0, 'bs_tx_TYR': 0.0, 'bs_tx_MG_2': 0.0, 'bs_tx_HIS': 0.0, 'bs_tx_MET': 0.0, 'ms_tx_OXYGEN_MOLECULE': 0.0, 'bs_tx_SULFATE': 0.0, 'bs_tx_ARG': 0.0, 'bs_tx_SER': 0.0, 'bs_tx_NITRATE': 0.0, 'bs_tx_L_ASPARTATE': 0.0, 'bs_tx_LEU': 0.0, 'bs_tx_GLY': 0.0, 'bs_tx_THR': 0.0, 'bs_tx__Pi_': 0.0, 'bs_tx_GLT': 0.0}, [], {}, ['_conservation_SUCROSE_phloem', '_conservation_WATER_xylem', '_conservation_GLY_phloem', '_conservation_LEU_phloem', '_conservation_GLUTATHIONE_phloem', '_conservation_ILE_phloem', '_conservation_TYR_phloem', '_conservation_NITRATE_xylem', '_conservation_MG_2_xylem', '_conservation_MET_phloem', '_conservation_L_alanine_phloem', '_conservation_PHE_phloem', '_conservation_VAL_phloem', '_conservation_ARG_phloem', '_conservation_oxygen_intercellular_air_space', '_conservation_LYS_phloem', '_conservation_SER_phloem', '_conservation_PROTON_xylem', '_conservation_GLT_phloem', '_conservation_CPD_397_phloem', '_conservation_SULFATE_xylem', '_conservation_CO2_intercellular_air_space', '_conservation_phosphate_xylem', '_conservation_L_ASPARTATE_phloem', '_conservation_HIS_phloem', '_conservation_ASN_phloem', '_conservation_THR_phloem', 'CO2_leakiness_constraint'], ['_conservation_bs_CPD_9956_mitochondrion', '_conservation_ms_dhurrin', '_conservation_bs_Reduced_ferredoxins', '_conservation_ms_METHYLENE_THF_mitochondrion', '_conservation_bs_Pyruvate_dehydrogenase_acetylDHlipoyl_mitochondrion', '_conservation_ms_Charged_GLT_tRNAs', '_conservation_ms_INDOLE_3_ACETYL_ALA', '_conservation_ms_Oxidized_ferredoxins', '_conservation_ms_DI_H_OROTATE_mitochondrion', '_conservation_ms_Oleoyl_groups', '_conservation_bs_NAD_peroxisome', '_conservation_bs_NADP_chloroplast', '_conservation_ms_phosphate_mitochondrion', '_conservation_bs_NADPH', '_conservation_bs_CPD_506', '_conservation_ms_Ox_Thioredoxin', '_conservation_ms_NAD_peroxisome', '_conservation_ms_Reduced_ferredoxins_chloroplast', '_conservation_ms_PROTON_peroxisome', '_conservation_bs_Pyruvate_dehydrogenase_lipoate', '_conservation_ms_OXALACETIC_ACID_peroxisome', '_conservation_bs_OXALACETIC_ACID_peroxisome', '_conservation_bs_PLASTOQUINOL_1_chloroplast', '_conservation_ms_Cytochromes_C_Oxidized_mitochondrion', '_conservation_bs_INDOLE_ACETATE_AUXIN', '_conservation_ms_NADH', '_conservation_bs_NAD_mitochondrion', '_conservation_bs_THF_mitochondrion', '_conservation_bs_DODECANOATE', '_conservation_ms_NADPH_chloroplast', '_conservation_bs_ADP_mitochondrion', '_conservation_bs_OROTATE_mitochondrion', '_conservation_ms_NADP', '_conservation_ms_PLASTOQUINOL_1_chloroplast', '_conservation_bs_BUTYRIC_ACID', '_conservation_bs_OXIDIZED_GLUTATHIONE_chloroplast', '_conservation_bs_BCCP_dimers', '_conservation_ms_NAD_mitochondrion', '_conservation_ms_LAUROYLCOA_CPD', '_conservation_ms__10_FORMYL_THF', '_conservation_ms_ATP_mitochondrion', '_conservation_ms_BUTYRYL_COA', '_conservation_bs_Oxidized_ferredoxins_chloroplast', '_conservation_bs__1_PHOSPHATIDYL_1D_MYO_INOSITOL_35_BISPH', '_conservation_bs_NAD', '_conservation_ms_UBIQUINONE_8_mitochondrion', '_conservation_ms_ADP_D_GLUCOSE_chloroplast', '_conservation_bs_ACETYL_COA_mitochondrion', '_conservation_bs_NADH_peroxisome', '_conservation_bs_Plastocyanin_Reduced_chloroplast', '_conservation_bs_Cytochromes_C_Reduced_mitochondrion', '_conservation_bs_Red_Thioredoxin', '_conservation_ms_SUC_COA_mitochondrion', '_conservation_bs_Charged_GLT_tRNAs', '_conservation_bs_PALMITYL_COA', '_conservation_ms_INOSITOL_1_3_4_TRIPHOSPHATE', '_conservation_bs_ATP_mitochondrion', '_conservation_ms_BCCP_dimers', '_conservation_bs_ATP_chloroplast', '_conservation_ms_D_SEDOHEPTULOSE_7_P_chloroplast', '_conservation_ms_GLUTATHIONE_chloroplast', '_conservation_bs_phosphate_chloroplast', '_conservation_bs_METHYLENE_T ...
# ---------------------------------------------------------------------------
# OptimizationFailure                       Traceback (most recent call last)
# <ipython-input-83-783aeb3369af> in <module>()
#       1 print details
#       2 simpleS3.compile()
# ----> 3 simpleS3.solve()
#
# /Users/yukai/anaconda2/lib/python2.7/site-packages/fluxtools/nlcm.pyc in solve(self, x0, options)
#     898
#     899         if self.status not in (0, 1):
# --> 900             raise OptimizationFailure('IPOPT exited with status %d' % self.status)
#     901
#     902         return self.x.copy()
#
# OptimizationFailure: IPOPT exited with status -12
