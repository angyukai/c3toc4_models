# %%
import scobra
import pandas as pd
import suppFunctions as sf
from cobra import Metabolite
m1m2 = scobra.Model('AraLightDarkCore_DbMesophyll_v4.xls')
m = scobra.Model('AraLightDarkCore_ScrumPy.xls')
# m1m2.SetReacsFixedRatio({"RXN-961_Dark_p_M1":1, "RIBULOSE-BISPHOSPHATE-CARBOXYLASE-RXN_Dark_p_M1":3})

# %% [markdown]
# ## Changes made to the model so far

# %%
###################################################################
### 1. Added sucrose and amino acid transport between M1 and M2 ###
###################################################################

# AA_met = ['GLY','GLN','MET','LEU','HIS','VAL','ILE',
#          'L-ALPHA-ALANINE','L-ASPARTATE','SER','TYR','LYS','PHE',
#          'ARG','TRP','GLT','ASN','THR']

# #transport AA from M1 to M2 LIGHT
# for met in AA_met:
#     m1m2.AddReaction(met+'_Light_M1M2',{met+'_Light_c_M1':-1,met+'_Light_c_M2':1},True)

# #transport AA from M1 to M2 DARK
# for met in AA_met:
#     m1m2.AddReaction(met+'_Dark_M1M2',{met+'_Dark_c_M1':-1,met+'_Dark_c_M2':1},True)

# m1m2.PrintReaction('GLN_Light_M1M2')
# m1m2.PrintReaction('GLN_Dark_M1M2')
# m1m2.PrintReaction('Sucrose_Light_M1M2')

####################################################
### 2. Added Malate transport between M1 and M2. ###
####################################################

#Adding malate transporters between M1 and M2
# m1m2.AddReaction('MAL_Light_M1M2',{'MAL_Light_c_M1':-1,'MAL_Light_c_M2':1},True)
# m1m2.AddReaction('MAL_Dark_M1M2',{'MAL_Dark_c_M1':-1,'MAL_dark_c_M2':1},True)

####################################################
### 3. Added pyruvate transport between M1 and M2. ###
####################################################

# m1m2.AddReaction('PYRUVATE_Light_M1M2',{'PYRUVATE_Light_c_M1':-1,'PYRUVATE_Light_c_M2':1},True)
# m1m2.AddReaction('PYRUVATE_Dark_M1M2',{'PYRUVATE_Dark_c_M1':-1,'PYRUVATE_Dark_c_M2':1},True)

# %% [markdown]
# ## M constraints

# %%
#constraint list

constraints_list = {'Photon_Light_tx':(0,None),
                   'Photon_Dark_tx':(0,0),
                   'GLC_Dark_tx':(0,0),
                   'GLC_Light_tx':(0,0),
                   'Sucrose_Dark_tx':(0,0),
                   'Sucrose_Light_tx':(0,0),
                   'TAG_Dark_tx':(0,0),
                   'TAG_Light_tx':(0,0),
                   'Starch_Dark_tx':(0,0),
                   'Starch_Light_tx':(0,0),
                   'NADPH_Dehydrogenase_Dark_p':(0,0),
                   'NADPH_Dehydrogenase_Light_p':(0,0),
                   'NADPHoxx_Light_tx':(0,0),
                    'NADPHoxx_Dark_tx':(0,0),
                    'Plastoquinol_Oxidase_Dark_p':(0,0),
                    'Plastoquinol_Oxidase_Light_p':(0,0),
                    'NH4_Light_tx':(0,0),
                    'NH4_Dark_tx':(0,0)
                   }

m.SetConstraints(constraints_list)


lightdic = {'Alanine_Light_biomass':-9.7,'Arginine_Light_biomass':-1.6,'Asparagine_Light_biomass':-10.1,'Aspartate_Light_biomass':-9.5,
'Glutamate_Light_biomass':-11.4,'Glutamine_Light_biomass':-33.2,'Glycine_Light_biomass':-0.7,'Serine_Light_biomass':-7.7,
'Tyrosine_Light_biomass':-0.6,'Histidine_Light_biomass':-0.4,'Isoleucine_Light_biomass':-1.2,'Leucine_Light_biomass':-1.2,
'Lysine_Light_biomass':-1.8,'Methionine_Light_biomass':-0.7,'Phenylalanine_Light_biomass':-1.1,'Threonine_Light_biomass':-5.6,
'Tryptophan_Light_biomass':-0.9,'Valine_Light_biomass':-2.4}

darkdic = {'Alanine_Dark_biomass':-9.7,'Arginine_Dark_biomass':-1.6,'Asparagine_Dark_biomass':-10.1,'Aspartate_Dark_biomass':-9.5,
'Glutamate_Dark_biomass':-11.4,'Glutamine_Dark_biomass':-33.2,'Glycine_Dark_biomass':-0.7,'Serine_Dark_biomass':-7.7,
'Tyrosine_Dark_biomass':-0.6,'Histidine_Dark_biomass':-0.4,'Isoleucine_Dark_biomass':-1.2,'Leucine_Dark_biomass':-1.2,
'Lysine_Dark_biomass':-1.8,'Methionine_Dark_biomass':-0.7,'Phenylalanine_Dark_biomass':-1.1,'Threonine_Dark_biomass':-5.6,
'Tryptophan_Dark_biomass':-0.9,'Valine_Dark_biomass':-2.4}

exclude_list = []

for i in lightdic.keys():
    exclude_list.append(i)

for i in darkdic.keys():
    exclude_list.append(i)

exclude_list.append('Sucrose_Light_biomass')
exclude_list.append('Sucrose_Dark_biomass')

list_b = m.Reactions('_biomass')

for i in list_b:
    check = sf.notInList(i, exclude_list)
    if check:
        m.SetConstraint(i,0,0)

m.SetReacsFixedRatio({"RXN-961_Dark_p":1, "RIBULOSE-BISPHOSPHATE-CARBOXYLASE-RXN_Dark_p":3})
m.SetReacsFixedRatio({"RXN-961_Light_p":1, "RIBULOSE-BISPHOSPHATE-CARBOXYLASE-RXN_Light_p":3})
m.SetReacsFixedRatio({"NO3_Light_tx":3, 'NO3_Dark_tx':2})

#Setting night and day export constraints.
m.SetReacsFixedRatio({'Sucrose_Light_biomass':3,'Sucrose_Dark_biomass':1})

# Setting ratios between sucrose and amino acids
for aa in lightdic.keys():
    m.SetReacsFixedRatio({aa:-lightdic[aa],'Sucrose_Light_biomass':220})

for aa in darkdic.keys():
    m.SetReacsFixedRatio({aa:-darkdic[aa],'Sucrose_Dark_biomass':220})

#Set ATP and NADPH rxn to be None to 0. 
ATP_constraints = ['NADPHoxc', 'NADPHoxm', 'NADPHoxp']

for reac in ATP_constraints:
    nadph_d = reac+'_Light_tx'
    nadph_n = reac+'_Dark_tx'
    
    m.SetReacsFixedRatio({nadph_d:1,'ATPase_Light_tx':9})
    m.SetReacsFixedRatio({nadph_n:1,'ATPase_Dark_tx':9})

# m.SetConstraints({'Sucrose_Light_biomass':(-0.01,-0.01)})
# m.SetConstraints({'Sucrose_Dark_biomass':(-sucrose_dark,-sucrose_dark)})
m.SetConstraints({'ATPase_Light_tx':(-7.5,-7.5)})
m.SetConstraints({'ATPase_Dark_tx':(-7.5,-7.5)})

m.SetConstraints({'Photon_Light_tx':(194,194)})

#ATP maintenance should go in the direction that consumes ATP
m.SetObjDirec('min')
m.SetObjective('Sucrose_Light_biomass')
m.SetObjective('Sucrose_Dark_biomass')
m.MinFluxSolve()
# Out:
# optimal

# %% [markdown]
# ## M1M2 constraints: Standard ones

# %%
constraints = ['Photon_Dark_tx',
                   'GLC_Dark_tx',
                   'GLC_Light_tx',
                   'Sucrose_Dark_tx',
                   'Sucrose_Light_tx',
                   'TAG_Dark_tx',
                   'TAG_Light_tx',
                   'Starch_Dark_tx',
                   'Starch_Light_tx',
                   'NADPH_Dehydrogenase_Dark_p',
                   'NADPH_Dehydrogenase_Light_p',
                   'NADPHoxx_Light_tx',
                    'NADPHoxx_Dark_tx',
                    'Plastoquinol_Oxidase_Dark_p',
                    'Plastoquinol_Oxidase_Light_p',
                    'NH4_Light_tx',
                    'NH4_Dark_tx']

for tx in constraints:
    reac = tx+'_M1'
    m1m2.SetConstraint(reac,0,0)

for tx in constraints:
    reac = tx+'_M2'
    m1m2.SetConstraint(reac,0,0)

#Setting biomasses to 0
lightdic = {'Alanine_Light_biomass':-9.7,'Arginine_Light_biomass':-1.6,'Asparagine_Light_biomass':-10.1,'Aspartate_Light_biomass':-9.5,
'Glutamate_Light_biomass':-11.4,'Glutamine_Light_biomass':-33.2,'Glycine_Light_biomass':-0.7,'Serine_Light_biomass':-7.7,
'Tyrosine_Light_biomass':-0.6,'Histidine_Light_biomass':-0.4,'Isoleucine_Light_biomass':-1.2,'Leucine_Light_biomass':-1.2,
'Lysine_Light_biomass':-1.8,'Methionine_Light_biomass':-0.7,'Phenylalanine_Light_biomass':-1.1,'Threonine_Light_biomass':-5.6,
'Tryptophan_Light_biomass':-0.9,'Valine_Light_biomass':-2.4}

darkdic = {'Alanine_Dark_biomass':-9.7,'Arginine_Dark_biomass':-1.6,'Asparagine_Dark_biomass':-10.1,'Aspartate_Dark_biomass':-9.5,
'Glutamate_Dark_biomass':-11.4,'Glutamine_Dark_biomass':-33.2,'Glycine_Dark_biomass':-0.7,'Serine_Dark_biomass':-7.7,
'Tyrosine_Dark_biomass':-0.6,'Histidine_Dark_biomass':-0.4,'Isoleucine_Dark_biomass':-1.2,'Leucine_Dark_biomass':-1.2,
'Lysine_Dark_biomass':-1.8,'Methionine_Dark_biomass':-0.7,'Phenylalanine_Dark_biomass':-1.1,'Threonine_Dark_biomass':-5.6,
'Tryptophan_Dark_biomass':-0.9,'Valine_Dark_biomass':-2.4}

exclude_list = []

for aa in lightdic.keys():
    M1 = aa+'_M1'
    exclude_list.append(M1)
    M2 = aa+'_M2'
    exclude_list.append(M2)

for aa in darkdic.keys():
    M1 = aa+'_M1'
    exclude_list.append(M1)
    M2 = aa+'_M2'
    exclude_list.append(M2)

exclude_list.append('Sucrose_Light_biomass_M1')
exclude_list.append('Sucrose_Light_biomass_M2')
exclude_list.append('Sucrose_Dark_biomass_M1')
exclude_list.append('Sucrose_Dark_biomass_M2')

list_b = m1m2.Reactions('_biomass')

for i in list_b:
    check = sf.notInList(i, exclude_list)
    if check:
        m1m2.SetConstraint(i,0,0)
print '111'
m1m2.SetReacsFixedRatio({"RXN-961_Dark_p_M1":1, "RIBULOSE-BISPHOSPHATE-CARBOXYLASE-RXN_Dark_p_M1":3})
print '222'
# m1m2.SetReacsFixedRatio({"RXN-961_Dark_p_M2":1, "RIBULOSE-BISPHOSPHATE-CARBOXYLASE-RXN_Dark_p_M2":3})
print '333'
m1m2.SetReacsFixedRatio({"RXN-961_Light_p_M1":1, "RIBULOSE-BISPHOSPHATE-CARBOXYLASE-RXN_Light_p_M1":3})
print '444'
# m1m2.SetReacsFixedRatio({"RXN-961_Light_p_M2":1, "RIBULOSE-BISPHOSPHATE-CARBOXYLASE-RXN_Light_p_M2":3})
m1m2.SetReacsFixedRatio({"NO3_Light_tx_M1":3, 'NO3_Dark_tx_M1':2})
m1m2.SetReacsFixedRatio({"NO3_Light_tx_M2":3, 'NO3_Dark_tx_M2':2})

#Set ATP and NADPH rxn to be None to 0. 
ATP_constraints = ['NADPHoxc', 'NADPHoxm', 'NADPHoxp']

for reac in ATP_constraints:
    nadph_d = reac+'_Light_tx_M1'
    nadph_n = reac+'_Dark_tx_M1'
    
    m1m2.SetReacsFixedRatio({nadph_d:1,'ATPase_Light_tx_M1':9})
    m1m2.SetReacsFixedRatio({nadph_n:1,'ATPase_Dark_tx_M1':9})
    
for reac in ATP_constraints:
    nadph_d = reac+'_Light_tx_M2'
    nadph_n = reac+'_Dark_tx_M2'
    
    m1m2.SetReacsFixedRatio({nadph_d:1,'ATPase_Light_tx_M2':9})
    m1m2.SetReacsFixedRatio({nadph_n:1,'ATPase_Dark_tx_M2':9})

    
    
#Setting night and day export constraints.
m1m2.SetReacsFixedRatio({'Sucrose_Light_biomass_M1':3,'Sucrose_Dark_biomass_M1':1})
m1m2.SetReacsFixedRatio({'Sucrose_Light_biomass_M2':3,'Sucrose_Dark_biomass_M2':1})

# Setting ratios between sucrose and amino acids
for aa in lightdic.keys():
    m1m2.SetReacsFixedRatio({aa+'_M1':-lightdic[aa],'Sucrose_Light_biomass_M1':220})
    m1m2.SetReacsFixedRatio({aa+'_M2':-lightdic[aa],'Sucrose_Light_biomass_M2':220})

for aa in darkdic.keys():
    m1m2.SetReacsFixedRatio({aa+'_M1':-darkdic[aa],'Sucrose_Dark_biomass_M1':220})
    m1m2.SetReacsFixedRatio({aa+'_M2':-darkdic[aa],'Sucrose_Dark_biomass_M2':220})


m1m2.SetConstraints({'ATPase_Light_tx_M1':(-7.5,-7.5)})
m1m2.SetConstraints({'ATPase_Dark_tx_M1':(-7.5,-7.5)})
m1m2.SetConstraints({'ATPase_Light_tx_M2':(-7.5,-7.5)})
m1m2.SetConstraints({'ATPase_Dark_tx_M2':(-7.5,-7.5)})
# Out:
# 111
# RIBULOSE-BISPHOSPHATE-CARBOXYLASE-RXN_Dark_p_M1_RXN-961_Dark_p_M1_fixedratio is already in the model
# 222
# 333
# RXN-961_Light_p_M1_RIBULOSE-BISPHOSPHATE-CARBOXYLASE-RXN_Light_p_M1_fixedratio is already in the model
# 444
# NO3_Dark_tx_M1_NO3_Light_tx_M1_fixedratio is already in the model
# NO3_Light_tx_M2_NO3_Dark_tx_M2_fixedratio is already in the model
# ATPase_Light_tx_M1_NADPHoxc_Light_tx_M1_fixedratio is already in the model
# ATPase_Dark_tx_M1_NADPHoxc_Dark_tx_M1_fixedratio is already in the model
# ATPase_Light_tx_M1_NADPHoxm_Light_tx_M1_fixedratio is already in the model
# NADPHoxm_Dark_tx_M1_ATPase_Dark_tx_M1_fixedratio is already in the model
# ATPase_Dark_tx_M1_NADPHoxp_Dark_tx_M1_fixedratio is already in the model
# NADPHoxc_Light_tx_M2_ATPase_Light_tx_M2_fixedratio is already in the model
# NADPHoxc_Dark_tx_M2_ATPase_Dark_tx_M2_fixedratio is already in the model
# ATPase_Light_tx_M2_NADPHoxm_Light_tx_M2_fixedratio is already in the model
# NADPHoxm_Dark_tx_M2_ATPase_Dark_tx_M2_fixedratio is already in the model
# NADPHoxp_Light_tx_M2_ATPase_Light_tx_M2_fixedratio is already in the model
# NADPHoxp_Dark_tx_M2_ATPase_Dark_tx_M2_fixedratio is already in the model
# Sucrose_Dark_biomass_M1_Sucrose_Light_biomass_M1_fixedratio is already in the model
# Sucrose_Dark_biomass_M2_Sucrose_Light_biomass_M2_fixedratio is already in the model
# Glycine_Light_biomass_M1_Sucrose_Light_biomass_M1_fixedratio is already in the model
# Glycine_Light_biomass_M2_Sucrose_Light_biomass_M2_fixedratio is already in the model
# Glutamine_Light_biomass_M2_Sucrose_Light_biomass_M2_fixedratio is already in the model
# Sucrose_Light_biomass_M1_Methionine_Light_biomass_M1_fixedratio is already in the model
# Methionine_Light_biomass_M2_Sucrose_Light_biomass_M2_fixedratio is already in the model
# Sucrose_Light_biomass_M1_Leucine_Light_biomass_M1_fixedratio is already in the model
# Sucrose_Light_biomass_M2_Leucine_Light_biomass_M2_fixedratio is already in the model
# Histidine_Light_biomass_M1_Sucrose_Light_biomass_M1_fixedratio is already in the model
# Sucrose_Light_biomass_M2_Histidine_Light_biomass_M2_fixedratio is already in the model
# Valine_Light_biomass_M1_Sucrose_Light_biomass_M1_fixedratio is already in the model
# Sucrose_Light_biomass_M2_Valine_Light_biomass_M2_fixedratio is already in the model
# Isoleucine_Light_biomass_M1_Sucrose_Light_biomass_M1_fixedratio is already in the model
# Sucrose_Light_biomass_M2_Isoleucine_Light_biomass_M2_fixedratio is already in the model
# Sucrose_Light_biomass_M1_Alanine_Light_biomass_M1_fixedratio is already in the model
# Alanine_Light_biomass_M2_Sucrose_Light_biomass_M2_fixedratio is already in the model
# Sucrose_Light_biomass_M2_Aspartate_Light_biomass_M2_fixedratio is already in the model
# Sucrose_Light_biomass_M1_Serine_Light_biomass_M1_fixedratio is already in the model
# Serine_Light_biomass_M2_Sucrose_Light_biomass_M2_fixedratio is already in the model
# Sucrose_Light_biomass_M1_Tyrosine_Light_biomass_M1_fixedratio is already in the model
# Tyrosine_Light_biomass_M2_Sucrose_Light_biomass_M2_fixedratio is already in the model
# Sucrose_Light_biomass_M1_Lysine_Light_biomass_M1_fixedratio is already in the model
# Lysine_Light_biomass_M2_Sucrose_Light_biomass_M2_fixedratio is already in the model
# Sucrose_Light_biomass_M1_Phenylalanine_Light_biomass_M1_fixedratio is already in the model
# Sucrose_Light_biomass_M2_Phenylalanine_Light_biomass_M2_fixedratio is already in the model
# Arginine_Light_biomass_M1_Sucrose_Light_biomass_M1_fixedratio is already in the model
# Sucrose_Light_biomass_M2_Arginine_Light_biomass_M2_fixedratio is already in the model
# Sucrose_Light_biomass_M1_Tryptophan_Light_biomass_M1_fixedratio is already in the model
# Tryptophan_Light_biomass_M2_Sucrose_Light_biomass_M2_fixedratio is already in the model
# Glutamate_Light_biomass_M1_Sucrose_Light_biomass_M1_fixedratio is already in the model
# Sucrose_Light_biomass_M2_Glutamate_Light_biomass_M2_fixedratio is already in the model
# Sucrose_Light_biomass_M2_Asparagine_Light_biomass_M2_fixedratio is already in the model
# Sucrose_Light_biomass_M1_Threonine_Light_biomass_M1_fixedratio is already in the model
# Threonine_Light_biomass_M2_Sucrose_Light_biomass_M2_fixedratio is already in the model
# Sucrose_Dark_biomass_M1_Alanine_Dark_biomass_M1_fixedratio is already in the model
# Alanine_Dark_biomass_M2_Sucrose_Dark_biomass_M2_fixedratio is already in the model
# Sucrose_Dark_biomass_M1_Threonine_Dark_biomass_M1_fixedratio is already in the model
# Sucrose_Dark_biomass_M2_Threonine_Dark_biomass_M2_fixedratio is already in the model
# Sucrose_Dark_biomass_M1_Glutamine_Dark_biomass_M1_fixedratio is already in the model
# Sucrose_Dark_biomass_M1_Aspartate_Dark_biomass_M1_fixedratio is already in the model
# Sucrose_Dark_biomass_M2_Aspartate_Dark_biomass_M2_fixedratio is already in the model
# Sucrose_Dark_biomass_M1_Isoleucine_Dark_biomass_M1_fixedratio is already in the model
# Sucrose_Dark_biomass_M2_Isoleucine_Dark_biomass_M2_fixedratio is already in the model
# Sucrose_Dark_biomass_M1_Tyrosine_Dark_biomass_M1_fixedratio is already in the model
# Tyrosine_Dark_biomass_M2_Sucrose_Dark_biomass_M2_fixedratio is already in the model
# Sucrose_Dark_biomass_M1_Methionine_Dark_biomass_M1_fixedratio is already in the model
# Methionine_Dark_biomass_M2_Sucrose_Dark_biomass_M2_fixedratio is already in the model
# Sucrose_Dark_biomass_M1_Tryptophan_Dark_biomass_M1_fixedratio is already in the model
# Sucrose_Dark_biomass_M2_Tryptophan_Dark_biomass_M2_fixedratio is already in the model
# Sucrose_Dark_biomass_M1_Leucine_Dark_biomass_M1_fixedratio is already in the model
# Sucrose_Dark_biomass_M1_Glutamate_Dark_biomass_M1_fixedratio is already in the model
# Sucrose_Dark_biomass_M2_Glutamate_Dark_biomass_M2_fixedratio is already in the model
# Sucrose_Dark_biomass_M1_Glycine_Dark_biomass_M1_fixedratio is already in the model
# Sucrose_Dark_biomass_M2_Glycine_Dark_biomass_M2_fixedratio is already in the model
# Sucrose_Dark_biomass_M1_Phenylalanine_Dark_biomass_M1_fixedratio is already in the model
# Phenylalanine_Dark_biomass_M2_Sucrose_Dark_biomass_M2_fixedratio is already in the model
# Sucrose_Dark_biomass_M1_Lysine_Dark_biomass_M1_fixedratio is already in the model
# Sucrose_Dark_biomass_M2_Lysine_Dark_biomass_M2_fixedratio is already in the model
# Sucrose_Dark_biomass_M1_Valine_Dark_biomass_M1_fixedratio is already in the model
# Sucrose_Dark_biomass_M2_Valine_Dark_biomass_M2_fixedratio is already in the model
# Sucrose_Dark_biomass_M1_Serine_Dark_biomass_M1_fixedratio is already in the model
# Sucrose_Dark_biomass_M2_Serine_Dark_biomass_M2_fixedratio is already in the model
# Sucrose_Dark_biomass_M1_Asparagine_Dark_biomass_M1_fixedratio is already in the model
# Sucrose_Dark_biomass_M2_Asparagine_Dark_biomass_M2_fixedratio is already in the model
# Sucrose_Dark_biomass_M1_Arginine_Dark_biomass_M1_fixedratio is already in the model
# Sucrose_Dark_biomass_M2_Arginine_Dark_biomass_M2_fixedratio is already in the model
# Sucrose_Dark_biomass_M1_Histidine_Dark_biomass_M1_fixedratio is already in the model
# Histidine_Dark_biomass_M2_Sucrose_Dark_biomass_M2_fixedratio is already in the model

# %% [markdown]
# ## Cutting link for M1M2

# %%
# m1m2.SetConstraints({'Sucrose_Light_M1M2':(0,0)})
# m1m2.SetConstraints({'Sucrose_Dark_M1M2':(0,0)})

# AA_met = ['GLY','GLN','MET','LEU','HIS','VAL','ILE',
#          'L-ALPHA-ALANINE','L-ASPARTATE','SER','TYR','LYS','PHE',
#          'ARG','TRP','GLT','ASN','THR']

# for aa in AA_met:
#     m1m2.SetConstraints({aa+'_Light_M1M2':(0,0)})

# for aa in AA_met:
#     m1m2.SetConstraints({aa+'_Dark_M1M2':(0,0)})

# %% [markdown]
# ## Variable M1M2 constraints for photon and sucrose

# %%
m1m2.SetObjDirec('min')

m1m2.SetConstraints({'Photon_Light_tx_M1':(194,194)})
m1m2.SetConstraints({'Photon_Light_tx_M2':(194,194)})
m1m2.SetConstraints({'Sucrose_Light_biomass_M1':(0,0)})
m1m2.SetConstraints({'Sucrose_Dark_biomass_M1':(0,0)})
m1m2.SetObjective({'Sucrose_Light_biomass_M2'})
m1m2.SetObjective({'Sucrose_Dark_biomass_M2'})
m1m2.SetObjective({'Sucrose_Light_biomass_M1'})
m1m2.SetObjective({'Sucrose_Dark_biomass_M1'})
m1m2.MinFluxSolve()


sol_M1M2 = m1m2.GetSol(IncZeroes=True)
sol_M = m.GetSol(IncZeroes=True)

m1m2.PrintSol('Sucrose_Light_M1M2', IncZeroes=True)
m1m2.PrintSol('Sucrose_Dark_M1M2', IncZeroes=True)
m1m2.PrintSol('Photon_Light_tx_M1', IncZeroes=True)
m1m2.PrintSol('Photon_Light_tx_M2', IncZeroes=True)
m1m2.PrintSol('Sucrose_Light_biomass_M1', IncZeroes=True)
m1m2.PrintSol('Sucrose_Light_biomass_M2', IncZeroes=True)
m.PrintSol('Sucrose_Light_biomass',IncZeroes=True)


print "\n"
m1m2.PrintSol('MAL_Light_M1M2', IncZeroes=True)
sf.visualizeDataCategories(sol_M1M2,sol_M,writeData=True)
# Out:
# optimal
# Sucrose_Light_M1M2: 4.15825811326
# Sucrose_Dark_M1M2: -0.20036061944
# Photon_Light_tx_M1: 194.0
# Photon_Light_tx_M2: 194.0
# Sucrose_Light_biomass_M1: 0.0
# Sucrose_Light_biomass_M2: -0.873831161105
# Sucrose_Light_biomass: -0.513836512638
#
#
# MAL_Light_M1M2: 32.0
# EVOLUTIONARY RXN
#                              M        M1         M2
# GLY-DC_Lt_m           2.465415  1.000000   3.747743
# GLY-DC_Dk_m           0.005995  0.013372   0.000000
# PEPCase_Lt_c          0.236676  2.000000   0.000000
# PEPCase_Dk_c          0.000000  0.000000   0.000000
# CA_Lt_c               0.236676  2.000000   0.000000
# CA_Dk_c               0.000000  0.000000   0.000000
# Malate-DEH-RXN_Lt_c   0.470861 -0.475650  21.260369
# Malate-DEH-RXN_Dk_c  -0.701405 -0.013372  -1.153191
# NADP-ME_Lt_c          0.000000  0.000000   0.000000
# NADP-ME_Dk_c          0.000000  0.000000   0.134863
# Rubisco-Carbox_Lt_p  14.816315  0.000000  30.000000
# Rubisco-Carbox_Dk_p   0.000000  0.000000   0.000000
# Rubisco-Oxy_Lt_p      4.938772  0.000000  10.000000
# Rubisco-Oxy_Dk_p      0.000000  0.000000   0.000000
#
#
# GLYCOLYSIS
#                                  M         M1         M2
# Hexokinase_Lt_c           0.000000   0.000000   1.639599
# Hexokinase_Dk_c           0.000000   0.000000   0.661553
# Hexokinase_Lt_p           0.000000   0.000000   0.000000
# Hexokinase_Dk_p           0.000000   0.000000   0.000000
# Hexose_P_Isomerase_Lt_c   0.000000   0.000000  -4.929255
# Hexose_P_Isomerase_Dk_c   0.000000   0.000000  -4.929255
# Hexose_P_Isomerase_Lt_p  -1.201804  -4.875743   9.019948
# Hexose_P_Isomerase_Dk_p  -1.201804  -4.875743   9.019948
# PFK_Lt_c                  0.000000   0.000000   0.000000
# PFK_Dk_c                  0.000000   0.000000   0.000000
# PFK_Lt_p                  0.000000   0.000000   0.000000
# PFK_Dk_p                  0.026876   0.000000   0.000000
# F16_Aldolase_Lt_c        -0.685115  -3.957897  -4.929255
# F16_Aldolase_Dk_c         0.171279  -0.186988   0.491638
# F16_Aldolase_Lt_p        -7.793580  -4.406599  -4.035608
# F16_Aldolase_Dk_p         0.026876   0.000000   0.000000
# Triose_P_Isomerase_Lt_c   0.000000   0.000000   4.929255
# Triose_P_Isomerase_Dk_c  -0.171279   0.186988  -0.491638
# Triose_P_Isomerase_Lt_p  15.062375   8.364497  17.091164
# Triose_P_Isomerase_Dk_p  -0.026876   0.000000   0.000000
# GAPDH_Lt_c                0.000000   0.000000 -20.458563
# GAPDH_Dk_c                0.701405   0.013372   1.153191
# GAPDH_Lt_p                0.000000   0.000000   0.000000
# GAPDH_Dk_p                0.013438   0.000000   0.000000
# PG_Kinase_Lt_c            0.000000   0.000000  20.458563
# PG_Kinase_Dk_c           -0.701405  -0.013372  -1.153191
# PG_Kinase_Lt_p           38.269992  16.496540  36.637830
# PG_Kinase_Dk_p           -0.013438   0.000000   0.000000
# PG_Mutase_Lt_c            0.259332   0.000000   0.000000
# PG_Mutase_Dk_c            0.701405   0.013372   1.153191
# PG_Mutase_Lt_p            0.037370 -11.793680  12.903607
# PG_Mutase_Dk_p            0.013438   0.000000   0.000000
# Enolase_Lt_c              0.259332   0.000000   0.000000
# Enolase_Dk_c              0.701405   0.013372   1.153191
# Enolase_Lt_p              0.037370 -11.793680  12.903607
# Enolase_Dk_p              0.013438   0.000000   0.000000
# Pyruvate_Kinase_Lt_c      0.022656   0.000000   0.000000
# Pyruvate_Kinase_Dk_c      0.701405   0.013372   1.153191
# Pyruvate_Kinase_Lt_p      0.021176   0.000000  12.903607
# Pyruvate_Kinase_Dk_p      0.013438   0.000000   0.000000
#
#
# GLYCOLYSIS
#                                  M         M1         M2
# Hexokinase_Lt_c           0.000000   0.000000   1.639599
# Hexokinase_Dk_c           0.000000   0.000000   0.661553
# Hexokinase_Lt_p           0.000000   0.000000   0.000000
# Hexokinase_Dk_p           0.000000   0.000000   0.000000
# Hexose_P_Isomerase_Lt_c   0.000000   0.000000  -4.929255
# Hexose_P_Isomerase_Dk_c   0.000000   0.000000  -4.929255
# Hexose_P_Isomerase_Lt_p  -1.201804  -4.875743   9.019948
# Hexose_P_Isomerase_Dk_p  -1.201804  -4.875743   9.019948
# PFK_Lt_c                  0.000000   0.000000   0.000000
# PFK_Dk_c                  0.000000   0.000000   0.000000
# PFK_Lt_p                  0.000000   0.000000   0.000000
# PFK_Dk_p                  0.026876   0.000000   0.000000
# F16_Aldolase_Lt_c        -0.685115  -3.957897  -4.929255
# F16_Aldolase_Dk_c         0.171279  -0.186988   0.491638
# F16_Aldolase_Lt_p        -7.793580  -4.406599  -4.035608
# F16_Aldolase_Dk_p         0.026876   0.000000   0.000000
# Triose_P_Isomerase_Lt_c   0.000000   0.000000   4.929255
# Triose_P_Isomerase_Dk_c  -0.171279   0.186988  -0.491638
# Triose_P_Isomerase_Lt_p  15.062375   8.364497  17.091164
# Triose_P_Isomerase_Dk_p  -0.026876   0.000000   0.000000
# GAPDH_Lt_c                0.000000   0.000000 -20.458563
# GAPDH_Dk_c                0.701405   0.013372   1.153191
# GAPDH_Lt_p                0.000000   0.000000   0.000000
# GAPDH_Dk_p                0.013438   0.000000   0.000000
# PG_Kinase_Lt_c            0.000000   0.000000  20.458563
# PG_Kinase_Dk_c           -0.701405  -0.013372  -1.153191
# PG_Kinase_Lt_p           38.269992  16.496540  36.637830
# PG_Kinase_Dk_p           -0.013438   0.000000   0.000000
# PG_Mutase_Lt_c            0.259332   0.000000   0.000000
# PG_Mutase_Dk_c            0.701405   0.013372   1.153191
# PG_Mutase_Lt_p            0.037370 -11.793680  12.903607
# PG_Mutase_Dk_p            0.013438   0.000000   0.000000
# Enolase_Lt_c              0.259332   0.000000   0.000000
# Enolase_Dk_c              0.701405   0.013372   1.153191
# Enolase_Lt_p              0.037370 -11.793680  12.903607
# Enolase_Dk_p              0.013438   0.000000   0.000000
# Pyruvate_Kinase_Lt_c      0.022656   0.000000   0.000000
# Pyruvate_Kinase_Dk_c      0.701405   0.013372   1.153191
# Pyruvate_Kinase_Lt_p      0.021176   0.000000  12.903607
# Pyruvate_Kinase_Dk_p      0.013438   0.000000   0.000000
#
#
# PPP
#                                   M        M1         M2
# Hexose_P_Isomerase_Lt_p   -1.201804 -4.875743   9.019948
# Hexose_P_Isomerase_Dk_p   -0.610192 -0.774698  -0.339830
# Hexose_P_Isomerase_Lt_c    0.000000  0.000000  -4.929255
# Hexose_P_Isomerase_Dk_c    0.171279 -0.186988   0.000000
# Transadolase_Lt_p          0.000000  0.241456   0.000000
# Transadolase_Dk_p          0.318534  0.387349   0.169915
# 1_Transketolase_Lt_p       6.583679 -0.241456  13.055556
# 1_Transketolase_Dk_p      -0.318534 -0.387349  -0.169915
# 2_Transketolase_Lt_p      -6.591776  0.227687 -13.055556
# 2_Transketolase_Dk_p       0.318534  0.387349   0.169915
# Epimerase_Lt_p           -13.175456 -0.248341 -26.944444
# Epimerase_Dk_p             0.099534  0.029318   0.246752
# Epimerase_Lt_c             0.000000  0.717485   0.833333
# Epimerase_Dk_c             0.537533  0.745380   0.093079
# R5P_Isomerase_Lt_p         6.579631 -0.248341  13.055556
# R5P_Isomerase_Dk_p        -0.318534 -0.387349  -0.169915
# R5P_Isomerase_Lt_c         0.000000  0.000000   0.000000
# R5P_Isomerase_Dk_c         0.000000  0.000000   0.000000
# G6PDH1_Lt_p                0.000000  0.000000   0.000000
# G6PDH1_Dk_p                0.418068  0.416667   0.416667
# G6PDH1_Lt_c                0.000000  0.717485   0.833333
# G6PDH1_Dk_c                0.537533  0.745380   0.093079
# G6PDH2_Lt_p                0.000000  0.000000   0.000000
# G6PDH2_Dk_p                0.418068  0.416667   0.416667
# G6PDH2_Lt_c                0.000000  0.717485   0.833333
# G6PDH2_Dk_c                0.537533  0.745380   0.093079
# GLCNATE6P-DH_Lt_c          0.000000  0.717485   0.833333
# GLCNATE6P-DH_Dk_c          0.537533  0.745380   0.093079
# GLCNATE6P-DH_p_Lt_p        0.000000  0.000000   0.000000
# GLCNATE6P-DH_Dk_p          0.418068  0.416667   0.416667
#
#
# ETC
#                          M        M1         M2
# Complex_I_Lt_m    4.549938  0.000000  14.487374
# Complex_I_Dk_m    4.549938  0.000000  14.487374
# Complex II_Lt_m   0.000000  0.000000   0.000000
# Complex_II_Dk_m   0.556877  1.084038   0.419244
# Complex_III_Lt_m  2.274969  0.000000   7.243687
# Complex_III_Dk_m  1.596442  1.639429   1.810853
# Complex_IV_Lt_m   4.549938  0.000000  14.487374
# Complex_IV_Dk_m   3.192885  3.278858   3.621706
# AOX1              0.000000  0.000000   0.000000
# AOX1              0.000000  0.000000   0.000000
# AOX2              0.000000  0.000000   0.000000
# AOX2              0.000000  0.000000   0.000000
#
#
# PHOTOSYSTEMS
#                                     M         M1         M2
# PS-II_Lt_p                  24.250000  24.250000  24.250000
# PS-II_Dk_p                   0.000000   0.000000   0.000000
# PQuinol-PCyanin-Reduc_Lt_p  48.500000  48.500000  48.500000
# PQuinol-PCyanin-Reduc_Dk_p   0.000000   0.000000   0.000000
# PS-I_Lt_p                   97.000000  97.000000  97.000000
# PS-I_Dk_p                    0.000000   0.000000   0.000000
# Ferredoxin-Oxidase_Lt_p     44.254219  48.488879  37.509294
# Ferredoxin-Oxidase_Dk_p      0.000000   0.000000   0.000000
# Cyclic-PS_Lt_p               0.000000   0.000000   0.000000
# Cyclic-PS_Dk_p               0.000000   0.000000   0.000000
#
#
# BIOMASSES
#                                     M   M1        M2
# Sucrose_Light_biomass       -0.513837  0.0 -0.873831
# Sucrose_Dark_biomass        -0.171279  0.0 -0.291277
# Alanine_Light_biomass       -0.022656  0.0 -0.038528
# Alanine_Dark_biomass        -0.007552  0.0 -0.012843
# Arginine_Light_biomass      -0.003737  0.0 -0.006355
# Arginine_Dark_biomass       -0.001246  0.0 -0.002118
# Aspartate_Light_biomass     -0.022188  0.0 -0.037734
# Aspartate_Dark_biomass      -0.007396  0.0 -0.012578
# Glutamate_Light_biomass     -0.026626  0.0 -0.045280
# Glutamate_Dark_biomass      -0.008875  0.0 -0.015093
# Glutamine_Light_biomass     -0.077543  0.0 -0.131869
# Glutamine_Dark_biomass      -0.025848  0.0 -0.043956
# Glycine_Light_biomass       -0.001635  0.0 -0.002780
# Glycine_Dark_biomass        -0.000545  0.0 -0.000927
# Serine_Light_biomass        -0.017984  0.0 -0.030584
# Serine_Dark_biomass         -0.005995  0.0 -0.010195
# Tyrosine_Light_biomass      -0.001401  0.0 -0.002383
# Tyrosine_Dark_biomass       -0.000467  0.0 -0.000794
# Histidine_Light_biomass     -0.000934  0.0 -0.001589
# Histidine_Dark_biomass      -0.000311  0.0 -0.000530
# Isoleucine_Light_biomass    -0.002803  0.0 -0.004766
# Isoleucine_Dark_biomass     -0.000934  0.0 -0.001589
# Leucine_Light_biomass       -0.002803  0.0 -0.004766
# Leucine_Dark_biomass        -0.000934  0.0 -0.001589
# Lysine_Light_biomass        -0.004204  0.0 -0.007150
# Lysine_Dark_biomass         -0.001401  0.0 -0.002383
# Methionine_Light_biomass    -0.001635  0.0 -0.002780
# Methionine_Dark_biomass     -0.000545  0.0 -0.000927
# Phenylalanine_Light_biomass -0.002569  0.0 -0.004369
# Phenylalanine_Dark_biomass  -0.000856  0.0 -0.001456
# Threonine_Light_biomass     -0.013079  0.0 -0.022243
# Threonine_Dark_biomass      -0.004360  0.0 -0.007414
# Tryptophan_Light_biomass    -0.002102  0.0 -0.003575
# Tryptophan_Dark_biomass     -0.000701  0.0 -0.001192
# Valine_Light_biomass        -0.005605  0.0 -0.009533
# Valine_Dark_biomass         -0.001868  0.0 -0.003178
#
#
# _tx_rxn
#                       M         M1         M2
# CO2_Light_tx  12.454757  -2.810452  25.390325
# CO2_Dark_tx   -2.815495  -2.435363  -3.751967
# O2_Light_tx  -13.316873 -23.000000  -0.756313
# O2_Dark_tx     2.846442   2.889429   3.060853
#
#
# M1M2
#                                  M1M2
# Malate_Lt_M1M2              32.000000
# Malate_Dk_M1M2               0.000000
# Pyruvate_Lt_M1M2           -46.299255
# Pyruvate_Dk_M1M2             0.189278
# Sucrose_Light_M1M2           4.158258
# Sucrose_Dark_M1M2           -0.200361
# GLY_Light_M1M2              -2.477239
# GLY_Dark_M1M2               -0.026745
# MET_Light_M1M2               0.003707
# MET_Dark_M1M2                0.000000
# LEU_Light_M1M2               0.004766
# LEU_Dark_M1M2                0.001589
# HIS_Light_M1M2               0.001589
# HIS_Dark_M1M2                0.000530
# VAL_Light_M1M2              -0.006355
# VAL_Dark_M1M2                0.000000
# ILE_Light_M1M2               0.004766
# ILE_Dark_M1M2                0.001589
# L-ALPHA-ALANINE_Light_M1M2  33.481839
# L-ALPHA-ALANINE_Dark_M1M2   -0.122020
# L-ASPARTATE_Light_M1M2     -31.952734
# L-ASPARTATE_Dark_M1M2        1.070665
# SER_Light_M1M2              -3.717159
# SER_Dark_M1M2                0.013372
# TYR_Light_M1M2               0.002383
# TYR_Dark_M1M2                0.000794
# LYS_Light_M1M2               0.000000
# LYS_Dark_M1M2                0.000000
# PHE_Light_M1M2               0.004369
# PHE_Dark_M1M2                0.001456
# ARG_Light_M1M2               0.006355
# ARG_Dark_M1M2                0.002118
# TRP_Light_M1M2               0.004766
# TRP_Dark_M1M2                0.000000
# GLT_Light_M1M2              -3.990457
# GLT_Dark_M1M2               -0.908132
# ASN_Light_M1M2               0.040117
# ASN_Dark_M1M2                0.013372
# THR_Light_M1M2               0.022243
# THR_Dark_M1M2                0.007414

# %% [markdown]
# ## Step 1: Increased GDC activity in M2, reduced in M1

# %%
m1m2.SetConstraints({'GCVMULTI-RXN_Light_m_M1':(0,1.0)})
m1m2.SetConstraints({'GCVMULTI-RXN_Dark_m_M1':(0,1.0)})
m1m2.SetConstraints({'GCVMULTI-RXN_Light_m_M2':(0,4.0)})
m1m2.SetConstraints({'GCVMULTI-RXN_Dark_m_M2':(0,4.0)})
m1m2.MinFluxSolve()


sol_M1M2 = m1m2.GetSol(IncZeroes=True)
sol_M = m.GetSol(IncZeroes=True)

sf.visualizeDataCategories(sol_M1M2,sol_M,writeData=True)
# Out:
# optimal
# EVOLUTIONARY RXN
#                              M        M1         M2
# GLY-DC_Lt_m           2.465415  1.000000   3.747743
# GLY-DC_Dk_m           0.005995  0.013372   0.000000
# PEPCase_Lt_c          0.236676  2.000000   0.000000
# PEPCase_Dk_c          0.000000  0.000000   0.000000
# CA_Lt_c               0.236676  2.000000   0.000000
# CA_Dk_c               0.000000  0.000000   0.000000
# Malate-DEH-RXN_Lt_c   0.470861 -0.475650  21.260369
# Malate-DEH-RXN_Dk_c  -0.701405 -0.013372  -1.153191
# NADP-ME_Lt_c          0.000000  0.000000   0.000000
# NADP-ME_Dk_c          0.000000  0.000000   0.134863
# Rubisco-Carbox_Lt_p  14.816315  0.000000  30.000000
# Rubisco-Carbox_Dk_p   0.000000  0.000000   0.000000
# Rubisco-Oxy_Lt_p      4.938772  0.000000  10.000000
# Rubisco-Oxy_Dk_p      0.000000  0.000000   0.000000
#
#
# GLYCOLYSIS
#                                  M         M1         M2
# Hexokinase_Lt_c           0.000000   0.000000   1.639599
# Hexokinase_Dk_c           0.000000   0.000000   0.661553
# Hexokinase_Lt_p           0.000000   0.000000   0.000000
# Hexokinase_Dk_p           0.000000   0.000000   0.000000
# Hexose_P_Isomerase_Lt_c   0.000000   0.000000  -4.929255
# Hexose_P_Isomerase_Dk_c   0.000000   0.000000  -4.929255
# Hexose_P_Isomerase_Lt_p  -1.201804  -4.875743   9.019948
# Hexose_P_Isomerase_Dk_p  -1.201804  -4.875743   9.019948
# PFK_Lt_c                  0.000000   0.000000   0.000000
# PFK_Dk_c                  0.000000   0.000000   0.000000
# PFK_Lt_p                  0.000000   0.000000   0.000000
# PFK_Dk_p                  0.026876   0.000000   0.000000
# F16_Aldolase_Lt_c        -0.685115  -3.957897  -4.929255
# F16_Aldolase_Dk_c         0.171279  -0.186988   0.491638
# F16_Aldolase_Lt_p        -7.793580  -4.406599  -4.035608
# F16_Aldolase_Dk_p         0.026876   0.000000   0.000000
# Triose_P_Isomerase_Lt_c   0.000000   0.000000   4.929255
# Triose_P_Isomerase_Dk_c  -0.171279   0.186988  -0.491638
# Triose_P_Isomerase_Lt_p  15.062375   8.364497  17.091164
# Triose_P_Isomerase_Dk_p  -0.026876   0.000000   0.000000
# GAPDH_Lt_c                0.000000   0.000000 -20.458563
# GAPDH_Dk_c                0.701405   0.013372   1.153191
# GAPDH_Lt_p                0.000000   0.000000   0.000000
# GAPDH_Dk_p                0.013438   0.000000   0.000000
# PG_Kinase_Lt_c            0.000000   0.000000  20.458563
# PG_Kinase_Dk_c           -0.701405  -0.013372  -1.153191
# PG_Kinase_Lt_p           38.269992  16.496540  36.637830
# PG_Kinase_Dk_p           -0.013438   0.000000   0.000000
# PG_Mutase_Lt_c            0.259332   0.000000   0.000000
# PG_Mutase_Dk_c            0.701405   0.013372   1.153191
# PG_Mutase_Lt_p            0.037370 -11.793680  12.903607
# PG_Mutase_Dk_p            0.013438   0.000000   0.000000
# Enolase_Lt_c              0.259332   0.000000   0.000000
# Enolase_Dk_c              0.701405   0.013372   1.153191
# Enolase_Lt_p              0.037370 -11.793680  12.903607
# Enolase_Dk_p              0.013438   0.000000   0.000000
# Pyruvate_Kinase_Lt_c      0.022656   0.000000   0.000000
# Pyruvate_Kinase_Dk_c      0.701405   0.013372   1.153191
# Pyruvate_Kinase_Lt_p      0.021176   0.000000  12.903607
# Pyruvate_Kinase_Dk_p      0.013438   0.000000   0.000000
#
#
# GLYCOLYSIS
#                                  M         M1         M2
# Hexokinase_Lt_c           0.000000   0.000000   1.639599
# Hexokinase_Dk_c           0.000000   0.000000   0.661553
# Hexokinase_Lt_p           0.000000   0.000000   0.000000
# Hexokinase_Dk_p           0.000000   0.000000   0.000000
# Hexose_P_Isomerase_Lt_c   0.000000   0.000000  -4.929255
# Hexose_P_Isomerase_Dk_c   0.000000   0.000000  -4.929255
# Hexose_P_Isomerase_Lt_p  -1.201804  -4.875743   9.019948
# Hexose_P_Isomerase_Dk_p  -1.201804  -4.875743   9.019948
# PFK_Lt_c                  0.000000   0.000000   0.000000
# PFK_Dk_c                  0.000000   0.000000   0.000000
# PFK_Lt_p                  0.000000   0.000000   0.000000
# PFK_Dk_p                  0.026876   0.000000   0.000000
# F16_Aldolase_Lt_c        -0.685115  -3.957897  -4.929255
# F16_Aldolase_Dk_c         0.171279  -0.186988   0.491638
# F16_Aldolase_Lt_p        -7.793580  -4.406599  -4.035608
# F16_Aldolase_Dk_p         0.026876   0.000000   0.000000
# Triose_P_Isomerase_Lt_c   0.000000   0.000000   4.929255
# Triose_P_Isomerase_Dk_c  -0.171279   0.186988  -0.491638
# Triose_P_Isomerase_Lt_p  15.062375   8.364497  17.091164
# Triose_P_Isomerase_Dk_p  -0.026876   0.000000   0.000000
# GAPDH_Lt_c                0.000000   0.000000 -20.458563
# GAPDH_Dk_c                0.701405   0.013372   1.153191
# GAPDH_Lt_p                0.000000   0.000000   0.000000
# GAPDH_Dk_p                0.013438   0.000000   0.000000
# PG_Kinase_Lt_c            0.000000   0.000000  20.458563
# PG_Kinase_Dk_c           -0.701405  -0.013372  -1.153191
# PG_Kinase_Lt_p           38.269992  16.496540  36.637830
# PG_Kinase_Dk_p           -0.013438   0.000000   0.000000
# PG_Mutase_Lt_c            0.259332   0.000000   0.000000
# PG_Mutase_Dk_c            0.701405   0.013372   1.153191
# PG_Mutase_Lt_p            0.037370 -11.793680  12.903607
# PG_Mutase_Dk_p            0.013438   0.000000   0.000000
# Enolase_Lt_c              0.259332   0.000000   0.000000
# Enolase_Dk_c              0.701405   0.013372   1.153191
# Enolase_Lt_p              0.037370 -11.793680  12.903607
# Enolase_Dk_p              0.013438   0.000000   0.000000
# Pyruvate_Kinase_Lt_c      0.022656   0.000000   0.000000
# Pyruvate_Kinase_Dk_c      0.701405   0.013372   1.153191
# Pyruvate_Kinase_Lt_p      0.021176   0.000000  12.903607
# Pyruvate_Kinase_Dk_p      0.013438   0.000000   0.000000
#
#
# PPP
#                                   M        M1         M2
# Hexose_P_Isomerase_Lt_p   -1.201804 -4.875743   9.019948
# Hexose_P_Isomerase_Dk_p   -0.610192 -0.774698  -0.339830
# Hexose_P_Isomerase_Lt_c    0.000000  0.000000  -4.929255
# Hexose_P_Isomerase_Dk_c    0.171279 -0.186988   0.000000
# Transadolase_Lt_p          0.000000  0.241456   0.000000
# Transadolase_Dk_p          0.318534  0.387349   0.169915
# 1_Transketolase_Lt_p       6.583679 -0.241456  13.055556
# 1_Transketolase_Dk_p      -0.318534 -0.387349  -0.169915
# 2_Transketolase_Lt_p      -6.591776  0.227687 -13.055556
# 2_Transketolase_Dk_p       0.318534  0.387349   0.169915
# Epimerase_Lt_p           -13.175456 -0.248341 -26.944444
# Epimerase_Dk_p             0.099534  0.029318   0.246752
# Epimerase_Lt_c             0.000000  0.717485   0.833333
# Epimerase_Dk_c             0.537533  0.745380   0.093079
# R5P_Isomerase_Lt_p         6.579631 -0.248341  13.055556
# R5P_Isomerase_Dk_p        -0.318534 -0.387349  -0.169915
# R5P_Isomerase_Lt_c         0.000000  0.000000   0.000000
# R5P_Isomerase_Dk_c         0.000000  0.000000   0.000000
# G6PDH1_Lt_p                0.000000  0.000000   0.000000
# G6PDH1_Dk_p                0.418068  0.416667   0.416667
# G6PDH1_Lt_c                0.000000  0.717485   0.833333
# G6PDH1_Dk_c                0.537533  0.745380   0.093079
# G6PDH2_Lt_p                0.000000  0.000000   0.000000
# G6PDH2_Dk_p                0.418068  0.416667   0.416667
# G6PDH2_Lt_c                0.000000  0.717485   0.833333
# G6PDH2_Dk_c                0.537533  0.745380   0.093079
# GLCNATE6P-DH_Lt_c          0.000000  0.717485   0.833333
# GLCNATE6P-DH_Dk_c          0.537533  0.745380   0.093079
# GLCNATE6P-DH_p_Lt_p        0.000000  0.000000   0.000000
# GLCNATE6P-DH_Dk_p          0.418068  0.416667   0.416667
#
#
# ETC
#                          M        M1         M2
# Complex_I_Lt_m    4.549938  0.000000  14.487374
# Complex_I_Dk_m    4.549938  0.000000  14.487374
# Complex II_Lt_m   0.000000  0.000000   0.000000
# Complex_II_Dk_m   0.556877  1.084038   0.419244
# Complex_III_Lt_m  2.274969  0.000000   7.243687
# Complex_III_Dk_m  1.596442  1.639429   1.810853
# Complex_IV_Lt_m   4.549938  0.000000  14.487374
# Complex_IV_Dk_m   3.192885  3.278858   3.621706
# AOX1              0.000000  0.000000   0.000000
# AOX1              0.000000  0.000000   0.000000
# AOX2              0.000000  0.000000   0.000000
# AOX2              0.000000  0.000000   0.000000
#
#
# PHOTOSYSTEMS
#                                     M         M1         M2
# PS-II_Lt_p                  24.250000  24.250000  24.250000
# PS-II_Dk_p                   0.000000   0.000000   0.000000
# PQuinol-PCyanin-Reduc_Lt_p  48.500000  48.500000  48.500000
# PQuinol-PCyanin-Reduc_Dk_p   0.000000   0.000000   0.000000
# PS-I_Lt_p                   97.000000  97.000000  97.000000
# PS-I_Dk_p                    0.000000   0.000000   0.000000
# Ferredoxin-Oxidase_Lt_p     44.254219  48.488879  37.509294
# Ferredoxin-Oxidase_Dk_p      0.000000   0.000000   0.000000
# Cyclic-PS_Lt_p               0.000000   0.000000   0.000000
# Cyclic-PS_Dk_p               0.000000   0.000000   0.000000
#
#
# BIOMASSES
#                                     M   M1        M2
# Sucrose_Light_biomass       -0.513837  0.0 -0.873831
# Sucrose_Dark_biomass        -0.171279  0.0 -0.291277
# Alanine_Light_biomass       -0.022656  0.0 -0.038528
# Alanine_Dark_biomass        -0.007552  0.0 -0.012843
# Arginine_Light_biomass      -0.003737  0.0 -0.006355
# Arginine_Dark_biomass       -0.001246  0.0 -0.002118
# Aspartate_Light_biomass     -0.022188  0.0 -0.037734
# Aspartate_Dark_biomass      -0.007396  0.0 -0.012578
# Glutamate_Light_biomass     -0.026626  0.0 -0.045280
# Glutamate_Dark_biomass      -0.008875  0.0 -0.015093
# Glutamine_Light_biomass     -0.077543  0.0 -0.131869
# Glutamine_Dark_biomass      -0.025848  0.0 -0.043956
# Glycine_Light_biomass       -0.001635  0.0 -0.002780
# Glycine_Dark_biomass        -0.000545  0.0 -0.000927
# Serine_Light_biomass        -0.017984  0.0 -0.030584
# Serine_Dark_biomass         -0.005995  0.0 -0.010195
# Tyrosine_Light_biomass      -0.001401  0.0 -0.002383
# Tyrosine_Dark_biomass       -0.000467  0.0 -0.000794
# Histidine_Light_biomass     -0.000934  0.0 -0.001589
# Histidine_Dark_biomass      -0.000311  0.0 -0.000530
# Isoleucine_Light_biomass    -0.002803  0.0 -0.004766
# Isoleucine_Dark_biomass     -0.000934  0.0 -0.001589
# Leucine_Light_biomass       -0.002803  0.0 -0.004766
# Leucine_Dark_biomass        -0.000934  0.0 -0.001589
# Lysine_Light_biomass        -0.004204  0.0 -0.007150
# Lysine_Dark_biomass         -0.001401  0.0 -0.002383
# Methionine_Light_biomass    -0.001635  0.0 -0.002780
# Methionine_Dark_biomass     -0.000545  0.0 -0.000927
# Phenylalanine_Light_biomass -0.002569  0.0 -0.004369
# Phenylalanine_Dark_biomass  -0.000856  0.0 -0.001456
# Threonine_Light_biomass     -0.013079  0.0 -0.022243
# Threonine_Dark_biomass      -0.004360  0.0 -0.007414
# Tryptophan_Light_biomass    -0.002102  0.0 -0.003575
# Tryptophan_Dark_biomass     -0.000701  0.0 -0.001192
# Valine_Light_biomass        -0.005605  0.0 -0.009533
# Valine_Dark_biomass         -0.001868  0.0 -0.003178
#
#
# _tx_rxn
#                       M         M1         M2
# CO2_Light_tx  12.454757  -2.810452  25.390325
# CO2_Dark_tx   -2.815495  -2.435363  -3.751967
# O2_Light_tx  -13.316873 -23.000000  -0.756313
# O2_Dark_tx     2.846442   2.889429   3.060853
#
#
# M1M2
#                                  M1M2
# Malate_Lt_M1M2              32.000000
# Malate_Dk_M1M2               0.000000
# Pyruvate_Lt_M1M2           -46.299255
# Pyruvate_Dk_M1M2             0.189278
# Sucrose_Light_M1M2           4.158258
# Sucrose_Dark_M1M2           -0.200361
# GLY_Light_M1M2              -2.477239
# GLY_Dark_M1M2               -0.026745
# MET_Light_M1M2               0.003707
# MET_Dark_M1M2                0.000000
# LEU_Light_M1M2               0.004766
# LEU_Dark_M1M2                0.001589
# HIS_Light_M1M2               0.001589
# HIS_Dark_M1M2                0.000530
# VAL_Light_M1M2              -0.006355
# VAL_Dark_M1M2                0.000000
# ILE_Light_M1M2               0.004766
# ILE_Dark_M1M2                0.001589
# L-ALPHA-ALANINE_Light_M1M2  33.481839
# L-ALPHA-ALANINE_Dark_M1M2   -0.122020
# L-ASPARTATE_Light_M1M2     -31.952734
# L-ASPARTATE_Dark_M1M2        1.070665
# SER_Light_M1M2              -3.717159
# SER_Dark_M1M2                0.013372
# TYR_Light_M1M2               0.002383
# TYR_Dark_M1M2                0.000794
# LYS_Light_M1M2               0.000000
# LYS_Dark_M1M2                0.000000
# PHE_Light_M1M2               0.004369
# PHE_Dark_M1M2                0.001456
# ARG_Light_M1M2               0.006355
# ARG_Dark_M1M2                0.002118
# TRP_Light_M1M2               0.004766
# TRP_Dark_M1M2                0.000000
# GLT_Light_M1M2              -3.990457
# GLT_Dark_M1M2               -0.908132
# ASN_Light_M1M2               0.040117
# ASN_Dark_M1M2                0.013372
# THR_Light_M1M2               0.022243
# THR_Dark_M1M2                0.007414

# %% [markdown]
# ## Step 2: Increased PEPCase/PPDK activity in M1

# %%
#Ok so right now just increasing PEPCase doesnt exactly 
m1m2.SetConstraints({'PEPCARBOX-RXN_Light_c_M1':(4.0,None)})
m1m2.SetConstraints({'PEPCARBOX-RXN_Light_c_M2':(0,0)})
m1m2.MinFluxSolve()


sol_M1M2 = m1m2.GetSol(IncZeroes=True)
sol_M = m.GetSol(IncZeroes=True)

sf.visualizeDataCategories(sol_M1M2,sol_M,writeData=True)
# Out:
# optimal
# EVOLUTIONARY RXN
#                              M        M1         M2
# GLY-DC_Lt_m           2.465415  1.000000   3.692389
# GLY-DC_Dk_m           0.005995  0.013230   0.000000
# PEPCase_Lt_c          0.236676  4.000000   0.000000
# PEPCase_Dk_c          0.000000  0.000000   0.000000
# CA_Lt_c               0.236676  4.000000   0.000000
# CA_Dk_c               0.000000  0.000000   0.000000
# Malate-DEH-RXN_Lt_c   0.470861 -0.586667  20.822526
# Malate-DEH-RXN_Dk_c  -0.701405 -0.013230  -1.144911
# NADP-ME_Lt_c          0.000000  0.000000   0.000000
# NADP-ME_Dk_c          0.000000  0.000000   0.141832
# Rubisco-Carbox_Lt_p  14.816315  0.000000  30.000000
# Rubisco-Carbox_Dk_p   0.000000  0.000000   0.000000
# Rubisco-Oxy_Lt_p      4.938772  0.000000  10.000000
# Rubisco-Oxy_Dk_p      0.000000  0.000000   0.000000
#
#
# GLYCOLYSIS
#                                  M         M1         M2
# Hexokinase_Lt_c           0.000000   0.000000   0.000000
# Hexokinase_Dk_c           0.000000   0.000000   0.656993
# Hexokinase_Lt_p           0.000000   0.000000   0.000000
# Hexokinase_Dk_p           0.000000   0.000000   0.000000
# Hexose_P_Isomerase_Lt_c   0.000000   0.000000  -6.320928
# Hexose_P_Isomerase_Dk_c   0.000000   0.000000  -6.320928
# Hexose_P_Isomerase_Lt_p  -1.201804  -4.743704   8.648059
# Hexose_P_Isomerase_Dk_p  -1.201804  -4.743704   8.648059
# PFK_Lt_c                  0.000000   0.000000   0.000000
# PFK_Dk_c                  0.000000   0.000000   0.000000
# PFK_Lt_p                  0.000000   0.000000   0.000000
# PFK_Dk_p                  0.026876   0.000000   0.000000
# F16_Aldolase_Lt_c        -0.685115  -3.825240  -4.793294
# F16_Aldolase_Dk_c         0.171279  -0.186515   0.487919
# F16_Aldolase_Lt_p        -7.793580  -4.273640  -4.407496
# F16_Aldolase_Dk_p         0.026876   0.000000   0.000000
# Triose_P_Isomerase_Lt_c   0.000000   0.000000   4.793294
# Triose_P_Isomerase_Dk_c  -0.171279   0.186515  -0.487919
# Triose_P_Isomerase_Lt_p  15.062375   8.098879  17.463052
# Triose_P_Isomerase_Dk_p  -0.026876   0.000000   0.000000
# GAPDH_Lt_c                0.000000   0.000000 -20.029263
# GAPDH_Dk_c                0.701405   0.013230   1.144911
# GAPDH_Lt_p                0.000000   0.000000   0.000000
# GAPDH_Dk_p                0.013438   0.000000   0.000000
# PG_Kinase_Lt_c            0.000000   0.000000  20.029263
# PG_Kinase_Dk_c           -0.701405  -0.013230  -1.144911
# PG_Kinase_Lt_p           38.269992  15.964822  37.538985
# PG_Kinase_Dk_p           -0.013438   0.000000   0.000000
# PG_Mutase_Lt_c            0.259332  -0.058683   0.000000
# PG_Mutase_Dk_c            0.701405   0.013230   1.144911
# PG_Mutase_Lt_p            0.037370 -11.258156  12.431753
# PG_Mutase_Dk_p            0.013438   0.000000   0.000000
# Enolase_Lt_c              0.259332  -0.058683   0.000000
# Enolase_Dk_c              0.701405   0.013230   1.144911
# Enolase_Lt_p              0.037370 -11.258156  12.431753
# Enolase_Dk_p              0.013438   0.000000   0.000000
# Pyruvate_Kinase_Lt_c      0.022656   0.000000   0.000000
# Pyruvate_Kinase_Dk_c      0.701405   0.013230   1.144911
# Pyruvate_Kinase_Lt_p      0.021176   0.000000  12.431753
# Pyruvate_Kinase_Dk_p      0.013438   0.000000   0.000000
#
#
# GLYCOLYSIS
#                                  M         M1         M2
# Hexokinase_Lt_c           0.000000   0.000000   0.000000
# Hexokinase_Dk_c           0.000000   0.000000   0.656993
# Hexokinase_Lt_p           0.000000   0.000000   0.000000
# Hexokinase_Dk_p           0.000000   0.000000   0.000000
# Hexose_P_Isomerase_Lt_c   0.000000   0.000000  -6.320928
# Hexose_P_Isomerase_Dk_c   0.000000   0.000000  -6.320928
# Hexose_P_Isomerase_Lt_p  -1.201804  -4.743704   8.648059
# Hexose_P_Isomerase_Dk_p  -1.201804  -4.743704   8.648059
# PFK_Lt_c                  0.000000   0.000000   0.000000
# PFK_Dk_c                  0.000000   0.000000   0.000000
# PFK_Lt_p                  0.000000   0.000000   0.000000
# PFK_Dk_p                  0.026876   0.000000   0.000000
# F16_Aldolase_Lt_c        -0.685115  -3.825240  -4.793294
# F16_Aldolase_Dk_c         0.171279  -0.186515   0.487919
# F16_Aldolase_Lt_p        -7.793580  -4.273640  -4.407496
# F16_Aldolase_Dk_p         0.026876   0.000000   0.000000
# Triose_P_Isomerase_Lt_c   0.000000   0.000000   4.793294
# Triose_P_Isomerase_Dk_c  -0.171279   0.186515  -0.487919
# Triose_P_Isomerase_Lt_p  15.062375   8.098879  17.463052
# Triose_P_Isomerase_Dk_p  -0.026876   0.000000   0.000000
# GAPDH_Lt_c                0.000000   0.000000 -20.029263
# GAPDH_Dk_c                0.701405   0.013230   1.144911
# GAPDH_Lt_p                0.000000   0.000000   0.000000
# GAPDH_Dk_p                0.013438   0.000000   0.000000
# PG_Kinase_Lt_c            0.000000   0.000000  20.029263
# PG_Kinase_Dk_c           -0.701405  -0.013230  -1.144911
# PG_Kinase_Lt_p           38.269992  15.964822  37.538985
# PG_Kinase_Dk_p           -0.013438   0.000000   0.000000
# PG_Mutase_Lt_c            0.259332  -0.058683   0.000000
# PG_Mutase_Dk_c            0.701405   0.013230   1.144911
# PG_Mutase_Lt_p            0.037370 -11.258156  12.431753
# PG_Mutase_Dk_p            0.013438   0.000000   0.000000
# Enolase_Lt_c              0.259332  -0.058683   0.000000
# Enolase_Dk_c              0.701405   0.013230   1.144911
# Enolase_Lt_p              0.037370 -11.258156  12.431753
# Enolase_Dk_p              0.013438   0.000000   0.000000
# Pyruvate_Kinase_Lt_c      0.022656   0.000000   0.000000
# Pyruvate_Kinase_Dk_c      0.701405   0.013230   1.144911
# Pyruvate_Kinase_Lt_p      0.021176   0.000000  12.431753
# Pyruvate_Kinase_Dk_p      0.013438   0.000000   0.000000
#
#
# PPP
#                                   M        M1         M2
# Hexose_P_Isomerase_Lt_p   -1.201804 -4.743704   8.648059
# Hexose_P_Isomerase_Dk_p   -0.610192 -0.772520  -0.338148
# Hexose_P_Isomerase_Lt_c    0.000000  0.000000  -6.320928
# Hexose_P_Isomerase_Dk_c    0.171279 -0.186515   0.000000
# Transadolase_Lt_p          0.000000  0.241843   0.000000
# Transadolase_Dk_p          0.318534  0.386260   0.169074
# 1_Transketolase_Lt_p       6.583679 -0.241843  13.055556
# 1_Transketolase_Dk_p      -0.318534 -0.386260  -0.169074
# 2_Transketolase_Lt_p      -6.591776  0.228221 -13.055556
# 2_Transketolase_Dk_p       0.318534  0.386260   0.169074
# Epimerase_Lt_p           -13.175456 -0.248655 -26.944444
# Epimerase_Dk_p             0.099534  0.030406   0.247593
# Epimerase_Lt_c             0.000000  0.718719   0.833333
# Epimerase_Dk_c             0.537533  0.742114   0.090556
# R5P_Isomerase_Lt_p         6.579631 -0.248655  13.055556
# R5P_Isomerase_Dk_p        -0.318534 -0.386260  -0.169074
# R5P_Isomerase_Lt_c         0.000000  0.000000   0.000000
# R5P_Isomerase_Dk_c         0.000000  0.000000   0.000000
# G6PDH1_Lt_p                0.000000  0.000000   0.000000
# G6PDH1_Dk_p                0.418068  0.416667   0.416667
# G6PDH1_Lt_c                0.000000  0.718719   0.833333
# G6PDH1_Dk_c                0.537533  0.742114   0.090556
# G6PDH2_Lt_p                0.000000  0.000000   0.000000
# G6PDH2_Dk_p                0.418068  0.416667   0.416667
# G6PDH2_Lt_c                0.000000  0.718719   0.833333
# G6PDH2_Dk_c                0.537533  0.742114   0.090556
# GLCNATE6P-DH_Lt_c          0.000000  0.718719   0.833333
# GLCNATE6P-DH_Dk_c          0.537533  0.742114   0.090556
# GLCNATE6P-DH_p_Lt_p        0.000000  0.000000   0.000000
# GLCNATE6P-DH_Dk_p          0.418068  0.416667   0.416667
#
#
# ETC
#                          M        M1         M2
# Complex_I_Lt_m    4.549938  0.000000  14.869863
# Complex_I_Dk_m    4.549938  0.000000  14.869863
# Complex II_Lt_m   0.000000  0.000000   0.000000
# Complex_II_Dk_m   0.556877  1.084180   0.423905
# Complex_III_Lt_m  2.274969  0.000000   7.434931
# Complex_III_Dk_m  1.596442  1.639500   1.809259
# Complex_IV_Lt_m   4.549938  0.000000  14.869863
# Complex_IV_Dk_m   3.192885  3.279001   3.618517
# AOX1              0.000000  0.000000   0.000000
# AOX1              0.000000  0.000000   0.000000
# AOX2              0.000000  0.000000   0.000000
# AOX2              0.000000  0.000000   0.000000
#
#
# PHOTOSYSTEMS
#                                     M         M1         M2
# PS-II_Lt_p                  24.250000  24.250000  24.250000
# PS-II_Dk_p                   0.000000   0.000000   0.000000
# PQuinol-PCyanin-Reduc_Lt_p  48.500000  48.500000  48.500000
# PQuinol-PCyanin-Reduc_Dk_p   0.000000   0.000000   0.000000
# PS-I_Lt_p                   97.000000  97.000000  97.000000
# PS-I_Dk_p                    0.000000   0.000000   0.000000
# Ferredoxin-Oxidase_Lt_p     44.254219  48.488997  38.410042
# Ferredoxin-Oxidase_Dk_p      0.000000   0.000000   0.000000
# Cyclic-PS_Lt_p               0.000000   0.000000   0.000000
# Cyclic-PS_Dk_p               0.000000   0.000000   0.000000
#
#
# BIOMASSES
#                                     M   M1        M2
# Sucrose_Light_biomass       -0.513837  0.0 -0.864521
# Sucrose_Dark_biomass        -0.171279  0.0 -0.288174
# Alanine_Light_biomass       -0.022656  0.0 -0.038117
# Alanine_Dark_biomass        -0.007552  0.0 -0.012706
# Arginine_Light_biomass      -0.003737  0.0 -0.006287
# Arginine_Dark_biomass       -0.001246  0.0 -0.002096
# Aspartate_Light_biomass     -0.022188  0.0 -0.037332
# Aspartate_Dark_biomass      -0.007396  0.0 -0.012444
# Glutamate_Light_biomass     -0.026626  0.0 -0.044798
# Glutamate_Dark_biomass      -0.008875  0.0 -0.014933
# Glutamine_Light_biomass     -0.077543  0.0 -0.130464
# Glutamine_Dark_biomass      -0.025848  0.0 -0.043488
# Glycine_Light_biomass       -0.001635  0.0 -0.002751
# Glycine_Dark_biomass        -0.000545  0.0 -0.000917
# Serine_Light_biomass        -0.017984  0.0 -0.030258
# Serine_Dark_biomass         -0.005995  0.0 -0.010086
# Tyrosine_Light_biomass      -0.001401  0.0 -0.002358
# Tyrosine_Dark_biomass       -0.000467  0.0 -0.000786
# Histidine_Light_biomass     -0.000934  0.0 -0.001572
# Histidine_Dark_biomass      -0.000311  0.0 -0.000524
# Isoleucine_Light_biomass    -0.002803  0.0 -0.004716
# Isoleucine_Dark_biomass     -0.000934  0.0 -0.001572
# Leucine_Light_biomass       -0.002803  0.0 -0.004716
# Leucine_Dark_biomass        -0.000934  0.0 -0.001572
# Lysine_Light_biomass        -0.004204  0.0 -0.007073
# Lysine_Dark_biomass         -0.001401  0.0 -0.002358
# Methionine_Light_biomass    -0.001635  0.0 -0.002751
# Methionine_Dark_biomass     -0.000545  0.0 -0.000917
# Phenylalanine_Light_biomass -0.002569  0.0 -0.004323
# Phenylalanine_Dark_biomass  -0.000856  0.0 -0.001441
# Threonine_Light_biomass     -0.013079  0.0 -0.022006
# Threonine_Dark_biomass      -0.004360  0.0 -0.007335
# Tryptophan_Light_biomass    -0.002102  0.0 -0.003537
# Tryptophan_Dark_biomass     -0.000701  0.0 -0.001179
# Valine_Light_biomass        -0.005605  0.0 -0.009431
# Valine_Dark_biomass         -0.001868  0.0 -0.003144
#
#
# _tx_rxn
#                       M         M1         M2
# CO2_Light_tx  12.454757  -3.032211  25.445985
# CO2_Dark_tx   -2.815495  -2.438629  -3.757262
# O2_Light_tx  -13.316873 -23.000000  -0.565069
# O2_Dark_tx     2.846442   2.889500   3.059259
#
#
# M1M2
#                                  M1M2
# Malate_Lt_M1M2              32.000000
# Malate_Dk_M1M2               0.000000
# Pyruvate_Lt_M1M2           -46.702722
# Pyruvate_Dk_M1M2             0.195668
# Sucrose_Light_M1M2           4.024985
# Sucrose_Dark_M1M2           -0.199745
# GLY_Light_M1M2              -2.588239
# GLY_Dark_M1M2               -0.026460
# MET_Light_M1M2               0.002751
# MET_Dark_M1M2                0.000917
# LEU_Light_M1M2               0.004716
# LEU_Dark_M1M2                0.001572
# HIS_Light_M1M2               0.001572
# HIS_Dark_M1M2                0.000524
# VAL_Light_M1M2              -0.006287
# VAL_Dark_M1M2                0.000000
# ILE_Light_M1M2               0.006287
# ILE_Dark_M1M2                0.000000
# L-ALPHA-ALANINE_Light_M1M2  34.356243
# L-ALPHA-ALANINE_Dark_M1M2   -0.129126
# L-ASPARTATE_Light_M1M2     -31.953237
# L-ASPARTATE_Dark_M1M2        1.070951
# SER_Light_M1M2              -3.662130
# SER_Dark_M1M2                0.013230
# TYR_Light_M1M2               0.002358
# TYR_Dark_M1M2                0.000786
# LYS_Light_M1M2               0.000000
# LYS_Dark_M1M2                0.000000
# PHE_Light_M1M2               0.005763
# PHE_Dark_M1M2                0.000000
# ARG_Light_M1M2               0.006287
# ARG_Dark_M1M2                0.002096
# TRP_Light_M1M2               0.003537
# TRP_Dark_M1M2                0.001179
# GLT_Light_M1M2              -3.179719
# GLT_Dark_M1M2               -0.901742
# ASN_Light_M1M2               0.039689
# ASN_Dark_M1M2                0.013230
# THR_Light_M1M2               0.029341
# THR_Dark_M1M2                0.000000

# %% [markdown]
# ## Step 2.2 Increasing activity of MALIC-NADP-RXN_Light_c_M2 and reducing MALATE-DEH-RXN_Light_c

# %%
m1m2.SetConstraints({"MALIC-NADP-RXN_Light_c_M2":(20.0,None)})
m1m2.SetConstraints({"MALATE-DEH-RXN_Light_c_M2":(0,2.0)})

m1m2.MinFluxSolve()


sol_M1M2 = m1m2.GetSol(IncZeroes=True)
sol_M = m.GetSol(IncZeroes=True)

sf.visualizeDataCategories(sol_M1M2,sol_M,writeData=True)
# Out:
# optimal
# EVOLUTIONARY RXN
#                              M         M1         M2
# GLY-DC_Lt_m           2.465415   0.999389   4.000000
# GLY-DC_Dk_m           0.005995   0.000000   0.000000
# PEPCase_Lt_c          0.236676  20.302927   0.000000
# PEPCase_Dk_c          0.000000   0.000000   0.000000
# CA_Lt_c               0.236676  20.302927   0.000000
# CA_Dk_c               0.000000   0.000000   0.000000
# Malate-DEH-RXN_Lt_c   0.470861   0.619290   2.000000
# Malate-DEH-RXN_Dk_c  -0.701405  -1.048203  -0.065428
# NADP-ME_Lt_c          0.000000   0.000000  20.000000
# NADP-ME_Dk_c          0.000000   0.000000   0.000000
# Rubisco-Carbox_Lt_p  14.816315   0.000000  30.000000
# Rubisco-Carbox_Dk_p   0.000000   0.000000   0.000000
# Rubisco-Oxy_Lt_p      4.938772   0.000000  10.000000
# Rubisco-Oxy_Dk_p      0.000000   0.000000   0.000000
#
#
# GLYCOLYSIS
#                                  M        M1         M2
# Hexokinase_Lt_c           0.000000  0.000000   0.000000
# Hexokinase_Dk_c           0.000000  0.000000   0.000000
# Hexokinase_Lt_p           0.000000  0.000000   0.000000
# Hexokinase_Dk_p           0.000000  0.000000   0.000000
# Hexose_P_Isomerase_Lt_c   0.000000  0.000000  -0.087081
# Hexose_P_Isomerase_Dk_c   0.000000  0.000000  -0.087081
# Hexose_P_Isomerase_Lt_p  -1.201804 -1.644968   0.027407
# Hexose_P_Isomerase_Dk_p  -1.201804 -1.644968   0.027407
# PFK_Lt_c                  0.000000  0.000000   0.000000
# PFK_Dk_c                  0.000000  0.000000   0.000000
# PFK_Lt_p                  0.000000  0.000000   0.000000
# PFK_Dk_p                  0.026876  0.024742   0.000000
# F16_Aldolase_Lt_c        -0.685115 -0.901505  -0.146756
# F16_Aldolase_Dk_c         0.171279  0.301275  -0.065428
# F16_Aldolase_Lt_p        -7.793580 -1.645376 -13.314205
# F16_Aldolase_Dk_p         0.026876  0.024742   0.000000
# Triose_P_Isomerase_Lt_c   0.000000  0.901505   0.146756
# Triose_P_Isomerase_Dk_c  -0.171279 -0.326017   0.000000
# Triose_P_Isomerase_Lt_p  15.062375  1.645783  26.645231
# Triose_P_Isomerase_Dk_p  -0.026876  0.000000   0.065428
# GAPDH_Lt_c                0.000000  0.000000  -2.000000
# GAPDH_Dk_c                0.701405  1.048203   0.065428
# GAPDH_Lt_p                0.000000  0.000000 -17.263399
# GAPDH_Dk_p                0.013438  0.020870   0.000000
# PG_Kinase_Lt_c            0.000000  0.000000   2.000000
# PG_Kinase_Dk_c           -0.701405 -1.048203  -0.065428
# PG_Kinase_Lt_p           38.269992  5.094982  64.921922
# PG_Kinase_Dk_p           -0.013438 -0.020870   0.000000
# PG_Mutase_Lt_c            0.259332  0.000000   0.000000
# PG_Mutase_Dk_c            0.701405  1.048203   0.065428
# PG_Mutase_Lt_p            0.037370  0.089951   2.858434
# PG_Mutase_Dk_p            0.013438  0.012625   0.000000
# Enolase_Lt_c              0.259332  0.000000   0.000000
# Enolase_Dk_c              0.701405  1.048203   0.065428
# Enolase_Lt_p              0.037370  0.089951   2.858434
# Enolase_Dk_p              0.013438  0.012625   0.000000
# Pyruvate_Kinase_Lt_c      0.022656  0.000000   0.000000
# Pyruvate_Kinase_Dk_c      0.701405  1.048203   0.065428
# Pyruvate_Kinase_Lt_p      0.021176  0.000000   2.837262
# Pyruvate_Kinase_Dk_p      0.013438  0.012625   0.000000
#
#
# GLYCOLYSIS
#                                  M        M1         M2
# Hexokinase_Lt_c           0.000000  0.000000   0.000000
# Hexokinase_Dk_c           0.000000  0.000000   0.000000
# Hexokinase_Lt_p           0.000000  0.000000   0.000000
# Hexokinase_Dk_p           0.000000  0.000000   0.000000
# Hexose_P_Isomerase_Lt_c   0.000000  0.000000  -0.087081
# Hexose_P_Isomerase_Dk_c   0.000000  0.000000  -0.087081
# Hexose_P_Isomerase_Lt_p  -1.201804 -1.644968   0.027407
# Hexose_P_Isomerase_Dk_p  -1.201804 -1.644968   0.027407
# PFK_Lt_c                  0.000000  0.000000   0.000000
# PFK_Dk_c                  0.000000  0.000000   0.000000
# PFK_Lt_p                  0.000000  0.000000   0.000000
# PFK_Dk_p                  0.026876  0.024742   0.000000
# F16_Aldolase_Lt_c        -0.685115 -0.901505  -0.146756
# F16_Aldolase_Dk_c         0.171279  0.301275  -0.065428
# F16_Aldolase_Lt_p        -7.793580 -1.645376 -13.314205
# F16_Aldolase_Dk_p         0.026876  0.024742   0.000000
# Triose_P_Isomerase_Lt_c   0.000000  0.901505   0.146756
# Triose_P_Isomerase_Dk_c  -0.171279 -0.326017   0.000000
# Triose_P_Isomerase_Lt_p  15.062375  1.645783  26.645231
# Triose_P_Isomerase_Dk_p  -0.026876  0.000000   0.065428
# GAPDH_Lt_c                0.000000  0.000000  -2.000000
# GAPDH_Dk_c                0.701405  1.048203   0.065428
# GAPDH_Lt_p                0.000000  0.000000 -17.263399
# GAPDH_Dk_p                0.013438  0.020870   0.000000
# PG_Kinase_Lt_c            0.000000  0.000000   2.000000
# PG_Kinase_Dk_c           -0.701405 -1.048203  -0.065428
# PG_Kinase_Lt_p           38.269992  5.094982  64.921922
# PG_Kinase_Dk_p           -0.013438 -0.020870   0.000000
# PG_Mutase_Lt_c            0.259332  0.000000   0.000000
# PG_Mutase_Dk_c            0.701405  1.048203   0.065428
# PG_Mutase_Lt_p            0.037370  0.089951   2.858434
# PG_Mutase_Dk_p            0.013438  0.012625   0.000000
# Enolase_Lt_c              0.259332  0.000000   0.000000
# Enolase_Dk_c              0.701405  1.048203   0.065428
# Enolase_Lt_p              0.037370  0.089951   2.858434
# Enolase_Dk_p              0.013438  0.012625   0.000000
# Pyruvate_Kinase_Lt_c      0.022656  0.000000   0.000000
# Pyruvate_Kinase_Dk_c      0.701405  1.048203   0.065428
# Pyruvate_Kinase_Lt_p      0.021176  0.000000   2.837262
# Pyruvate_Kinase_Dk_p      0.013438  0.012625   0.000000
#
#
# PPP
#                                   M        M1         M2
# Hexose_P_Isomerase_Lt_p   -1.201804 -1.644968   0.027407
# Hexose_P_Isomerase_Dk_p   -0.610192 -0.809338  -0.392566
# Hexose_P_Isomerase_Lt_c    0.000000  0.000000  -0.087081
# Hexose_P_Isomerase_Dk_c    0.171279  0.301275  -0.130855
# Transadolase_Lt_p          0.000000  0.000000   0.000000
# Transadolase_Dk_p          0.318534  0.417040   0.196283
# 1_Transketolase_Lt_p       6.583679  0.000407  13.331026
# 1_Transketolase_Dk_p      -0.318534 -0.417040  -0.196283
# 2_Transketolase_Lt_p      -6.591776 -0.000407 -13.341612
# 2_Transketolase_Dk_p       0.318534  0.417040   0.196283
# Epimerase_Lt_p           -13.175456 -0.000814 -26.672638
# Epimerase_Dk_p             0.099534  0.000950   0.220384
# Epimerase_Lt_c             0.000000  0.000000   0.000000
# Epimerase_Dk_c             0.537533  0.833130   0.172182
# R5P_Isomerase_Lt_p         6.579631 -0.000814  13.327362
# R5P_Isomerase_Dk_p        -0.318534 -0.417447  -0.196283
# R5P_Isomerase_Lt_c         0.000000  0.000000   0.000000
# R5P_Isomerase_Dk_c         0.000000  0.000000   0.000000
# G6PDH1_Lt_p                0.000000  0.000000   0.000000
# G6PDH1_Dk_p                0.418068  0.418397   0.416667
# G6PDH1_Lt_c                0.000000  0.000000   0.000000
# G6PDH1_Dk_c                0.537533  0.833130   0.172182
# G6PDH2_Lt_p                0.000000  0.000000   0.000000
# G6PDH2_Dk_p                0.418068  0.418397   0.416667
# G6PDH2_Lt_c                0.000000  0.000000   0.000000
# G6PDH2_Dk_c                0.537533  0.833130   0.172182
# GLCNATE6P-DH_Lt_c          0.000000  0.000000   0.000000
# GLCNATE6P-DH_Dk_c          0.537533  0.833130   0.172182
# GLCNATE6P-DH_p_Lt_p        0.000000  0.000000   0.000000
# GLCNATE6P-DH_Dk_p          0.418068  0.418397   0.416667
#
#
# ETC
#                          M        M1         M2
# Complex_I_Lt_m    4.549938  0.007761  21.139079
# Complex_I_Dk_m    4.549938  0.007761  21.139079
# Complex II_Lt_m   0.000000  0.000000   2.204912
# Complex_II_Dk_m   0.556877  0.545463   0.729813
# Complex_III_Lt_m  2.274969  0.003880  11.671995
# Complex_III_Dk_m  1.596442  1.380418   1.754180
# Complex_IV_Lt_m   4.549938  0.007761  23.343991
# Complex_IV_Dk_m   3.192885  2.760836   3.508360
# AOX1              0.000000  0.000000   0.000000
# AOX1              0.000000  0.000000   0.000000
# AOX2              0.000000  0.000000   0.000000
# AOX2              0.000000  0.000000   0.000000
#
#
# PHOTOSYSTEMS
#                                     M         M1     M2
# PS-II_Lt_p                  24.250000  24.250000  24.25
# PS-II_Dk_p                   0.000000   0.000000   0.00
# PQuinol-PCyanin-Reduc_Lt_p  48.500000  48.500000  48.50
# PQuinol-PCyanin-Reduc_Dk_p   0.000000   0.000000   0.00
# PS-I_Lt_p                   97.000000  97.000000  97.00
# PS-I_Dk_p                    0.000000   0.000000   0.00
# Ferredoxin-Oxidase_Lt_p     44.254219  41.160562  48.50
# Ferredoxin-Oxidase_Dk_p      0.000000   0.000000   0.00
# Cyclic-PS_Lt_p               0.000000   0.000000   0.00
# Cyclic-PS_Dk_p               0.000000   0.000000   0.00
#
#
# BIOMASSES
#                                     M   M1        M2
# Sucrose_Light_biomass       -0.513837  0.0 -0.671814
# Sucrose_Dark_biomass        -0.171279  0.0 -0.223938
# Alanine_Light_biomass       -0.022656  0.0 -0.029621
# Alanine_Dark_biomass        -0.007552  0.0 -0.009874
# Arginine_Light_biomass      -0.003737  0.0 -0.004886
# Arginine_Dark_biomass       -0.001246  0.0 -0.001629
# Aspartate_Light_biomass     -0.022188  0.0 -0.029010
# Aspartate_Dark_biomass      -0.007396  0.0 -0.009670
# Glutamate_Light_biomass     -0.026626  0.0 -0.034812
# Glutamate_Dark_biomass      -0.008875  0.0 -0.011604
# Glutamine_Light_biomass     -0.077543  0.0 -0.101383
# Glutamine_Dark_biomass      -0.025848  0.0 -0.033794
# Glycine_Light_biomass       -0.001635  0.0 -0.002138
# Glycine_Dark_biomass        -0.000545  0.0 -0.000713
# Serine_Light_biomass        -0.017984  0.0 -0.023513
# Serine_Dark_biomass         -0.005995  0.0 -0.007838
# Tyrosine_Light_biomass      -0.001401  0.0 -0.001832
# Tyrosine_Dark_biomass       -0.000467  0.0 -0.000611
# Histidine_Light_biomass     -0.000934  0.0 -0.001221
# Histidine_Dark_biomass      -0.000311  0.0 -0.000407
# Isoleucine_Light_biomass    -0.002803  0.0 -0.003664
# Isoleucine_Dark_biomass     -0.000934  0.0 -0.001221
# Leucine_Light_biomass       -0.002803  0.0 -0.003664
# Leucine_Dark_biomass        -0.000934  0.0 -0.001221
# Lysine_Light_biomass        -0.004204  0.0 -0.005497
# Lysine_Dark_biomass         -0.001401  0.0 -0.001832
# Methionine_Light_biomass    -0.001635  0.0 -0.002138
# Methionine_Dark_biomass     -0.000545  0.0 -0.000713
# Phenylalanine_Light_biomass -0.002569  0.0 -0.003359
# Phenylalanine_Dark_biomass  -0.000856  0.0 -0.001120
# Threonine_Light_biomass     -0.013079  0.0 -0.017101
# Threonine_Dark_biomass      -0.004360  0.0 -0.005700
# Tryptophan_Light_biomass    -0.002102  0.0 -0.002748
# Tryptophan_Dark_biomass     -0.000701  0.0 -0.000916
# Valine_Light_biomass        -0.005605  0.0 -0.007329
# Valine_Dark_biomass         -0.001868  0.0 -0.002443
#
#
# _tx_rxn
#                       M         M1        M2
# CO2_Light_tx  12.454757  15.949643  2.344825
# CO2_Dark_tx   -2.815495  -1.797193 -3.894458
# O2_Light_tx  -13.316873 -22.996120  3.671995
# O2_Dark_tx     2.846442   2.630418  3.004180
#
#
# M1M2
#                                  M1M2
# Malate_Lt_M1M2              32.000000
# Malate_Dk_M1M2               0.000000
# Pyruvate_Lt_M1M2           -44.244438
# Pyruvate_Dk_M1M2             1.119256
# Sucrose_Light_M1M2           0.612139
# Sucrose_Dark_M1M2            0.289365
# GLY_Light_M1M2              -1.997557
# GLY_Dark_M1M2                0.000407
# MET_Light_M1M2               0.002138
# MET_Dark_M1M2                0.000713
# LEU_Light_M1M2               0.000000
# LEU_Dark_M1M2                0.000000
# HIS_Light_M1M2               0.001221
# HIS_Dark_M1M2                0.000407
# VAL_Light_M1M2               0.012215
# VAL_Dark_M1M2                0.002443
# ILE_Light_M1M2               0.003664
# ILE_Dark_M1M2                0.001221
# L-ALPHA-ALANINE_Light_M1M2  22.187376
# L-ALPHA-ALANINE_Dark_M1M2    0.078684
# L-ASPARTATE_Light_M1M2     -13.426544
# L-ASPARTATE_Dark_M1M2        0.533350
# SER_Light_M1M2              -4.192466
# SER_Dark_M1M2                0.007838
# TYR_Light_M1M2               0.000000
# TYR_Dark_M1M2                0.000000
# LYS_Light_M1M2               0.005497
# LYS_Dark_M1M2                0.001832
# PHE_Light_M1M2               0.000000
# PHE_Dark_M1M2                0.000000
# ARG_Light_M1M2               0.004886
# ARG_Dark_M1M2                0.001629
# TRP_Light_M1M2               0.000000
# TRP_Dark_M1M2                0.000000
# GLT_Light_M1M2               5.555512
# GLT_Dark_M1M2               -0.580886
# ASN_Light_M1M2               0.030842
# ASN_Dark_M1M2                0.010281
# THR_Light_M1M2               0.022801
# THR_Dark_M1M2                0.000000

# %% [markdown]
# ## Step 3: Increased CA in M1, reduced in M2

# %%
# m1m2.SetConstraints({'PEPCARBOX-RXN_Light_c_M1':(0.4,0.4)})
# m1m2.SetConstraints({'RXN0-5224_Light_c_M1':(0.45,None)})
# m1m2.MinFluxSolve()


# sol_M1M2 = m1m2.GetSol(IncZeroes=True)
# sol_M = m.GetSol(IncZeroes=True)

# sf.visualizeDataCategories(sol_M1M2,sol_M,writeData=True)

# %% [markdown]
# ## Step 4: Reducing Rubisco activity in M1

# %%
m1m2.SetConstraints({'RIBULOSE-BISPHOSPHATE-CARBOXYLASE-RXN_Light_p_M1':(-1000,0)})
m1m2.SetConstraints({'RIBULOSE-BISPHOSPHATE-CARBOXYLASE-RXN_Light_p_M2':(30,None)})
m1m2.MinFluxSolve()


sol_M1M2 = m1m2.GetSol(IncZeroes=True)
sol_M = m.GetSol(IncZeroes=True)

sf.visualizeDataCategories(sol_M1M2,sol_M,writeData=True)
# Out:
# optimal
# EVOLUTIONARY RXN
#                              M         M1         M2
# GLY-DC_Lt_m           2.465415   0.999389   4.000000
# GLY-DC_Dk_m           0.005995   0.000000   0.000000
# PEPCase_Lt_c          0.236676  20.302927   0.000000
# PEPCase_Dk_c          0.000000   0.000000   0.000000
# CA_Lt_c               0.236676  20.302927   0.000000
# CA_Dk_c               0.000000   0.000000   0.000000
# Malate-DEH-RXN_Lt_c   0.470861   0.619290   2.000000
# Malate-DEH-RXN_Dk_c  -0.701405  -1.048203  -0.065428
# NADP-ME_Lt_c          0.000000   0.000000  20.000000
# NADP-ME_Dk_c          0.000000   0.000000   0.000000
# Rubisco-Carbox_Lt_p  14.816315   0.000000  30.000000
# Rubisco-Carbox_Dk_p   0.000000   0.000000   0.000000
# Rubisco-Oxy_Lt_p      4.938772   0.000000  10.000000
# Rubisco-Oxy_Dk_p      0.000000   0.000000   0.000000
#
#
# GLYCOLYSIS
#                                  M        M1         M2
# Hexokinase_Lt_c           0.000000  0.000000   0.000000
# Hexokinase_Dk_c           0.000000  0.000000   0.000000
# Hexokinase_Lt_p           0.000000  0.000000   0.000000
# Hexokinase_Dk_p           0.000000  0.000000   0.000000
# Hexose_P_Isomerase_Lt_c   0.000000  0.000000  -0.087081
# Hexose_P_Isomerase_Dk_c   0.000000  0.000000  -0.087081
# Hexose_P_Isomerase_Lt_p  -1.201804 -1.644968   0.027407
# Hexose_P_Isomerase_Dk_p  -1.201804 -1.644968   0.027407
# PFK_Lt_c                  0.000000  0.000000   0.000000
# PFK_Dk_c                  0.000000  0.000000   0.000000
# PFK_Lt_p                  0.000000  0.000000   0.000000
# PFK_Dk_p                  0.026876  0.024742   0.000000
# F16_Aldolase_Lt_c        -0.685115 -0.901505  -0.146756
# F16_Aldolase_Dk_c         0.171279  0.301275  -0.065428
# F16_Aldolase_Lt_p        -7.793580 -1.645376 -13.314205
# F16_Aldolase_Dk_p         0.026876  0.024742   0.000000
# Triose_P_Isomerase_Lt_c   0.000000  0.901505   0.146756
# Triose_P_Isomerase_Dk_c  -0.171279 -0.326017   0.000000
# Triose_P_Isomerase_Lt_p  15.062375  1.645783  26.645231
# Triose_P_Isomerase_Dk_p  -0.026876  0.000000   0.065428
# GAPDH_Lt_c                0.000000  0.000000  -2.000000
# GAPDH_Dk_c                0.701405  1.048203   0.065428
# GAPDH_Lt_p                0.000000  0.000000 -17.263399
# GAPDH_Dk_p                0.013438  0.020870   0.000000
# PG_Kinase_Lt_c            0.000000  0.000000   2.000000
# PG_Kinase_Dk_c           -0.701405 -1.048203  -0.065428
# PG_Kinase_Lt_p           38.269992  5.094982  64.921922
# PG_Kinase_Dk_p           -0.013438 -0.020870   0.000000
# PG_Mutase_Lt_c            0.259332  0.000000   0.000000
# PG_Mutase_Dk_c            0.701405  1.048203   0.065428
# PG_Mutase_Lt_p            0.037370  0.089951   2.858434
# PG_Mutase_Dk_p            0.013438  0.012625   0.000000
# Enolase_Lt_c              0.259332  0.000000   0.000000
# Enolase_Dk_c              0.701405  1.048203   0.065428
# Enolase_Lt_p              0.037370  0.089951   2.858434
# Enolase_Dk_p              0.013438  0.012625   0.000000
# Pyruvate_Kinase_Lt_c      0.022656  0.000000   0.000000
# Pyruvate_Kinase_Dk_c      0.701405  1.048203   0.065428
# Pyruvate_Kinase_Lt_p      0.021176  0.000000   2.837262
# Pyruvate_Kinase_Dk_p      0.013438  0.012625   0.000000
#
#
# GLYCOLYSIS
#                                  M        M1         M2
# Hexokinase_Lt_c           0.000000  0.000000   0.000000
# Hexokinase_Dk_c           0.000000  0.000000   0.000000
# Hexokinase_Lt_p           0.000000  0.000000   0.000000
# Hexokinase_Dk_p           0.000000  0.000000   0.000000
# Hexose_P_Isomerase_Lt_c   0.000000  0.000000  -0.087081
# Hexose_P_Isomerase_Dk_c   0.000000  0.000000  -0.087081
# Hexose_P_Isomerase_Lt_p  -1.201804 -1.644968   0.027407
# Hexose_P_Isomerase_Dk_p  -1.201804 -1.644968   0.027407
# PFK_Lt_c                  0.000000  0.000000   0.000000
# PFK_Dk_c                  0.000000  0.000000   0.000000
# PFK_Lt_p                  0.000000  0.000000   0.000000
# PFK_Dk_p                  0.026876  0.024742   0.000000
# F16_Aldolase_Lt_c        -0.685115 -0.901505  -0.146756
# F16_Aldolase_Dk_c         0.171279  0.301275  -0.065428
# F16_Aldolase_Lt_p        -7.793580 -1.645376 -13.314205
# F16_Aldolase_Dk_p         0.026876  0.024742   0.000000
# Triose_P_Isomerase_Lt_c   0.000000  0.901505   0.146756
# Triose_P_Isomerase_Dk_c  -0.171279 -0.326017   0.000000
# Triose_P_Isomerase_Lt_p  15.062375  1.645783  26.645231
# Triose_P_Isomerase_Dk_p  -0.026876  0.000000   0.065428
# GAPDH_Lt_c                0.000000  0.000000  -2.000000
# GAPDH_Dk_c                0.701405  1.048203   0.065428
# GAPDH_Lt_p                0.000000  0.000000 -17.263399
# GAPDH_Dk_p                0.013438  0.020870   0.000000
# PG_Kinase_Lt_c            0.000000  0.000000   2.000000
# PG_Kinase_Dk_c           -0.701405 -1.048203  -0.065428
# PG_Kinase_Lt_p           38.269992  5.094982  64.921922
# PG_Kinase_Dk_p           -0.013438 -0.020870   0.000000
# PG_Mutase_Lt_c            0.259332  0.000000   0.000000
# PG_Mutase_Dk_c            0.701405  1.048203   0.065428
# PG_Mutase_Lt_p            0.037370  0.089951   2.858434
# PG_Mutase_Dk_p            0.013438  0.012625   0.000000
# Enolase_Lt_c              0.259332  0.000000   0.000000
# Enolase_Dk_c              0.701405  1.048203   0.065428
# Enolase_Lt_p              0.037370  0.089951   2.858434
# Enolase_Dk_p              0.013438  0.012625   0.000000
# Pyruvate_Kinase_Lt_c      0.022656  0.000000   0.000000
# Pyruvate_Kinase_Dk_c      0.701405  1.048203   0.065428
# Pyruvate_Kinase_Lt_p      0.021176  0.000000   2.837262
# Pyruvate_Kinase_Dk_p      0.013438  0.012625   0.000000
#
#
# PPP
#                                   M        M1         M2
# Hexose_P_Isomerase_Lt_p   -1.201804 -1.644968   0.027407
# Hexose_P_Isomerase_Dk_p   -0.610192 -0.809338  -0.392566
# Hexose_P_Isomerase_Lt_c    0.000000  0.000000  -0.087081
# Hexose_P_Isomerase_Dk_c    0.171279  0.301275  -0.130855
# Transadolase_Lt_p          0.000000  0.000000   0.000000
# Transadolase_Dk_p          0.318534  0.417040   0.196283
# 1_Transketolase_Lt_p       6.583679  0.000407  13.331026
# 1_Transketolase_Dk_p      -0.318534 -0.417040  -0.196283
# 2_Transketolase_Lt_p      -6.591776 -0.000407 -13.341612
# 2_Transketolase_Dk_p       0.318534  0.417040   0.196283
# Epimerase_Lt_p           -13.175456 -0.000814 -26.672638
# Epimerase_Dk_p             0.099534  0.000950   0.220384
# Epimerase_Lt_c             0.000000  0.000000   0.000000
# Epimerase_Dk_c             0.537533  0.833130   0.172182
# R5P_Isomerase_Lt_p         6.579631 -0.000814  13.327362
# R5P_Isomerase_Dk_p        -0.318534 -0.417447  -0.196283
# R5P_Isomerase_Lt_c         0.000000  0.000000   0.000000
# R5P_Isomerase_Dk_c         0.000000  0.000000   0.000000
# G6PDH1_Lt_p                0.000000  0.000000   0.000000
# G6PDH1_Dk_p                0.418068  0.418397   0.416667
# G6PDH1_Lt_c                0.000000  0.000000   0.000000
# G6PDH1_Dk_c                0.537533  0.833130   0.172182
# G6PDH2_Lt_p                0.000000  0.000000   0.000000
# G6PDH2_Dk_p                0.418068  0.418397   0.416667
# G6PDH2_Lt_c                0.000000  0.000000   0.000000
# G6PDH2_Dk_c                0.537533  0.833130   0.172182
# GLCNATE6P-DH_Lt_c          0.000000  0.000000   0.000000
# GLCNATE6P-DH_Dk_c          0.537533  0.833130   0.172182
# GLCNATE6P-DH_p_Lt_p        0.000000  0.000000   0.000000
# GLCNATE6P-DH_Dk_p          0.418068  0.418397   0.416667
#
#
# ETC
#                          M        M1         M2
# Complex_I_Lt_m    4.549938  0.007761  21.139079
# Complex_I_Dk_m    4.549938  0.007761  21.139079
# Complex II_Lt_m   0.000000  0.000000   2.204912
# Complex_II_Dk_m   0.556877  0.545463   0.729813
# Complex_III_Lt_m  2.274969  0.003880  11.671995
# Complex_III_Dk_m  1.596442  1.380418   1.754180
# Complex_IV_Lt_m   4.549938  0.007761  23.343991
# Complex_IV_Dk_m   3.192885  2.760836   3.508360
# AOX1              0.000000  0.000000   0.000000
# AOX1              0.000000  0.000000   0.000000
# AOX2              0.000000  0.000000   0.000000
# AOX2              0.000000  0.000000   0.000000
#
#
# PHOTOSYSTEMS
#                                     M         M1     M2
# PS-II_Lt_p                  24.250000  24.250000  24.25
# PS-II_Dk_p                   0.000000   0.000000   0.00
# PQuinol-PCyanin-Reduc_Lt_p  48.500000  48.500000  48.50
# PQuinol-PCyanin-Reduc_Dk_p   0.000000   0.000000   0.00
# PS-I_Lt_p                   97.000000  97.000000  97.00
# PS-I_Dk_p                    0.000000   0.000000   0.00
# Ferredoxin-Oxidase_Lt_p     44.254219  41.160562  48.50
# Ferredoxin-Oxidase_Dk_p      0.000000   0.000000   0.00
# Cyclic-PS_Lt_p               0.000000   0.000000   0.00
# Cyclic-PS_Dk_p               0.000000   0.000000   0.00
#
#
# BIOMASSES
#                                     M   M1        M2
# Sucrose_Light_biomass       -0.513837  0.0 -0.671814
# Sucrose_Dark_biomass        -0.171279  0.0 -0.223938
# Alanine_Light_biomass       -0.022656  0.0 -0.029621
# Alanine_Dark_biomass        -0.007552  0.0 -0.009874
# Arginine_Light_biomass      -0.003737  0.0 -0.004886
# Arginine_Dark_biomass       -0.001246  0.0 -0.001629
# Aspartate_Light_biomass     -0.022188  0.0 -0.029010
# Aspartate_Dark_biomass      -0.007396  0.0 -0.009670
# Glutamate_Light_biomass     -0.026626  0.0 -0.034812
# Glutamate_Dark_biomass      -0.008875  0.0 -0.011604
# Glutamine_Light_biomass     -0.077543  0.0 -0.101383
# Glutamine_Dark_biomass      -0.025848  0.0 -0.033794
# Glycine_Light_biomass       -0.001635  0.0 -0.002138
# Glycine_Dark_biomass        -0.000545  0.0 -0.000713
# Serine_Light_biomass        -0.017984  0.0 -0.023513
# Serine_Dark_biomass         -0.005995  0.0 -0.007838
# Tyrosine_Light_biomass      -0.001401  0.0 -0.001832
# Tyrosine_Dark_biomass       -0.000467  0.0 -0.000611
# Histidine_Light_biomass     -0.000934  0.0 -0.001221
# Histidine_Dark_biomass      -0.000311  0.0 -0.000407
# Isoleucine_Light_biomass    -0.002803  0.0 -0.003664
# Isoleucine_Dark_biomass     -0.000934  0.0 -0.001221
# Leucine_Light_biomass       -0.002803  0.0 -0.003664
# Leucine_Dark_biomass        -0.000934  0.0 -0.001221
# Lysine_Light_biomass        -0.004204  0.0 -0.005497
# Lysine_Dark_biomass         -0.001401  0.0 -0.001832
# Methionine_Light_biomass    -0.001635  0.0 -0.002138
# Methionine_Dark_biomass     -0.000545  0.0 -0.000713
# Phenylalanine_Light_biomass -0.002569  0.0 -0.003359
# Phenylalanine_Dark_biomass  -0.000856  0.0 -0.001120
# Threonine_Light_biomass     -0.013079  0.0 -0.017101
# Threonine_Dark_biomass      -0.004360  0.0 -0.005700
# Tryptophan_Light_biomass    -0.002102  0.0 -0.002748
# Tryptophan_Dark_biomass     -0.000701  0.0 -0.000916
# Valine_Light_biomass        -0.005605  0.0 -0.007329
# Valine_Dark_biomass         -0.001868  0.0 -0.002443
#
#
# _tx_rxn
#                       M         M1        M2
# CO2_Light_tx  12.454757  15.949643  2.344825
# CO2_Dark_tx   -2.815495  -1.797193 -3.894458
# O2_Light_tx  -13.316873 -22.996120  3.671995
# O2_Dark_tx     2.846442   2.630418  3.004180
#
#
# M1M2
#                                  M1M2
# Malate_Lt_M1M2              32.000000
# Malate_Dk_M1M2               0.000000
# Pyruvate_Lt_M1M2           -44.244438
# Pyruvate_Dk_M1M2             1.119256
# Sucrose_Light_M1M2           0.612139
# Sucrose_Dark_M1M2            0.289365
# GLY_Light_M1M2              -1.997557
# GLY_Dark_M1M2                0.000407
# MET_Light_M1M2               0.002138
# MET_Dark_M1M2                0.000713
# LEU_Light_M1M2               0.000000
# LEU_Dark_M1M2                0.000000
# HIS_Light_M1M2               0.001221
# HIS_Dark_M1M2                0.000407
# VAL_Light_M1M2               0.012215
# VAL_Dark_M1M2                0.002443
# ILE_Light_M1M2               0.003664
# ILE_Dark_M1M2                0.001221
# L-ALPHA-ALANINE_Light_M1M2  22.187376
# L-ALPHA-ALANINE_Dark_M1M2    0.078684
# L-ASPARTATE_Light_M1M2     -13.426544
# L-ASPARTATE_Dark_M1M2        0.533350
# SER_Light_M1M2              -4.192466
# SER_Dark_M1M2                0.007838
# TYR_Light_M1M2               0.000000
# TYR_Dark_M1M2                0.000000
# LYS_Light_M1M2               0.005497
# LYS_Dark_M1M2                0.001832
# PHE_Light_M1M2               0.000000
# PHE_Dark_M1M2                0.000000
# ARG_Light_M1M2               0.004886
# ARG_Dark_M1M2                0.001629
# TRP_Light_M1M2               0.000000
# TRP_Dark_M1M2                0.000000
# GLT_Light_M1M2               5.555512
# GLT_Dark_M1M2               -0.580886
# ASN_Light_M1M2               0.030842
# ASN_Dark_M1M2                0.010281
# THR_Light_M1M2               0.022801
# THR_Dark_M1M2                0.000000

# %% [markdown]
# ## Adding/Deleting reactions (should usually be commented out) basically stuff which I have added thus far

# %%
# AA_met = ['GLY','GLN','MET','LEU','HIS','VAL','ILE',
#          'L-ALPHA-ALANINE','L-ASPARTATE','SER','TYR','LYS','PHE',
#          'ARG','TRP','GLT','ASN','THR']

# #transport AA from M1 to M2 LIGHT
# for met in AA_met:
#     m1m2.AddReaction(met+'_Light_M1M2',{met+'_Light_c_M1':-1,met+'_Light_c_M2':1},True)

# #transport AA from M1 to M2 DARK
# for met in AA_met:
#     m1m2.AddReaction(met+'_Dark_M1M2',{met+'_Dark_c_M1':-1,met+'_Dark_c_M2':1},True)

# m1m2.PrintReaction('GLN_Light_M1M2')
# m1m2.PrintReaction('GLN_Dark_M1M2')
# m1m2.PrintReaction('Sucrose_Light_M1M2')


#Adding malate transporters between M1 and M2
# m1m2.AddReaction('MAL_Light_M1M2',{'MAL_Light_c_M1':-1,'MAL_Light_c_M2':1},True)
# m1m2.AddReaction('MAL_Dark_M1M2',{'MAL_Dark_c_M1':-1,'MAL_dark_c_M2':1},True)

#Adding pyruvate transports between M1 and M2

# m1m2.AddReaction('PYRUVATE_Light_M1M2',{'PYRUVATE_Light_c_M1':-1,'PYRUVATE_Light_c_M2':1},True)
# m1m2.AddReaction('PYRUVATE_Dark_M1M2',{'PYRUVATE_Dark_c_M1':-1,'PYRUVATE_Dark_c_M2':1},True)

# %%
## # m1m2.WriteModel('AraLightDarkCore_DbMesophyll_v1.xls', 'excel')
# m1m2.WriteModel('AraLightDarkCore_DbMesophyll_v4.xls', 'excel')
