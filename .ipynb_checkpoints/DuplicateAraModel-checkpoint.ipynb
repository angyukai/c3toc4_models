# %%
import scobra
import pandas as pd
from cobra import Metabolite
m = scobra.Model('AraLightDarkCore_DbMesophyll_v3.xls')

# %% [markdown]
# ## Personal functions for scobra

# %%
def notInList(element, alist):
    for i in alist:
        if element == i:
            return False
    return True

def PrintSolList(model, reacList):
    for i in range(len(reacList)):
        model.PrintSol(reacList[i])

def PrintIndvAminoAcids(sol, lightdic, darkdic):
    
    for i in lightdic:
        print i+'_M1:',sol[i+'_M1']
        
    for i in darkdic:
        print i+'_M1:',sol[i+'_M1']

    for i in lightdic:
        print i+'_M2:',sol[i+'_M2']
    
    for i in darkdic:
        print i+'_M2:',sol[i+'_M2']
        
def PrintAminoAcids(sol, lightdic, darkdic):
    
    aaLightM1 = 0
    aaDarkM1 = 0
    aaLightM2 = 0
    aaDarkM2 = 0
    
    for i in lightdic:
        aaLightM1 += sol[i+'_M1']
    
    for i in darkdic:
        aaDarkM1 += sol[i+'_M1']
    
    for i in lightdic:
        aaLightM2 += sol[i+'_M2']
    
    for i in darkdic:
        aaDarkM2 += sol[i+'_M2']
        
    print "Amino-acid_Light_M1: ",aaLightM1
    print "Amino-acid_Dark_M1: ",aaDarkM1
    print "Amino-acid_Light_M2: ",aaLightM2
    print "Amino-acid_Dark_M2: ",aaDarkM2

def prepareDataForVisualization(reacList):
    
    all_M1_rxn = []
    all_M2_rxn = []
    all_index = []
    
    for rxn in range(len(reacList)):

        lightRxn = reacList[rxn][0]
        darkRxn = reacList[rxn][1]
        tempM1 = [sol[lightRxn+'_M1'],sol[darkRxn+'_M1']]
        tempM2 = [sol[lightRxn+'_M2'],sol[darkRxn+'_M2']]
        tempIndex = [lightRxn,darkRxn]
        
        for rxn in tempM1:
            all_M1_rxn.append(rxn)
        for rxn in tempM2:
            all_M2_rxn.append(rxn)
        for i in tempIndex:
            all_index.append(i)
    
    return all_M1_rxn, all_M2_rxn, all_index
    

def VisualizeData(sol, reacList, printData=True, writeData=False, aaConsolidate=True):
    '''For the reacList, it should be a list of lists containing 2 elements, one light rxn and one dark rxn.
    e.g. [ [rxn_A_Light,rxn_A_Dark], [rxn_B_Light,rxn_B_Dark], [rxn_C_Light,rxn_C_Dark]]
    Note: ALWAYS put the light reaction first.'''
    #############################################
    #### For most of the M1 and M2 reactions ####
    #############################################
    
    all_M1_rxn, all_M2_rxn, all_index = prepareDataForVisualization(reacList)
    
    ################################
    #### For AminoAcids biomass ####
    ################################
    
    lightdic = {'Alanine_Light_biomass':-9.7,'Arginine_Light_biomass':-1.6,'Asparagine_Light_biomass':-10.1,'Aspartate_Light_biomass':-9.5,
    'Glutamate_Light_biomass':-11.4,'Glutamine_Light_biomass':-33.2,'Glycine_Light_biomass':-0.7,'Serine_Light_biomass':-7.7,
    'Tyrosine_Light_biomass':-0.6,'Histidine_Light_biomass':-0.4,'Isoleucine_Light_biomass':-1.2,'Leucine_Light_biomass':-1.2,
    'Lysine_Light_biomass':-1.8,'Methionine_Light_biomass':-0.7,'Phenylalanine_Light_biomass':-1.1,'Threonine_Light_biomass':-5.6,
    'Tryptophan_Light_biomass':-0.9,'Valine_Light_biomass':-2.4}
    darkdic = {'Alanine_Dark_biomass':-9.7,'Arginine_Dark_biomass':-1.6,'Asparagine_Dark_biomass':-10.1,'Aspartate_Dark_biomass':-9.5,
    'Glutamate_Dark_biomass':-11.4,'Glutamine_Dark_biomass':-33.2,'Glycine_Dark_biomass':-0.7,'Serine_Dark_biomass':-7.7,
    'Tyrosine_Dark_biomass':-0.6,'Histidine_Dark_biomass':-0.4,'Isoleucine_Dark_biomass':-1.2,'Leucine_Dark_biomass':-1.2,
    'Lysine_Dark_biomass':-1.8,'Methionine_Dark_biomass':-0.7,'Phenylalanine_Dark_biomass':-1.1,'Threonine_Dark_biomass':-5.6,
    'Tryptophan_Dark_biomass':-0.9,'Valine_Dark_biomass':-2.4}

    if aaConsolidate:
        aaLightM1 = 0
        aaLightM2 = 0
        aaDarkM1 = 0
        aaDarkM2 = 0
        index = ['AminoAcids_Light_biomass','AminoAcids_Dark_biomass']
        for aa in lightdic:
            aaLightM1+=sol[aa+'_M1']
            aaLightM2+=sol[aa+'_M2']
#             print 'LIGHT M2:',sol[aa+'_M2']
        for aa in darkdic:
            aaDarkM1+=sol[aa+'_M1']
            aaDarkM2+=sol[aa+'_M2']
#             print 'DARK M2:',sol[aa+'_M2']
        ###START FROM HERE AGAIN
        allM1aa = [aaLightM1,aaDarkM1]
        allM2aa = [aaLightM2,aaLightM1]

        for i in range(len(allM1aa)):
            all_M1_rxn.append(allM1aa[i])
        for i in range(len(allM2aa)):
            all_M2_rxn.append(allM2aa[i])    
        for name in index:
            all_index.append(name)
        
    #This wont work with aaConsolidate = True cos i lazy lol     
    else:
        aaM1 = []
        aaM2 = []
        index = []
        for aa in lightdic:
            aaM1.append(sol[aa+'_M1'])
            aaM2.append(sol[aa+'_M2'])
            index.append(aa)
        for aa in darkdic:
            aaM1.append(sol[aa+'_M1'])
            aaM2.append(sol[aa+'_M2'])
            index.append(aa)
    
        aminoacids = pd.DataFrame({'M1':aaM1,'M2':aaM2},index = index)
        
    allM1andM2 = pd.DataFrame({'M1':all_M1_rxn,'M2':all_M2_rxn},index = all_index)
        
    ############################
    #### For M1M2 reactions ####
    ############################
    sucroseLightDarkM1M2 = [sol['Sucrose_Light_M1M2'],sol['Sucrose_Dark_M1M2']]
    
    AA_met = ['GLY','GLN','MET','LEU','HIS','VAL','ILE',
         'L-ALPHA-ALANINE','L-ASPARTATE','SER','TYR','LYS','PHE',
         'ARG','TRP','GLT','ASN','THR']
    
    aminoacidLightDarkM1M2 = []
    aaTempLight = 0
    aaTempDark = 0
    for aa in AA_met:
        aaTempLight+=sol[aa+'_Light_M1M2']
        aaTempDark+=sol[aa+'_Dark_M1M2']
    
    aminoacidLightDarkM1M2.append(aaTempLight)
    aminoacidLightDarkM1M2.append(aaTempDark)
    
    allM1M2 = sucroseLightDarkM1M2+aminoacidLightDarkM1M2
    
    M1M2_excel_start_row = len(all_index)
    
    index = ['Sucrose_Light_M1M2','Sucrose_Dark_M1M2','AminoAcids_Light_M1M2','AminoAcids_Dark_M1M2']
    M1M2 = pd.DataFrame({'M1M2':allM1M2},index)
    
    ###############################
    #### For PEPKase reactions ####
    ###############################
    
    
    if printData:
        print 'm1 and m2'
        print allM1andM2
        print 'M1M2'
        print M1M2
    
        
    if writeData:
        frames = [allM1andM2]
        result = pd.concat(frames)
        
        # Create a Pandas Excel writer using XlsxWriter as the engine.
        writer = pd.ExcelWriter('panda_test.xlsx', engine='xlsxwriter')
        
        # Convert the dataframe to an XlsxWriter Excel object.
        result.to_excel(writer, sheet_name='Sheet1')
        M1M2.to_excel(writer, sheet_name='Sheet1', startrow=M1M2_excel_start_row)

        # Close the Pandas Excel writer and output the Excel file.
        writer.save()

# %% [markdown]
# ## Creating visualization function which categorizes rxn type

# %%
def prepareDataWithCustomIndex(reacList, customIndex):
    
    all_M1_rxn = []
    all_M2_rxn = []
    all_index = []
    
    for rxn in range(len(reacList)):
        
        lightRxn = reacList[rxn][0]
        darkRxn = reacList[rxn][1]
        tempM1 = [sol[lightRxn+'_M1'],sol[darkRxn+'_M1']]
        tempM2 = [sol[lightRxn+'_M2'],sol[darkRxn+'_M2']]
        tempIndex = customIndex[rxn]

        for rxn in tempM1:
            all_M1_rxn.append(rxn)
        for rxn in tempM2:
            all_M2_rxn.append(rxn)
        for i in tempIndex:
            all_index.append(i)
    
    return all_M1_rxn, all_M2_rxn, all_index
    

def visualizeDataCategories(sol, reacList = None , printData=True, writeData=False, aaConsolidate=True):
    
    #1. C3 to C4 reaction steps
    #2. Glycolysis
    #3. TCA
    #4. PPP
    #5. ETC
    #6. M1 to M2
    
    groupings = ['C3 to C4 Reaction Steps','Glycolysis','TCA','PPP','ETC','M1 to M2']
    
    all_groups = []
    
    ###################
    #### GLYCOLYSIS ###
    ###################
    
#     1. GAPDH
#     2. Hexokinase
#     3. Phosphoglucose isomerase
#     4. Phosphofructokinase
#     5. Aldolase
#     6. Triose phosphate isomerase
#     7. Phosphoglycerate kinase
#     8. Phosphoglycerate mutase
#     9. Phosphoglycerate hydratase
    
    
    #QUESTION, ALL SHOULD BE IN THE _c?
    #Confusion on GAP vs G3p. rxn GAPXNPHOSPHN - why does GAP straight away go to DPG? and what is DPG
    rxnIndex = [['Lt Hexokinase','Dk Hexokinase'],
                ['Lt_c PGLC Isomerase','Dk_c PGLC Isomerase'],
                ['Lt_p PGLC Isomerase','Dk_p PGLC Isomerase'],
                ['Lt_c PFK','Dk_c PFK'],
                ['Lt_p PFK','Dk_p PFK'],
                ['Lt_c F16 Aldolase','Dk_c F16 Aldolase'],
                ['Lt_p F16 Aldolase','Dk_p F16 Aldolase'],
                ['Lt_c Triose P Isomerase','Dk_c Triose P Isomerase'],
                ['Lt_p Triose P Isomerase','Dk_p Triose P Isomerase'],
                ['Lt_c GAPDH','Dk_c GAPDH'],
                ['Lt_p GAPDH','Dk_p GAPDH'],
                #reflect GAP to G3P pathway
                ['Lt_c PG Kinase','Dk_c PG Kinase'],
                ['Lt_p PG Kinase','Dk_p PG Kinase'],
                ['Lt_c PG Mutase','Dk_c PG Mutase'],
                ['Lt_p PG Mutase','Dk_p PG Mutase'],
                ['Lt_c Enolase','Dk_c Enolase'],
                ['Lt_p Enolase','Dk_p Enolase'],
                ['Lt_c Pyruvate Kinase','Dk_c Pyruvate Kinase'],
                ['Lt_p Pyruvate Kinase','Dk_p Pyruvate Kinase']
                
               ]
    
    reactions = [['GLUCOKIN-RXN_Light_c','GLUCOKIN-RXN_Dark_c'],
                 ['PGLUCISOM-RXN_Light_c','PGLUCISOM-RXN_Light_c'],
                 ['PGLUCISOM-RXN_Light_p','PGLUCISOM-RXN_Light_p'],
                 ['6PFRUCTPHOS-RXN_Light_c','6PFRUCTPHOS-RXN_Dark_c'],
                 ['6PFRUCTPHOS-RXN_Light_p','6PFRUCTPHOS-RXN_Dark_p'],
                 ['F16ALDOLASE-RXN_Light_c','F16ALDOLASE-RXN_Dark_c'],
                 ['F16ALDOLASE-RXN_Light_p','F16ALDOLASE-RXN_Dark_p'],
                 ['TRIOSEPISOMERIZATION-RXN_Light_c','TRIOSEPISOMERIZATION-RXN_Dark_c'],
                 ['TRIOSEPISOMERIZATION-RXN_Light_p','TRIOSEPISOMERIZATION-RXN_Dark_p'],
                 ['GAPOXNPHOSPHN-RXN_Light_c','GAPOXNPHOSPHN-RXN_Dark_c'],
                 ['GAPOXNPHOSPHN-RXN_Light_p','GAPOXNPHOSPHN-RXN_Dark_p'],
                 ['PHOSGLYPHOS-RXN_Light_c','PHOSGLYPHOS-RXN_Dark_c'],
                 ['PHOSGLYPHOS-RXN_Light_p','PHOSGLYPHOS-RXN_Dark_p'],
                 ['3PGAREARR-RXN_Light_c','3PGAREARR-RXN_Dark_c'],
                 ['3PGAREARR-RXN_Light_p','3PGAREARR-RXN_Dark_p'],
                 ['2PGADEHYDRAT-RXN_Light_c','2PGADEHYDRAT-RXN_Dark_c'],
                 ['2PGADEHYDRAT-RXN_Light_p','2PGADEHYDRAT-RXN_Dark_p'],
                 ['PEPDEPHOS-RXN_Light_c','PEPDEPHOS-RXN_Dark_c'],
                 ['PEPDEPHOS-RXN_Light_p','PEPDEPHOS-RXN_Dark_p']
                ]
    
    M1_rxn, M2_rxn, indexes = prepareDataWithCustomIndex(reactions, rxnIndex)
    tempDataframe = pd.DataFrame({'M1':M1_rxn,'M2':M2_rxn},index = indexes)
    tempGroup = [tempDataframe,'GLYCOLYSIS']
    all_groups.append(tempGroup)
    
    #############
    #### TCA ####
    #############
    
#     Pyruvate dehydrogenase
#     Citrate synthase
#     Aconitase
#     Isocitrate dehydrogenase
#     2-oxoglutarate dehydrogenase
#     Succinate thiokinase
#     Complex II
#     Fumarase

    #CHECK IF SUCCCOA-RXN IS SUCCINATE THIOKINASE RXN
    rxnIndex = [['Lt PyruvateDH','Dk PyruvateDH'],
                ['Lt Citrate Synthase', 'Dk Citrate Synthase'],
                ['Lt Aconitase Light','Dk Aconitase'], 
                ['Lt IsocitrateDH','Dk IsocitrateDH'],
                ['Lt 2-oxoglutarateDH','Dk 2-oxoglutarateDH'],
                ['Lt SuccinateTK','Dk SuccinateTK'],
                ['Lt Fumarase','Dk Fumarase'],
                ['Lt Malate DH','Dk Malate DH']
               ]
    
    reactions = [['PYRUVDEH-RXN_Light_m','PYRUVDEH-RXN_Dark_m'],
                 ['CITSYN-RXN_Light_m','CITSYN-RXN_Dark_m'],
                 ['ACONITATEHYDR-RXN_Light_m','ACONITATEHYDR-RXN_Dark_m'],
                 ['ISOCITRATE-DEHYDROGENASE-NAD+-RXN_Light_m','ISOCITRATE-DEHYDROGENASE-NAD+-RXN_Dark_m'],
                 #include isocitrate DH in Cytosol
                 #Add PEPCARBOX-RXN_Light_c
                 ['2OXOGLUTARATEDEH-RXN_Light_m','2OXOGLUTARATEDEH-RXN_Dark_m'],
                 ['SUCCCOASYN-RXN_Light_m','SUCCCOASYN-RXN_Dark_m'],
                 ['FUMHYDR-RXN_Light_m','FUMHYDR-RXN_Dark_m'],
                 ['MALATE-DEH-RXN_Light_m','MALATE-DEH-RXN_Dark_m']
                ]

    
    M1_rxn, M2_rxn, indexes = prepareDataWithCustomIndex(reactions, rxnIndex)
    tempDataframe = pd.DataFrame({'M1':M1_rxn,'M2':M2_rxn},index = indexes)
    tempGroup = [tempDataframe,'TCA']
    all_groups.append(tempGroup)
    
    ##############
    #### OPPP ####
    ##############
    
    rxnIndex = [['Lt_p Hexose P Isomerase','Dk_p Hexose P Isomerase'],
                ['Lt_c Hexose P Isomerase','Dk_c Hexose P Isomerase'],
                ['Lt_p Transadolase','Dk_p Transadolase'],
                ['Lt_p 1 Transketolase','Dk_p 1 Transketolase'],
                ['Lt_p 2 Transketolase','Dk_p 2 Transketolase'],
                ['Lt_p Epimerase','Dk_p Epimerase'],
                ['Lt_c Epimerase','Dk_c Epimerase'],
                ['Lt_p R5P Isomerase','Dk_p R5P Isomerase'],
                ['Lt_c R5P Isomerase','Dk_c R5P Isomerase'],
                ['Lt_p G6PDH1','Dk_p G6PDH1'],
                ['Lt_c G6PDH1','Dk_c G6PDH1'],
                ['Lt_p G6PDH2','Dk_p G6PDH2'],
                ['Lt_c G6PDH2','Dk_c G6PDH2'],
                ['Lt_c GLCNATE6P-DH_c','Dk_c GLCNATE6P-DH'],
                ['Lt_p GLCNATE6P-DH_p','Dk_p GLCNATE6P-DH']
                ]
                
    reactions = [['PGLUCISOM-RXN_Light_p','PGLUCISOM-RXN_Dark_p'],
                 ['PGLUCISOM-RXN_Light_c','PGLUCISOM-RXN_Dark_c'],
                 ['TRANSALDOL-RXN_Light_p','TRANSALDOL-RXN_Dark_p'],
                 ['1TRANSKETO-RXN_Light_p','1TRANSKETO-RXN_Dark_p'],
                 ['2TRANSKETO-RXN_Light_p','2TRANSKETO-RXN_Dark_p'],
                 ['RIBULP3EPIM-RXN_Light_p','RIBULP3EPIM-RXN_Dark_p'],
                 ['RIBULP3EPIM-RXN_Light_c','RIBULP3EPIM-RXN_Dark_c'],
                 ['RIB5PISOM-RXN_Light_p','RIB5PISOM-RXN_Dark_p'],
                 ['RIB5PISOM-RXN_Light_c','RIB5PISOM-RXN_Dark_c'],
                 ['GLU6PDEHYDROG-RXN_Light_p','GLU6PDEHYDROG-RXN_Dark_p'],
                 ['GLU6PDEHYDROG-RXN_Light_c','GLU6PDEHYDROG-RXN_Dark_c'], #WHAT ARE THESE TWO STEPS?
                 ['6PGLUCONOLACT-RXN_Light_p','6PGLUCONOLACT-RXN_Dark_p'],
                 ['6PGLUCONOLACT-RXN_Light_c','6PGLUCONOLACT-RXN_Dark_c'],#WHAT ARE THESE TWO STEPS?
                 ['6PGLUCONDEHYDROG-RXN_Light_c','6PGLUCONDEHYDROG-RXN_Dark_c'],
                 ['6PGLUCONDEHYDROG-RXN_Light_p','6PGLUCONDEHYDROG-RXN_Dark_p']
                ]
    
    M1_rxn, M2_rxn, indexes = prepareDataWithCustomIndex(reactions, rxnIndex)
    tempDataframe = pd.DataFrame({'M1':M1_rxn,'M2':M2_rxn},index = indexes)
    tempGroup = [tempDataframe,'PPP']
    all_groups.append(tempGroup)
    
    #############
    #### ETC ####
    #############
    
    rxnIndex = [['Lt Complex I', 'Dk Complex I'],
                ['Lt Complex II','Dk Complex II'],
                ['Lt Complex III','Dk Complex III'],
                ['Lt Complex IV','Dk Complex IV'],
                ['Lt AOX1','Dk AOX1'],
                ['Lt AOX2','Dk AOX2']
                ]
    reactions = [['NADH-DEHYDROG-A-RXN_Light_m','NADH-DEHYDROG-A-RXN_Light_m'],
                 ['1.10.2.2-RXN_Light_m','1.10.2.2-RXN_Dark_m'],
                 ['CYTOCHROME-C-OXIDASE-RXN_Light_m','CYTOCHROME-C-OXIDASE-RXN_Dark_m'],
                 ['SUCCINATE-DEHYDROGENASE-UBIQUINONE-RXN_Light_m','SUCCINATE-DEHYDROGENASE-UBIQUINONE-RXN_Dark_m'],
                 ['RXN-6883_Light_m','RXN-6883_Dark_m'],
                 ['RXN-6884_Light_m','RXN-6884_Dark_m']
                 #Add all the RXN0-5330
                ]
    
    M1_rxn, M2_rxn, indexes = prepareDataWithCustomIndex(reactions, rxnIndex)
    tempDataframe = pd.DataFrame({'M1':M1_rxn,'M2':M2_rxn},index = indexes)
    tempGroup = [tempDataframe,'ETC']
    all_groups.append(tempGroup)
    
    ##############
    #### M1M2 ####
    ##############
    
    rxnIndex = [['GAPDH_Light','GAPDH_Dark'],['ROFL_Light','ROFL_Dark']]
    reactions = [['1.2.1.9-RXN_Light_c','1.2.1.9-RXN_Dark_c']]
    
    M1_rxn, M2_rxn, indexes = prepareDataWithCustomIndex(reactions, rxnIndex)
    tempDataframe = pd.DataFrame({'M1':M1_rxn,'M2':M2_rxn},index = indexes)
    tempGroup = [tempDataframe,'M1M2']
    all_groups.append(tempGroup)
    
    ################
    #### Others ####
    ################
    
    if reacList!=None:
        M1_rxn, M2_rxn, indexes = prepareDataForVisualization(reactions)
        tempDataframe = pd.DataFrame({'M1':M1_rxn,'M2':M2_rxn},index = indexes)
        tempGroup = [tempDataframe,'OTHERS']
        all_groups.append(tempGroup)    
    
    
    #### DISPLAYING ALL THE DATA IN CATEGORIES ####
    
    for group in range(len(all_groups)):
        print all_groups[group][1]
        print all_groups[group][0]
        print '\n'

# %% [markdown]
# ## Standard Working Constraints

# %%
constraints = ['Photon_Dark_tx',
                   'GLC_Dark_tx',
                   'GLC_Light_tx',
                   'Sucrose_Dark_tx',
                   'Sucrose_Light_tx',
                   'TAG_Dark_tx',
                   'TAG_Light_tx',
                   'Starch_Dark_tx',
                   'Starch_Light_tx',
                   'NADPH_Dehydrogenase_Dark_p',
                   'NADPH_Dehydrogenase_Light_p',
                   'NADPHoxx_Light_tx',
                    'NADPHoxx_Dark_tx',
                    'Plastoquinol_Oxidase_Dark_p',
                    'Plastoquinol_Oxidase_Light_p',
                    'NH4_Light_tx',
                    'NH4_Dark_tx']

for tx in constraints:
    reac = tx+'_M1'
    m.SetConstraint(reac,0,0)

for tx in constraints:
    reac = tx+'_M2'
    m.SetConstraint(reac,0,0)

# %%
#Setting biomasses to 0

lightdic = {'Alanine_Light_biomass':-9.7,'Arginine_Light_biomass':-1.6,'Asparagine_Light_biomass':-10.1,'Aspartate_Light_biomass':-9.5,
'Glutamate_Light_biomass':-11.4,'Glutamine_Light_biomass':-33.2,'Glycine_Light_biomass':-0.7,'Serine_Light_biomass':-7.7,
'Tyrosine_Light_biomass':-0.6,'Histidine_Light_biomass':-0.4,'Isoleucine_Light_biomass':-1.2,'Leucine_Light_biomass':-1.2,
'Lysine_Light_biomass':-1.8,'Methionine_Light_biomass':-0.7,'Phenylalanine_Light_biomass':-1.1,'Threonine_Light_biomass':-5.6,
'Tryptophan_Light_biomass':-0.9,'Valine_Light_biomass':-2.4}

darkdic = {'Alanine_Dark_biomass':-9.7,'Arginine_Dark_biomass':-1.6,'Asparagine_Dark_biomass':-10.1,'Aspartate_Dark_biomass':-9.5,
'Glutamate_Dark_biomass':-11.4,'Glutamine_Dark_biomass':-33.2,'Glycine_Dark_biomass':-0.7,'Serine_Dark_biomass':-7.7,
'Tyrosine_Dark_biomass':-0.6,'Histidine_Dark_biomass':-0.4,'Isoleucine_Dark_biomass':-1.2,'Leucine_Dark_biomass':-1.2,
'Lysine_Dark_biomass':-1.8,'Methionine_Dark_biomass':-0.7,'Phenylalanine_Dark_biomass':-1.1,'Threonine_Dark_biomass':-5.6,
'Tryptophan_Dark_biomass':-0.9,'Valine_Dark_biomass':-2.4}



exclude_list = []

for aa in lightdic.keys():
    M1 = aa+'_M1'
    exclude_list.append(M1)
    M2 = aa+'_M2'
    exclude_list.append(M2)

for aa in darkdic.keys():
    M1 = aa+'_M1'
    exclude_list.append(M1)
    M2 = aa+'_M2'
    exclude_list.append(M2)

exclude_list.append('Sucrose_Light_biomass_M1')
exclude_list.append('Sucrose_Light_biomass_M2')
exclude_list.append('Sucrose_Dark_biomass_M1')
exclude_list.append('Sucrose_Dark_biomass_M2')

list_b = m.Reactions('_biomass')

for i in list_b:
    check = notInList(i, exclude_list)
    if check:
        m.SetConstraint(i,0,0)

# %%
m.SetReacsFixedRatio({"RXN-961_Dark_p_M1":1, "RIBULOSE-BISPHOSPHATE-CARBOXYLASE-RXN_Dark_p_M1":3})
m.SetReacsFixedRatio({"RXN-961_Dark_p_M2":1, "RIBULOSE-BISPHOSPHATE-CARBOXYLASE-RXN_Dark_p_M2":3})
m.SetReacsFixedRatio({"RXN-961_Light_p_M1":1, "RIBULOSE-BISPHOSPHATE-CARBOXYLASE-RXN_Light_p_M1":3})
m.SetReacsFixedRatio({"RXN-961_Light_p_M2":1, "RIBULOSE-BISPHOSPHATE-CARBOXYLASE-RXN_Light_p_M2":3})
m.SetReacsFixedRatio({"NO3_Light_tx_M1":3, 'NO3_Dark_tx_M1':2})
m.SetReacsFixedRatio({"NO3_Light_tx_M2":3, 'NO3_Dark_tx_M2':2})

#Set ATP and NADPH rxn to be None to 0. 
ATP_constraints = ['NADPHoxc', 'NADPHoxm', 'NADPHoxp']

for reac in ATP_constraints:
    nadph_d = reac+'_Light_tx_M1'
    nadph_n = reac+'_Dark_tx_M1'
    
    m.SetReacsFixedRatio({nadph_d:1,'ATPase_Light_tx_M1':9})
    m.SetReacsFixedRatio({nadph_n:1,'ATPase_Dark_tx_M1':9})
    
for reac in ATP_constraints:
    nadph_d = reac+'_Light_tx_M2'
    nadph_n = reac+'_Dark_tx_M2'
    
    m.SetReacsFixedRatio({nadph_d:1,'ATPase_Light_tx_M2':9})
    m.SetReacsFixedRatio({nadph_n:1,'ATPase_Dark_tx_M2':9})

# %% [markdown]
# ## Problematic constraints (amino acids and sucrose)

# %%
# '''Set fixed ratio constraits for amino acids and sucrose'''
# for reac in lightdic.keys():
#     M1reac = reac+'_M1'
#     M2reac = reac+'_M2'
#     m.SetReacsFixedRatio({M1reac:1,'Sucrose_Light_biomass_M1':2.2})
#     m.SetReacsFixedRatio({M2reac:1,'Sucrose_Light_biomass_M2':2.2})

# for reac in darkdic.keys():
#     M1reac = reac+'_M1'
#     M2reac = reac+'_M2'
#     m.SetReacsFixedRatio({M1reac:1,'Sucrose_Dark_biomass_M1':2.2})
#     m.SetReacsFixedRatio({M2reac:1,'Sucrose_Dark_biomass_M2':2.2})

# %%
sucrose_light_M1 = 0.515625
sucrose_dark_M1 = sucrose_light_M1/3
sucrose_light_M2 = 0.515625
sucrose_dark_M2 = sucrose_light_M2/3
aaSucrose_ratio = 2.2

# m.DelReaction('Sucrose_Light_biomass_M1')
# m.DelReaction('Sucrose_Dark_biomass_M1')
m.SetConstraints({'Sucrose_Light_biomass_M1':(0,0)})
m.SetConstraints({'Sucrose_Dark_biomass_M1':(0,0)})
m.SetConstraints({'Sucrose_Light_biomass_M2':(-sucrose_light_M2,-sucrose_light_M2)})
m.SetConstraints({'Sucrose_Dark_biomass_M2':(-sucrose_dark_M2,-sucrose_dark_M2)})
# m.SetConstraints({'Sucrose_Light_M1M2':(0,0)})
# m.SetConstraints({'Sucrose_Dark_M1M2':(0,0)})


# #takes into consideration day/night, aa/sucrose, aa percentage ratios.
for reac in lightdic:
    aa_ratio = lightdic[reac]
    m.SetConstraints({reac+'_M1':(0,0)})
for reac in darkdic:
    aa_ratio = darkdic[reac]
    m.SetConstraints({reac+'_M1':(0,0)})
    
for reac in lightdic:
    aa_ratio = lightdic[reac]
    m.SetConstraints({reac+'_M2':((sucrose_light_M2/aaSucrose_ratio)*aa_ratio/100,
                            (sucrose_light_M2/aaSucrose_ratio)*aa_ratio/100)})
for reac in darkdic:
    aa_ratio = darkdic[reac]
    m.SetConstraints({reac+'_M2':((sucrose_dark_M2/aaSucrose_ratio)*aa_ratio/100,
                            (sucrose_dark_M2/aaSucrose_ratio)*aa_ratio/100)})

# m.SetConstraints({'Photon_Light_tx_M1':(300,300)})
# m.SetConstraints({'Photon_Light_tx_M2':(300,300)})
m.SetReacsFixedRatio({'Photon_Light_tx_M1':1,'Photon_Light_tx_M2':1})

m.SetConstraints({'ATPase_Light_tx_M1':(-7.5,-7.5)})
m.SetConstraints({'ATPase_Dark_tx_M1':(-7.5,-7.5)})
m.SetConstraints({'ATPase_Light_tx_M2':(-7.5,-7.5)})
m.SetConstraints({'ATPase_Dark_tx_M2':(-7.5,-7.5)})

# %% [markdown]
# ## Meddling with reactions

# %%
# m.SetObjDirec('Max')
# m.SetObjective('Sucrose_Light_biomass_M1')
# # m.SetObjective('Sucrose_Dark_biomass_M1')
# m.SetObjective('Sucrose_Light_biomass_M2')
# m.SetObjective('Sucrose_Dark_biomass_M2')
m.SetObjective('Photon_Light_tx_M1')
m.SetObjective('Photon_Light_tx_M2')
# m.SetObjective('Sucrose_Light_M1M2')
# m.SetObjective('Sucrose_Dark_M1M2')

m.MinFluxSolve()
# Out:
# optimal

# %%
sol = m.GetSol(IncZeroes=True)
reacList = ['Photon_Light_tx_M1','Photon_Light_tx_M2','ATPase_Light_tx_M1',
           'ATPase_Light_tx_M2', 'Sucrose_Light_biomass_M1', 'Sucrose_Light_biomass_M2', 'Sucrose_Dark_biomass_M1', 
            'Sucrose_Dark_biomass_M2','Sucrose_Light_M1M2', 'Sucrose_Dark_M1M2' 'Sucrose_Light_biomass_M1', 'Sucrose_Dark_M1M2'
           ,'ILE_Light_M1M2']

# m.PrintSol()
# m.PrintReaction('Sucrose_Light_M1M2')
# PrintSolList(m,reacList)
# PrintAminoAcids(sol,lightdic,darkdic)
# PrintIndvAminoAcids(sol,lightdic,darkdic)

reacList2 = [
    [['Sucrose_Light_biomass','Sucrose_Dark_biomass'],['GCVMULTI-RXN_Light_m','GCVMULTI-RXN_Dark_m']],
    [['1.2.1.9-RXN_Light_c','1.2.1.9-RXN_Dark_c']],
    [['Sucrose_Light_biomass','Sucrose_Dark_biomass'],['GCVMULTI-RXN_Light_m','GCVMULTI-RXN_Dark_m']],
    [['Sucrose_Light_biomass','Sucrose_Dark_biomass'],['GCVMULTI-RXN_Light_m','GCVMULTI-RXN_Dark_m']],
    [['Sucrose_Light_biomass','Sucrose_Dark_biomass'],['GCVMULTI-RXN_Light_m','GCVMULTI-RXN_Dark_m']],
    [['Sucrose_Light_biomass','Sucrose_Dark_biomass'],['GCVMULTI-RXN_Light_m','GCVMULTI-RXN_Dark_m']]
    ]
    




#PPP
#Glycolysis

visualizeDataCategories(sol,reacList2,writeData=False)
# Out:
# GLYCOLYSIS
#                                                  M1        M2
# Lt Hexokinase                              0.000000  0.000000
# Dk Hexokinase                              0.000000  0.000000
# Lt PGLC Isomerase                          0.000000  0.000000
# Dk PGLC Isomerase                          0.000000  0.000000
# 6-PHOSPHOFRUCTO-2-KINASE-RXN_Light(PFK2?)  0.000000  0.000000
# 6-PHOSPHOFRUCTO-2-KINASE-RXN_Dark_c        0.000000  0.000000
# 3.1.3.46-RXN_Light_c (pPFK2?)              0.000000  0.000000
# 3.1.3.46-RXN_Dark_c (pPFK2?)               0.000000  0.000000
# 6PFRUCTPHOS-RXN_Light_c(PFK?)              0.000000  0.000000
# 6PFRUCTPHOS-RXN_Dark_c (PFK?)              0.000000  0.000000
# Lt F16 Aldolase                           -0.418417 -0.269083
# Dk F16 Aldolase                            0.098271  0.073604
# Lt TRIOSEPISOMERIZATION-RXN                0.000000  0.269083
# Dk TRIOSEPISOMERIZATION-RXN               -0.098271 -0.073604
# GAPOXNPHOSPHN-RXN_Light_c (GAPDH?)         0.000000  0.000000
# GAPOXNPHOSPHN-RXN_Dark_c(GAPDH?)           0.564535  0.652561
# PHOSGLYPHOS-RXN_Light_c                    0.000000  0.000000
# PHOSGLYPHOS-RXN_Dark_c                    -0.564535 -0.652561
# 3PGAREARR-RXN_Light_c                      0.001406  0.280078
# 3PGAREARR-RXN_Dark_c                       0.564535  0.652561
# 2PGADEHYDRAT-RXN_Light_c                   0.001406  0.280078
# 2PGADEHYDRAT-RXN_Dark_c                    0.564535  0.652561
# PEPDEPHOS-RXN_Light_c                      0.000000  0.043984
# PEPDEPHOS-RXN_Dark_c                       0.564535  0.652561
#
#
# TCA
#                            M1        M2
# Lt PyruvateDH        0.000000  0.000000
# Dk PyruvateDH        0.580565  0.700668
# Lt Citrate Synthase  0.000000  0.000000
# Dk Citrate Synthase  0.580565  0.700668
# Lt Aconitase Light   0.000000  0.000000
# Dk Aconitase         0.580565  0.591137
# Lt IsocitrateDH      0.000000  0.000000
# Dk IsocitrateDH      0.000000  0.000000
# Lt 2-oxoglutarateDH  0.000000  0.000000
# Dk 2-oxoglutarateDH  0.580565  0.556293
# Lt SuccinateTK       0.000000  0.000000
# Dk SuccinateTK       0.580565  0.556293
# Lt Fumarase          0.000000  0.000000
# Dk Fumarase          0.580565  0.556293
# Lt Malate DH         2.154500  1.803301
# Dk Malate DH         1.161129  1.352195
#
#
# PPP
#                                M1        M2
# Lt_p Hexose P Isomerase -0.868653 -0.785793
# Dk_p Hexose P Isomerase -0.607754 -0.512731
# Lt_c Hexose P Isomerase  0.000000  0.000000
# Dk_c Hexose P Isomerase  0.098271  0.073604
# Lt_p Transadolase        0.000000  0.000000
# Dk_p Transadolase        0.319906  0.318613
# Lt_p 1 Transketolase     4.142248  3.899416
# Dk_p 1 Transketolase    -0.319906 -0.318613
# Lt_p 2 Transketolase    -4.145061 -3.904728
# Dk_p 2 Transketolase     0.319906  0.318613
# Lt_p Epimerase          -8.287309 -7.804144
# Dk_p Epimerase           0.096761  0.099460
# Lt_c Epimerase           0.000000  0.000000
# Dk_c Epimerase           0.543051  0.537765
# Lt_p R5P Isomerase       4.139436  3.898166
# Dk_p R5P Isomerase      -0.319906 -0.318613
# Lt_c R5P Isomerase       0.000000  0.000000
# Dk_c R5P Isomerase       0.000000  0.000000
# Lt_p G6PDH1              0.000000  0.000000
# Dk_p G6PDH1              0.416667  0.418073
# Lt_c G6PDH1              0.000000  0.000000
# Dk_c G6PDH1              0.543051  0.537765
# Lt_p G6PDH2              0.000000  0.000000
# Dk_p G6PDH2              0.416667  0.418073
# Lt_c G6PDH2              0.000000  0.000000
# Dk_c G6PDH2              0.543051  0.537765
# Lt_c GLCNATE6P-DH_c      0.000000  0.000000
# Dk_c DLCNATE6P-DH        0.543051  0.537765
# Lt_p GLCNATE6P-DH_p      0.000000  0.000000
# Dk_p DLCNATE6P-DH        0.416667  0.418073
#
#
# ETC
#                       M1        M2
# Lt Complex III  3.708547  3.261402
# Dk Complex III  2.902823  3.191386
# Lt Complex IV   1.854273  1.630701
# Dk Complex IV   1.451412  1.595693
# Lt Complex I    3.708547  3.261402
# Dk Complex I    3.708547  3.261402
# Lt AOX1         0.000000  0.000000
# Dk AOX1         0.000000  0.000000
# Lt AOX2         0.000000  0.000000
# Dk AOX2         0.000000  0.000000
# Lt Complex II   0.000000  0.000000
# Dk Complex II   0.580565  0.556293
#
#
# M1M2
#                    M1        M2
# GAPDH_Light  1.666667  1.555885
# GAPDH_Dark   0.000000  0.000000
#
#
# OTHERS
#                            M1        M2
# 1.2.1.9-RXN_Light_c  1.666667  1.555885
# 1.2.1.9-RXN_Dark_c   0.000000  0.000000

# %%
m.PrintSol()
# Out:
# Photon_Light_tx_M2: 124.349397275
# Photon_Light_tx_M1: 124.349397275
# RXN490-3650_Light_p_M2: 62.1746986375
# RXN490-3650_Light_p_M1: 62.1746986375
# PLASTOQUINOL--PLASTOCYANIN-REDUCTASE-RXN_Light_p_M2: 31.0873493187
# PLASTOQUINOL--PLASTOCYANIN-REDUCTASE-RXN_Light_p_M1: 31.0873493187
# 1.18.1.2-RXN_Light_p_M1: 29.5079905517
# 1.18.1.2-RXN_Light_p_M2: 27.8679981323
# PHOSGLYPHOS-RXN_Light_p_M1: 24.9576731716
# 1.2.1.13-RXN_Light_p_M1: 24.9562669216
# PHOSGLYPHOS-RXN_Light_p_M2: 23.1786532138
# 1.2.1.13-RXN_Light_p_M2: 23.1747469638
# PSII-RXN_Light_p_M2: 15.5436746594
# PSII-RXN_Light_p_M1: 15.5436746594
# Plastidial_ATP_Synthase_Light_p_M2: 13.323149708
# Plastidial_ATP_Synthase_Light_p_M1: 13.323149708
# PHOSPHORIBULOKINASE-RXN_Light_p_M1: 12.4267451359
# O2_Light_pc_M2: 12.2014306198
# O2_Light_pc_M1: 12.0203217087
# PHOSPHORIBULOKINASE-RXN_Light_p_M2: 11.7023094918
# TRIOSEPISOMERIZATION-RXN_Light_p_M1: 9.57437906313
# RIBULOSE-BISPHOSPHATE-CARBOXYLASE-RXN_Light_p_M1: 9.32005885196
# CO2_Light_pc_M1: -9.31443385196
# RIBULOSE-BISPHOSPHATE-CARBOXYLASE-RXN_Light_p_M2: 8.77673211884
# CO2_Light_pc_M2: -8.75860711884
# TRIOSEPISOMERIZATION-RXN_Light_p_M2: 8.58993709377
# RIBULP3EPIM-RXN_Light_p_M1: -8.2873092573
# O2_Light_tx_M2: -8.27460749487
# RIBULP3EPIM-RXN_Light_p_M2: -7.80414382786
# O2_Light_tx_M1: -7.77937195997
# CO2_Light_tx_M1: 7.76179383497
# ATPase_Light_tx_M2: -7.5
# ATPase_Light_tx_M1: -7.5
# ATPase_Dark_tx_M2: -7.5
# ATPase_Dark_tx_M1: -7.5
# CO2_Light_tx_M2: 7.42706843237
# Pi_H+_Light_mc_M1: -7.35735548156
# ATP_ADP_Light_mc_M1: 7.35735548156
# ATP_ADP_Dark_mc_M2: 7.10210602849
# Pi_H+_Dark_mc_M2: -7.08218415349
# ATP_ADP_Dark_mc_M1: 6.47552827002
# Pi_H+_Dark_mc_M1: -6.47552827002
# Pi_H+_Light_mc_M2: -6.06972053385
# ATP_ADP_Light_mc_M2: 5.99659553385
# F16BDEPHOS-RXN_Light_p_M1: 5.0137134073
# F16ALDOLASE-RXN_Light_p_M1: -5.0137134073
# F16BDEPHOS-RXN_Light_p_M2: 4.69052142984
# F16ALDOLASE-RXN_Light_p_M2: -4.69052142984
# 2TRANSKETO-RXN_Light_p_M1: -4.14506087865
# SEDOHEPTULOSE-BISPHOSPHATASE-RXN_Light_p_M1: 4.14224837865
# SEDOBISALDOL-RXN_Light_p_M1: 4.14224837865
# 1TRANSKETO-RXN_Light_p_M1: 4.14224837865
# RIB5PISOM-RXN_Light_p_M1: 4.13943587865
# 2TRANSKETO-RXN_Light_p_M2: -3.90472816393
# SEDOHEPTULOSE-BISPHOSPHATASE-RXN_Light_p_M2: 3.89941566393
# SEDOBISALDOL-RXN_Light_p_M2: 3.89941566393
# 1TRANSKETO-RXN_Light_p_M2: 3.89941566393
# RIB5PISOM-RXN_Light_p_M2: 3.89816566393
# MALATE-DEHYDROGENASE-NADP+-RXN_Light_p_M2: 3.77757408516
# OAA_MAL_Light_pc_M2: -3.77257408516
# MALATE-DEHYDROGENASE-NADP+-RXN_Light_p_M1: 3.71135904684
# OAA_MAL_Light_pc_M1: -3.71135904684
# NADH-DEHYDROG-A-RXN_Light_m_M1: 3.70854654684
# 1.10.2.2-RXN_Light_m_M1: 3.70854654684
# NADH-DEHYDROG-A-RXN_Light_m_M2: 3.26140221016
# 1.10.2.2-RXN_Light_m_M2: 3.26140221016
# 1.10.2.2-RXN_Dark_m_M2: 3.19138589208
# RXN-969_Light_x_M1: 3.10668628399
# RXN-961_Light_p_M1: 3.10668628399
# Glycolate_Light_xc_M1: -3.10668628399
# Glycolate_Light_pc_M1: 3.10668628399
# GPH-RXN_Light_p_M1: 3.10668628399
# GLY_Light_xc_M1: 3.10668628399
# Mitochondrial_ATP_Synthase_Light_m_M1: 2.97281099869
# ATP_ADP_Pi_Light_pc_M2: 2.97030520256
# RXN-969_Light_x_M2: 2.92557737295
# RXN-961_Light_p_M2: 2.92557737295
# Glycolate_Light_xc_M2: -2.92557737295
# Glycolate_Light_pc_M2: 2.92557737295
# GPH-RXN_Light_p_M2: 2.92557737295
# GLY_Light_xc_M2: 2.92557737295
# GLY_Light_mc_M2: -2.91276487295
# 1.10.2.2-RXN_Dark_m_M1: 2.90282301759
# O2_Dark_tx_M2: 2.84569294604
# CO2_Dark_tx_M2: -2.81463825854
# O2_Dark_tx_M1: 2.7014115088
# CO2_Dark_tx_M1: -2.7014115088
# Mitochondrial_ATP_Synthase_Light_m_M2: 2.65443015678
# NADH-DEHYDROG-A-RXN_Dark_m_M2: 2.63509308867
# CO2_Light_mc_M1: 2.38737960033
# NADH-DEHYDROG-A-RXN_Dark_m_M1: 2.32225841407
# CO2_Light_mc_M2: 2.29143451981
# O2_Light_mc_M1: -2.27093994009
# Mitochondrial_ATP_Synthase_Dark_m_M2: 2.19058357503
# MALATE-DEH-RXN_Light_m_M1: 2.15450027985
# CO2_Dark_mc_M2: 2.09630956517
# O2_Light_mc_M2: -2.04736777175
# O2_Dark_mc_M2: -2.01235961271
# CO2_Dark_mc_M1: 1.99446254037
# Mitochondrial_ATP_Synthase_Dark_m_M1: 1.96498788883
# GLUTAMINESYN-RXN_Light_m_M2: 1.89356993647
# GLN_GLU_Light_mc_M2: 1.89356993647
# O2_Dark_mc_M1: -1.86807817546
# CYTOCHROME-C-OXIDASE-RXN_Light_m_M1: 1.85427327342
# GLN_GLU_Light_pc_M2: -1.81575743647
# GLUTAMATE-SYNTHASE-FERREDOXIN-RXN_Light_p_M2: 1.81450743647
# MALATE-DEH-RXN_Light_m_M2: 1.80330102369
# 2KG_MAL_Light_pc_M2: -1.79153868647
# GLT_MAL_Light_pc_M2: 1.78653868647
# 1.2.1.9-RXN_Light_c_M1: 1.66666666667
# CYTOCHROME-C-OXIDASE-RXN_Light_m_M2: 1.63070110508
# CYTOCHROME-C-OXIDASE-RXN_Dark_m_M2: 1.59569294604
# GLUTAMINESYN-RXN_Light_m_M1: 1.5610775145
# GLN_GLU_Light_mc_M1: 1.5610775145
# GLN_GLU_Light_pc_M1: -1.5610775145
# GLUTAMATE-SYNTHASE-FERREDOXIN-RXN_Light_p_M1: 1.55826501699
# 2KG_MAL_Light_pc_M1: -1.55685876699
# GLT_MAL_Light_pc_M1: 1.55685876699
# 1.2.1.9-RXN_Light_c_M2: 1.55588541667
# GLYCINE-AMINOTRANSFERASE-RXN_Light_x_M1: 1.55545251699
# GLT_Light_xc_M1: -1.55545251699
# 2-KETOGLUTARATE_Light_xc_M1: 1.55545251699
# GLYOHMETRANS-RXN_Light_c_M1: -1.55404626699
# THF_Light_mc_M1: -1.55404626699
# METHYLENE-THF_Light_mc_M1: 1.55404626699
# GLY_Light_mc_M1: -1.55404626699
# GCVMULTI-RXN_Light_m_M1: 1.55404626699
# O2_Light_xc_M1: -1.55334314199
# CATAL-RXN_Light_x_M1: 1.55334314199
# SER_Light_xc_M1: -1.55123376699
# SERINE-GLYOXYLATE-AMINOTRANSFERASE-RXN_Light_x_M1: 1.55123376699
# OAA_Light_xc_M1: 1.55123376699
# MAL_Light_xc_M1: -1.55123376699
# MALATE-DEH-RXN_Light_x_M1: 1.55123376699
# HYDROXYPYRUVATE-REDUCTASE-RXN-(NAD)_Light_x_M1: 1.55123376699
# Glycerate_Light_xc_M1: 1.55123376699
# GLYCERATE_Light_pc_M1: -1.55123376699
# GLY3KIN-RXN_Light_p_M1: 1.55123376699
# GLYCINE-AMINOTRANSFERASE-RXN_Light_x_M2: 1.49114806147
# GLT_Light_xc_M2: -1.49114806147
# 2-KETOGLUTARATE_Light_xc_M2: 1.49114806147
# O2_Light_xc_M2: -1.46278868647
# CATAL-RXN_Light_x_M2: 1.46278868647
# GCVMULTI-RXN_Light_m_M2: 1.45810118647
# SER_Light_mc_M2: 1.45466368647
# GLYOHMETRANS-RXN_Light_m_M2: -1.45466368647
# CYTOCHROME-C-OXIDASE-RXN_Dark_m_M1: 1.4514115088
# SER_Light_xc_M2: -1.43442931147
# SERINE-GLYOXYLATE-AMINOTRANSFERASE-RXN_Light_x_M2: 1.43442931147
# OAA_Light_xc_M2: 1.43442931147
# MAL_Light_xc_M2: -1.43442931147
# MALATE-DEH-RXN_Light_x_M2: 1.43442931147
# HYDROXYPYRUVATE-REDUCTASE-RXN-(NAD)_Light_x_M2: 1.43442931147
# Glycerate_Light_xc_M2: 1.43442931147
# GLYCERATE_Light_pc_M2: -1.43442931147
# GLY3KIN-RXN_Light_p_M2: 1.43442931147
# MALATE-DEH-RXN_Dark_m_M2: 1.35219498183
# OAA_MAL_Light_mc_M1: 1.32116694652
# H+_ATPase_Light_c_M2: 1.31540625
# GAP_3PGA_Light_pc_M2: 1.27580729167
# GAP_3PGA_Light_pc_M1: 1.24684313949
# MALATE-DEH-RXN_Dark_m_M1: 1.16112920704
# OAA_MAL_Light_mc_M2: 0.969967690353
# PGLUCISOM-RXN_Light_p_M1: -0.868652528647
# GAP_Pi_Light_pc_M1: 0.838240804362
# NADPHoxp_Light_tx_M2: -0.833333333333
# NADPHoxp_Light_tx_M1: -0.833333333333
# NADPHoxp_Dark_tx_M2: -0.833333333333
# NADPHoxp_Dark_tx_M1: -0.833333333333
# NADPHoxm_Light_tx_M2: -0.833333333333
# NADPHoxm_Light_tx_M1: -0.833333333333
# NADPHoxm_Dark_tx_M2: -0.833333333333
# NADPHoxm_Dark_tx_M1: -0.833333333333
# NADPHoxc_Light_tx_M2: -0.833333333333
# NADPHoxc_Light_tx_M1: -0.833333333333
# NADPHoxc_Dark_tx_M2: -0.833333333333
# NADPHoxc_Dark_tx_M1: -0.833333333333
# OAA_ISOCITRATE_Light_mc_M2: 0.833333333333
# OAA_ISOCITRATE_Light_mc_M1: 0.833333333333
# ISOCITDEH-RXN_Light_m_M2: 0.833333333333
# ISOCITDEH-RXN_Light_m_M1: 0.833333333333
# ISOCITDEH-RXN_Light_c_M1: -0.833333333333
# ISOCITDEH-RXN_Dark_m_M2: 0.833333333333
# ISOCITDEH-RXN_Dark_m_M1: 0.833333333333
# 2KG_MAL_Light_mc_M2: 0.833333333333
# 2KG_MAL_Light_mc_M1: 0.833333333333
# GAP_Pi_Light_pc_M2: 0.818243570638
# PGLUCISOM-RXN_Light_p_M2: -0.785793265909
# Phloem_Loading_Light_c_M2: 0.74953125
# G6P_Pi_Dark_pc_M1: 0.739593308755
# ISOCITDEH-RXN_Light_c_M2: -0.723802083333
# PYRUVDEH-RXN_Dark_m_M2: 0.700667803417
# PYRUVATE_H+_Dark_mc_M2: -0.700667803417
# CITSYN-RXN_Dark_m_M2: 0.700667803417
# G6P_Pi_Dark_pc_M2: 0.684972779444
# PHOSGLYPHOS-RXN_Dark_c_M2: -0.652561416458
# PEPDEPHOS-RXN_Dark_c_M2: 0.652561416458
# MALATE-DEH-RXN_Dark_c_M2: -0.652561416458
# GAPOXNPHOSPHN-RXN_Dark_c_M2: 0.652561416458
# 3PGAREARR-RXN_Dark_c_M2: 0.652561416458
# 2PGADEHYDRAT-RXN_Dark_c_M2: 0.652561416458
# H+_ATPase_Dark_c_M2: 0.62271875
# PGLUCISOM-RXN_Dark_p_M1: -0.607753585365
# INORGPYROPHOSPHAT-RXN_Light_p_M2: 0.5985956545
# ACONITATEHYDR-RXN_Dark_m_M2: 0.591136553417
# ACONITATEDEHYDR-RXN_Dark_m_M2: 0.591136553417
# Starch_LightDark_M2: 0.5903144045
# RXN0-5184_Dark_p_M2: 0.5903144045
# PHOSPHOGLUCMUT-RXN_Light_p_M2: -0.5903144045
# PHOSPHOGLUCMUT-RXN_Dark_p_M2: 0.5903144045
# GLYCOGENSYN-RXN_Light_p_M2: 0.5903144045
# GLUC1PADENYLTRANS-RXN_Light_p_M2: 0.5903144045
# SUCCINATE-DEHYDROGENASE-UBIQUINONE-RXN_Dark_m_M1: 0.580564603519
# SUCCCOASYN-RXN_Dark_m_M1: 0.580564603519
# FUMHYDR-RXN_Dark_m_M1: 0.580564603519
# 2OXOGLUTARATEDEH-RXN_Dark_m_M1: 0.580564603519
# PYRUVDEH-RXN_Dark_m_M1: 0.580564603519
# PYRUVATE_H+_Dark_mc_M1: -0.580564603519
# CITSYN-RXN_Dark_m_M1: 0.580564603519
# ACONITATEHYDR-RXN_Dark_m_M1: 0.580564603519
# ACONITATEDEHYDR-RXN_Dark_m_M1: 0.580564603519
# OAA_MAL_Dark_mc_M1: 0.580564603519
# PHOSGLYPHOS-RXN_Dark_c_M1: -0.564535496788
# PEPDEPHOS-RXN_Dark_c_M1: 0.564535496788
# MALATE-DEH-RXN_Dark_c_M1: -0.564535496788
# GAPOXNPHOSPHN-RXN_Dark_c_M1: 0.564535496788
# 3PGAREARR-RXN_Dark_c_M1: 0.564535496788
# 2PGADEHYDRAT-RXN_Dark_c_M1: 0.564535496788
# SUCCINATE-DEHYDROGENASE-UBIQUINONE-RXN_Dark_m_M2: 0.556292803417
# SUCCCOASYN-RXN_Dark_m_M2: 0.556292803417
# FUMHYDR-RXN_Dark_m_M2: 0.556292803417
# 2OXOGLUTARATEDEH-RXN_Dark_m_M2: 0.556292803417
# INORGPYROPHOSPHAT-RXN_Light_p_M1: 0.552725140057
# Starch_LightDark_M1: 0.548506390057
# RXN0-5184_Dark_p_M1: 0.548506390057
# PHOSPHOGLUCMUT-RXN_Light_p_M1: -0.548506390057
# PHOSPHOGLUCMUT-RXN_Dark_p_M1: 0.548506390057
# GLYCOGENSYN-RXN_Light_p_M1: 0.548506390057
# GLUC1PADENYLTRANS-RXN_Light_p_M1: 0.548506390057
# X5P_Pi_Dark_pc_M1: -0.543051031574
# RIBULP3EPIM-RXN_Dark_c_M1: 0.543051031574
# GLU6PDEHYDROG-RXN_Dark_c_M1: 0.543051031574
# 6PGLUCONOLACT-RXN_Dark_c_M1: 0.543051031574
# 6PGLUCONDEHYDROG-RXN_Dark_c_M1: 0.543051031574
# X5P_Pi_Dark_pc_M2: -0.537765056625
# RIBULP3EPIM-RXN_Dark_c_M2: 0.537765056625
# GLU6PDEHYDROG-RXN_Dark_c_M2: 0.537765056625
# 6PGLUCONOLACT-RXN_Dark_c_M2: 0.537765056625
# 6PGLUCONDEHYDROG-RXN_Dark_c_M2: 0.537765056625
# Sucrose_Light_biomass_M2: -0.515625
# PGLUCISOM-RXN_Dark_p_M2: -0.512731291611
# GAP_Pi_Dark_pc_M2: 0.505353693639
# OAA_MAL_Dark_mc_M2: 0.4989397735
# ATP_ADP_Pi_Light_pc_M1: 0.471228157032
# NH3_Light_pc_M2: 0.46703125
# MALATE-DEH-RXN_Light_c_M2: 0.466875
# FERREDOXIN--NITRITE-REDUCTASE-RXN_Light_p_M2: 0.46609375
# NITRITE_Light_pc_M2: -0.46609375
# NITRATE-REDUCTASE-NADH-RXN_Light_c_M2: 0.46609375
# NH3_Light_mc_M2: -0.43546875
# CO2_Dark_pc_M2: 0.422760416667
# SUCROSE-PHOSPHATE-SYNTHASE-RXN_Light_c_M1: 0.418417277181
# SUCROSE-PHOSPHATASE-RXN_Light_c_M1: 0.418417277181
# F16ALDOLASE-RXN_Light_c_M1: -0.418417277181
# DHAP_3PGA_Light_pc_M1: 0.418417277181
# F16BDEPHOS-RXN_Light_c_M1: 0.418417277181
# GLU6PDEHYDROG-RXN_Dark_p_M2: 0.418072916667
# 6PGLUCONOLACT-RXN_Dark_p_M2: 0.418072916667
# 6PGLUCONDEHYDROG-RXN_Dark_p_M2: 0.418072916667
# O2_Dark_pc_M2: -0.416666666667
# O2_Dark_pc_M1: -0.416666666667
# GLU6PDEHYDROG-RXN_Dark_p_M1: 0.416666666667
# 6PGLUCONOLACT-RXN_Dark_p_M1: 0.416666666667
# 6PGLUCONDEHYDROG-RXN_Dark_p_M1: 0.416666666667
# CO2_Dark_pc_M1: 0.416666666667
# GAP_Pi_Dark_pc_M1: 0.367993219607
# UDPKIN-RXN_Light_c_M1: 0.320146138591
# PHOSPHOGLUCMUT-RXN_Light_c_M1: -0.320146138591
# GLUC1PURIDYLTRANS-RXN_Light_c_M1: 0.320146138591
# G6P_Pi_Light_pc_M1: 0.320146138591
# Sucrose_Light_M1M2: 0.320146138591
# RIB5PISOM-RXN_Dark_p_M1: -0.319905899414
# TRANSALDOL-RXN_Dark_p_M1: 0.319905899414
# 2TRANSKETO-RXN_Dark_p_M1: 0.319905899414
# 1TRANSKETO-RXN_Dark_p_M1: -0.319905899414
# TRANSALDOL-RXN_Dark_p_M2: 0.318612657764
# RIB5PISOM-RXN_Dark_p_M2: -0.318612657764
# 2TRANSKETO-RXN_Dark_p_M2: 0.318612657764
# 1TRANSKETO-RXN_Dark_p_M2: -0.318612657764
# 2KG_MAL_Dark_mc_M2: 0.296962404917
# 3PGAREARR-RXN_Light_c_M2: 0.280078125
# 2PGADEHYDRAT-RXN_Light_c_M2: 0.280078125
# NO3_Light_tx_M2: 0.27965625
# TRIOSEPISOMERIZATION-RXN_Light_c_M2: 0.269082722819
# SUCROSE-PHOSPHATE-SYNTHASE-RXN_Light_c_M2: 0.269082722819
# SUCROSE-PHOSPHATASE-RXN_Light_c_M2: 0.269082722819
# F16BDEPHOS-RXN_Light_c_M2: 0.269082722819
# F16ALDOLASE-RXN_Light_c_M2: -0.269082722819
# 2KG_ISOCITRATE_Dark_mc_M1: 0.252768729815
# ISOCITDEH-RXN_Dark_c_M1: -0.252768729815
# Phloem_Loading_Dark_c_M2: 0.24984375
# ISOCITDEH-RXN_Dark_c_M2: -0.242196779917
# RXN0-5224_Light_c_M2: 0.23609375
# PEPCARBOX-RXN_Light_c_M2: 0.23609375
# H+(PPi)_rev_Light_vc_M2: 0.232041361409
# INORGPYROPHOSPHAT-RXN_Light_c_M1: 0.221875
# H+(ATP)_rev_Dark_vc_M2: 0.21090625
# UDPKIN-RXN_Light_c_M2: 0.195478861409
# PHOSPHOGLUCMUT-RXN_Light_c_M2: -0.195478861409
# GLUC1PURIDYLTRANS-RXN_Light_c_M2: 0.195478861409
# G6P_Pi_Light_pc_M2: 0.195478861409
# Nitrate_LightDark_M2: -0.1864375
# NO3_Dark_tx_M2: 0.1864375
# NITRATE_Light_vc_M2: 0.1864375
# Sucrose_Dark_biomass_M2: -0.171875
# ASPAMINOTRANS-RXN_Light_c_M2: -0.168125
# OAA_ISOCITRATE_Dark_mc_M2: 0.132665529917
# TRIOSEPISOMERIZATION-RXN_Dark_p_M2: -0.124494023917
# F16ALDOLASE-RXN_Dark_p_M2: 0.124494023917
# 6PFRUCTPHOS-RXN_Dark_p_M2: 0.124494023917
# ACONITATEHYDR-RXN_Light_c_M2: 0.10953125
# ACONITATEDEHYDR-RXN_Light_c_M2: 0.10953125
# Citrate_LightDark_M2: -0.10953125
# CIT_ISOCITRATE_Dark_mc_M2: 0.10953125
# CIT_H+_rev_Dark_vc_M2: 0.10953125
# CIT_H+_Light_vc_M2: 0.10953125
# RIBULP3EPIM-RXN_Dark_p_M2: 0.0994602589028
# UDPKIN-RXN_Dark_c_M1: 0.0982711385905
# TRIOSEPISOMERIZATION-RXN_Dark_c_M1: -0.0982711385905
# Sucrose_Dark_M1M2: 0.0982711385905
# SUCROSE-SYNTHASE-RXN_Light_c_M1: -0.0982711385905
# SUCROSE-SYNTHASE-RXN_Dark_c_M1: 0.0982711385905
# PHOSPHOGLUCMUT-RXN_Dark_c_M1: -0.0982711385905
# PGLUCISOM-RXN_Dark_c_M1: 0.0982711385905
# GLUC1PURIDYLTRANS-RXN_Dark_c_M1: 0.0982711385905
# Fructose_LightDark_M1: 0.0982711385905
# FRU_H+_rev_Light_vc_M1: 0.0982711385905
# FRU_Dark_vc_M1: 0.0982711385905
# F16ALDOLASE-RXN_Dark_c_M1: 0.0982711385905
# 2.7.1.90-RXN_Dark_c_M1: 0.0982711385905
# H+(PPi)_rev_Light_vc_M1: 0.0982711385905
# RIBULP3EPIM-RXN_Dark_p_M1: 0.0967607672531
# NITRATE_H+_rev_Dark_vc_M2: 0.09321875
# Malate_LightDark_M2: 0.07921875
# MAL_H+_rev_Light_vc_M2: 0.07921875
# MAL_H+_Dark_vc_M2: 0.07921875
# Glutamine_Light_biomass_M2: -0.0778125
# UDPKIN-RXN_Dark_c_M2: 0.0736038614095
# TRIOSEPISOMERIZATION-RXN_Dark_c_M2: -0.0736038614095
# SUCROSE-SYNTHASE-RXN_Light_c_M2: -0.0736038614095
# SUCROSE-SYNTHASE-RXN_Dark_c_M2: 0.0736038614095
# PGLUCISOM-RXN_Dark_c_M2: 0.0736038614095
# GLUC1PURIDYLTRANS-RXN_Dark_c_M2: 0.0736038614095
# Fructose_LightDark_M2: 0.0736038614095
# FRU_H+_rev_Light_vc_M2: 0.0736038614095
# FRU_Dark_vc_M2: 0.0736038614095
# F16ALDOLASE-RXN_Dark_c_M2: 0.0736038614095
# 2.7.1.90-RXN_Dark_c_M2: 0.0736038614095
# PHOSPHOGLUCMUT-RXN_Dark_c_M2: -0.0736038614095
# ASP_LightDark_M2: 0.072578125
# ASPAMINOTRANS-RXN_Dark_c_M2: 0.06515625
# MALATE-DEH-RXN_Dark_p_M2: -0.0641220119584
# OAA_MAL_Dark_pc_M2: -0.0641220119584
# PHOSGLYPHOS-RXN_Dark_p_M2: -0.0622470119584
# PEPDEPHOS-RXN_Dark_p_M2: 0.0622470119584
# GAPOXNPHOSPHN-RXN_Dark_p_M2: 0.0622470119584
# 3PGAREARR-RXN_Dark_p_M2: 0.0622470119584
# 2PGADEHYDRAT-RXN_Dark_p_M2: 0.0622470119584
# PYRUVATE_Dark_pc_M2: 0.0556845119584
# PEPDEPHOS-RXN_Light_c_M2: 0.043984375
# L-ASPARTATE_Light_pc_M2: -0.03671875
# ATP_AMP_Light_mc_M2: 0.0365625
# ADENYL-KIN-RXN_Light_m_M2: 0.0365625
# TRIOSEPISOMERIZATION-RXN_Dark_p_M1: -0.032058213462
# F16ALDOLASE-RXN_Dark_p_M1: 0.032058213462
# 6PFRUCTPHOS-RXN_Dark_p_M1: 0.032058213462
# ASNSYNA-RXN_Light_c_M2: 0.0315625
# ASPARTATEKIN-RXN_Light_p_M2: 0.03046875
# ASPARTATE-SEMIALDEHYDE-DEHYDROGENASE-RXN_Light_p_M2: 0.03046875
# Glutamate_Light_biomass_M2: -0.02671875
# GLUTAMINESYN-RXN_Dark_m_M2: 0.0259375
# GLN_GLU_Dark_mc_M2: 0.0259375
# Glutamine_Dark_biomass_M2: -0.0259375
# HOMOSERKIN-RXN_Light_p_M2: 0.02484375
# HOMOSERDEHYDROG-RXN-(NADP)_Light_p_M2: 0.02484375
# Asparagine_Light_biomass_M2: -0.023671875
# Alanine_Light_biomass_M2: -0.022734375
# ALANINE-AMINOTRANSFERASE-RXN_Light_c_M2: -0.022734375
# THRESYN-RXN_Light_p_M2: 0.02265625
# Aspartate_Light_biomass_M2: -0.022265625
# PYRUVATE_Light_pc_M2: -0.02125
# OAA_Pi_Dark_mc_M2: 0.019921875
# GLUTAMATE-DEHYDROGENASE-RXN_Dark_m_M2: 0.019921875
# PRO_GLU_Dark_mc_M2: 0.019921875
# PRO_Dark_mc_M2: -0.019921875
# THR_Light_pc_M2: 0.01890625
# Serine_Light_biomass_M2: -0.018046875
# PHOSGLYPHOS-RXN_Dark_p_M1: -0.016029106731
# PEPDEPHOS-RXN_Dark_p_M1: 0.016029106731
# GAPOXNPHOSPHN-RXN_Dark_p_M1: 0.016029106731
# 3PGAREARR-RXN_Dark_p_M1: 0.016029106731
# 2PGADEHYDRAT-RXN_Dark_p_M1: 0.016029106731
# PYRUVATE_Dark_pc_M1: 0.016029106731
# OAA_MAL_Dark_pc_M1: -0.016029106731
# MALATE-DEH-RXN_Dark_p_M1: -0.016029106731
# Threonine_Light_biomass_M2: -0.013125
# GLY_LightDark_M2: 0.012578125
# 3PGAREARR-RXN_Light_p_M2: 0.010625
# 2PGADEHYDRAT-RXN_Light_p_M2: 0.010625
# Glutamate_Dark_biomass_M2: -0.00890625
# H+_ATPase_Light_c_M1: 0.0084375
# ADENYL-KIN-RXN_Light_p_M2: 0.00828125
# Asparagine_Dark_biomass_M2: -0.007890625
# ASN_LightDark_M2: 0.007890625
# Alanine_Dark_biomass_M2: -0.007578125
# ALANINE-AMINOTRANSFERASE-RXN_Dark_c_M2: -0.007578125
# Aspartate_Dark_biomass_M2: -0.007421875
# NITRITE_Light_pc_M1: -0.00703125000001
# NITRATE-REDUCTASE-NADH-RXN_Light_c_M1: 0.00703125000001
# FERREDOXIN--NITRITE-REDUCTASE-RXN_Light_p_M1: 0.00703125000001
# DIHYDROXYISOVALDEHYDRAT-RXN_Light_p_M2: 0.00703125
# ACETOLACTSYN-RXN_Light_p_M2: 0.00703125
# ACETOLACTREDUCTOISOM-RXN_Light_p_M2: 0.00703125
# NH3_Light_pc_M1: 0.00703124750754
# NH3_Light_mc_M1: -0.00703124750754
# FUMHYDR-RXN_Light_c_M2: 0.00625
# THF_Dark_mc_M2: -0.006015625
# METHYLENE-THF_Dark_mc_M2: 0.006015625
# GLY_Dark_mc_M2: -0.006015625
# GCVMULTI-RXN_Dark_m_M2: 0.006015625
# GLYOHMETRANS-RXN_Dark_c_M2: -0.006015625
# Serine_Dark_biomass_M2: -0.006015625
# H+_ATPase_Dark_c_M1: 0.00562500000001
# MALATE-DEH-RXN_Light_c_M1: 0.00562500000001
# 3PGAREARR-RXN_Light_p_M1: 0.005625
# 2PGADEHYDRAT-RXN_Light_p_M1: 0.005625
# Valine_Light_biomass_M2: -0.005625
# VAL_Light_pc_M2: 0.005625
# BRANCHED-CHAINAMINOTRANSFERVAL-RXN_Light_p_M2: -0.005625
# RXN-7737_Light_p_M2: 0.005625
# LYS_Light_pc_M2: 0.005625
# DIHYDROPICRED-RXN-(NADP)_Light_p_M2: 0.005625
# DIHYDRODIPICSYN-RXN_Light_p_M2: 0.005625
# DIAMINOPIMEPIM-RXN_Light_p_M2: 0.005625
# DIAMINOPIMDECARB-RXN_Light_p_M2: 0.005625
# SHIKIMATE-KINASE-RXN_Light_p_M2: 0.0053125
# SHIKIMATE-5-DEHYDROGENASE-RXN_Light_p_M2: 0.0053125
# PREPHENATE-TRANSAMINE-RXN_Light_p_M2: 0.0053125
# DAHPSYN-RXN_Light_p_M2: 0.0053125
# CHORISMATEMUT-RXN_Light_p_M2: 0.0053125
# CHORISMATE-SYNTHASE-RXN_Light_p_M2: 0.0053125
# 3-DEHYDROQUINATE-SYNTHASE-RXN_Light_p_M2: 0.0053125
# 3-DEHYDROQUINATE-DEHYDRATASE-RXN_Light_p_M2: 0.0053125
# 2.5.1.19-RXN_Light_p_M2: 0.0053125
# ORNCARBAMTRANSFER-RXN_Light_p_M2: 0.005
# N-ACETYLGLUTPREDUCT-RXN_Light_p_M2: 0.005
# L-CITRULLINE_Light_pc_M2: 0.005
# GLUTAMATE-N-ACETYLTRANSFERASE-RXN_Light_p_M2: 0.005
# ARGSUCCINSYN-RXN_Light_c_M2: 0.005
# ARGSUCCINLYA-RXN_Light_c_M2: 0.005
# ACETYLORNTRANSAM-RXN_Light_p_M2: 0.005
# ACETYLGLUTKIN-RXN_Light_p_M2: 0.005
# 6.3.4.16-RXN_Light_p_M2: 0.005
# ASPAMINOTRANS-RXN_Light_p_M2: 0.005
# Threonine_Dark_biomass_M2: -0.004375
# THR_LightDark_M2: 0.004375
# NO3_Light_tx_M1: 0.00421875
# Lysine_Light_biomass_M2: -0.00421875
# ADENYL-KIN-RXN_Light_p_M1: 0.00421875
# GAPOXNPHOSPHN-RXN_Light_p_M2: -0.00390625
# Arginine_Light_biomass_M2: -0.00375
# THREDEHYD-RXN_Light_p_M2: 0.00375
# ILE_Light_pc_M2: 0.00375
# DIHYDROXYMETVALDEHYDRAT-RXN_Light_p_M2: 0.00375
# BRANCHED-CHAINAMINOTRANSFERILEU-RXN_Light_p_M2: -0.00375
# ACETOOHBUTSYN-RXN_Light_p_M2: 0.00375
# ACETOOHBUTREDUCTOISOM-RXN_Light_p_M2: 0.00375
# ACETATE--COA-LIGASE-RXN_Light_p_M2: 0.00359375
# THF_Light_mc_M2: -0.0034375
# METHYLENE-THF_Light_mc_M2: 0.0034375
# PHE_Light_pc_M2: 0.0034375
# CARBOXYCYCLOHEXADIENYL-DEHYDRATASE-RXN_Light_p_M2: 0.0034375
# Nitrate_LightDark_M1: -0.0028125
# NO3_Dark_tx_M1: 0.0028125
# NITRATE_Light_vc_M1: 0.0028125
# SHIKIMATE-KINASE-RXN_Light_p_M1: 0.0028125
# SHIKIMATE-5-DEHYDROGENASE-RXN_Light_p_M1: 0.0028125
# DAHPSYN-RXN_Light_p_M1: 0.0028125
# CHORISMATE-SYNTHASE-RXN_Light_p_M1: 0.0028125
# 3-DEHYDROQUINATE-SYNTHASE-RXN_Light_p_M1: 0.0028125
# 3-DEHYDROQUINATE-DEHYDRATASE-RXN_Light_p_M1: 0.0028125
# 2.5.1.19-RXN_Light_p_M1: 0.0028125
# TRP_Light_pc_M1: 0.0028125
# RXN0-2382_Light_p_M1: 0.0028125
# RXN0-2381_Light_p_M1: 0.0028125
# PRTRANS-RXN_Light_p_M1: 0.0028125
# PRAISOM-RXN_Light_p_M1: 0.0028125
# IGPSYN-RXN_Light_p_M1: 0.0028125
# ANTHRANSYN-RXN_Light_p_M1: 0.0028125
# Leucine_Light_biomass_M2: -0.0028125
# Isoleucine_Light_biomass_M2: -0.0028125
# GLT_MAL_Dark_pc_M2: -0.0028125
# DIHYDROXYISOVALDEHYDRAT-RXN_Dark_p_M2: 0.0028125
# ACETOLACTSYN-RXN_Dark_p_M2: 0.0028125
# ACETOLACTREDUCTOISOM-RXN_Dark_p_M2: 0.0028125
# 2KG_MAL_Dark_pc_M2: 0.0028125
# SER_Light_pc_M1: -0.0028125
# PRPPSYN-RXN_Light_p_M1: 0.0028125
# Phenylalanine_Light_biomass_M2: -0.002578125
# SULFITE-REDUCTASE-FERREDOXIN-RXN_Light_p_M2: 0.0021875
# SER_Light_pc_M2: -0.0021875
# SERINE-O-ACETTRAN-RXN_Light_p_M2: 0.0021875
# HOMOCYSMETB12-RXN_Light_c_M2: 0.0021875
# HOMO-CYS_Light_pc_M2: 0.0021875
# CYSTATHIONINE-BETA-LYASE-RXN_Light_p_M2: 0.0021875
# CYSPH-RXN_Light_p_M2: 0.0021875
# ACSERLY-RXN_Light_p_M2: 0.0021875
# 1.5.1.20-RXN_Light_c_M2: 0.0021875
# SULFATE-ADENYLYLTRANS-RXN_Light_p_M2: 0.0021875
# SO4_Light_tx_M2: 0.0021875
# SO4_Light_pc_M2: -0.0021875
# GLUTATHIONE-REDUCT-NADPH-RXN_Light_p_M2: 0.0021875
# 1.8.4.9-RXN_Light_p_M2: 0.0021875
# Tryptophan_Light_biomass_M2: -0.002109375
# TRP_Light_M1M2: 0.002109375
# Valine_Dark_biomass_M2: -0.001875
# TYR_Light_pc_M2: 0.001875
# RXN-5682_Light_p_M2: 0.001875
# VAL_Dark_pc_M2: 0.001875
# BRANCHED-CHAINAMINOTRANSFERVAL-RXN_Dark_p_M2: -0.001875
# Methionine_Light_biomass_M2: -0.001640625
# Glycine_Light_biomass_M2: -0.001640625
# ASPAMINOTRANS-RXN_Light_c_M1: -0.00140625000001
# RXN0-5224_Light_c_M1: 0.00140625
# PEPCARBOX-RXN_Light_c_M1: 0.00140625
# 3PGAREARR-RXN_Light_c_M1: 0.00140625
# 2PGADEHYDRAT-RXN_Light_c_M1: 0.00140625
# NITRATE_H+_rev_Dark_vc_M1: 0.00140625
# L-ASPARTATE_Light_pc_M1: -0.00140625
# RXN-8991_Light_p_M2: 0.00140625
# 3-ISOPROPYLMALISOM-RXN_Light_p_M2: 0.00140625
# 3-ISOPROPYLMALDEHYDROG-RXN_Light_p_M2: 0.00140625
# 2-ISOPROPYLMALATESYN-RXN_Light_p_M2: 0.00140625
# RXN-7800_Light_p_M2: 0.00140625
# LEU_Light_pc_M2: 0.00140625
# BRANCHED-CHAINAMINOTRANSFERLEU-RXN_Light_p_M2: -0.00140625
# THREONINE-ALDOLASE-RXN_Light_c_M2: 0.00140625
# Lysine_Dark_biomass_M2: -0.00140625
# LYS_LightDark_M2: 0.00140625
# Tyrosine_Light_biomass_M2: -0.00140625
# RXN-8991_Light_p_M1: 0.00140625
# 3-ISOPROPYLMALISOM-RXN_Light_p_M1: 0.00140625
# 2-ISOPROPYLMALATESYN-RXN_Light_p_M1: 0.00140625
# ASPARTATEKIN-RXN_Light_p_M1: 0.00140625
# ASPARTATE-SEMIALDEHYDE-DEHYDROGENASE-RXN_Light_p_M1: 0.00140625
# DIHYDROXYISOVALDEHYDRAT-RXN_Light_p_M1: 0.00140625
# ACETOLACTSYN-RXN_Light_p_M1: 0.00140625
# ACETOLACTREDUCTOISOM-RXN_Light_p_M1: 0.00140625
# THRESYN-RXN_Light_p_M1: 0.00140625
# HOMOSERKIN-RXN_Light_p_M1: 0.00140625
# HOMOSERDEHYDROG-RXN-(NADP)_Light_p_M1: 0.00140625
# THR_Light_pc_M1: 0.00140625
# THREONINE-ALDOLASE-RXN_Light_c_M1: 0.00140625
# RXN66-3_Light_c_M1: 0.00140625
# RXN-7800_Light_p_M1: 0.00140625
# LEU_Light_pc_M1: 0.00140625
# LEU_Light_M1M2: 0.00140625
# BRANCHED-CHAINAMINOTRANSFERLEU-RXN_Light_p_M1: -0.00140625
# ACET_Light_pc_M1: -0.00140625
# ACETATE--COA-LIGASE-RXN_Light_p_M1: 0.00140625
# 3-ISOPROPYLMALDEHYDROG-RXN_Light_p_M1: 0.00140625
# GAPOXNPHOSPHN-RXN_Light_p_M1: -0.00140625
# RXN66-3_Light_c_M2: 0.00140625
# ACET_Light_pc_M2: -0.00140625
# THF_Light_pc_M2: 0.00125
# RXN-8001_Light_p_M2: 0.00125
# PRPPSYN-RXN_Light_p_M2: 0.00125
# PRIBFAICARPISOM-RXN_Light_p_M2: 0.00125
# IMPCYCLOHYDROLASE-RXN_Light_p_M2: 0.00125
# IMIDPHOSDEHYD-RXN_Light_p_M2: 0.00125
# HIS_Light_pc_M2: 0.00125
# HISTPRATPHYD-RXN_Light_p_M2: 0.00125
# HISTIDPHOS-RXN_Light_p_M2: 0.00125
# HISTCYCLOHYD-RXN_Light_p_M2: 0.00125
# HISTAMINOTRANS-RXN_Light_p_M2: 0.00125
# GLUTAMIDOTRANS-RXN_Light_p_M2: 0.00125
# GDPKIN-RXN_Light_p_M2: 0.00125
# FUM_Light_pc_M2: 0.00125
# ATPPHOSPHORIBOSYLTRANS-RXN_Light_p_M2: 0.00125
# AMPSYN-RXN_Light_p_M2: 0.00125
# AICARTRANSFORM-RXN_Light_p_M2: 0.00125
# ADENYLOSUCCINATE-SYNTHASE-RXN_Light_p_M2: 0.00125
# METHYLENETHFDEHYDROG-NADP-RXN_Light_c_M2: 0.00125
# METHENYLTHFCYCLOHYDRO-RXN_Light_c_M2: 0.00125
# 10-FORMYL-THF_Light_pc_M2: -0.00125
# Arginine_Dark_biomass_M2: -0.00125
# ARG_LightDark_M2: 0.00125
# RXN-8991_Dark_p_M2: 0.0009375
# RXN-7800_Dark_p_M2: 0.0009375
# PYRUVDEH-RXN_Dark_p_M2: 0.0009375
# LEU_Dark_pc_M2: 0.0009375
# BRANCHED-CHAINAMINOTRANSFERLEU-RXN_Dark_p_M2: -0.0009375
# 3-ISOPROPYLMALISOM-RXN_Dark_p_M2: 0.0009375
# 2-ISOPROPYLMALATESYN-RXN_Dark_p_M2: 0.0009375
# 3-ISOPROPYLMALDEHYDROG-RXN_Dark_p_M2: 0.0009375
# Leucine_Dark_biomass_M2: -0.0009375
# Isoleucine_Dark_biomass_M2: -0.0009375
# ILE_LightDark_M2: 0.0009375
# Histidine_Light_biomass_M2: -0.0009375
# Phenylalanine_Dark_biomass_M2: -0.000859375
# PHE_LightDark_M2: 0.000859375
# H+(ATP)_rev_Dark_vc_M1: 0.000703125000001
# Tryptophan_Dark_biomass_M2: -0.000703125
# TRP_LightDark_M1: 0.000703125
# TRP_Dark_M1M2: 0.000703125
# Methionine_Dark_biomass_M2: -0.000546875
# MET_LightDark_M2: 0.000546875
# Glycine_Dark_biomass_M2: -0.000546875
# Tyrosine_Dark_biomass_M2: -0.00046875
# TYR_LightDark_M2: 0.00046875
# HIS_LightDark_M2: 0.0003125
# Histidine_Dark_biomass_M2: -0.0003125
# GLUTAMINESYN-RXN_Light_p_M1: 2.49246731333e-09

# %%
m.PrintSol('Sucrose_Light_biomass_M2')
# Out:
# Sucrose_Light_biomass_M2: -0.515625

# %%
m.PrintReactions('Sucrose_Light_biomass_M2')
m.PrintReactions('Glycine_Light_biomass_M2')
# Out:
# Sucrose_Light_biomass_M2	 <-- Phloem-loading-cost_Light_c_M2 + SUCROSE_Light_c_M2
# Glycine_Light_biomass_M2	 <-- GLY_Light_c_M2 + Phloem-loading-cost_Light_c_M2

# %% [markdown]
# ## Adding/Deleting reactions (should usually be commented out)

# %%
# AA_met = ['GLY','GLN','MET','LEU','HIS','VAL','ILE',
#          'L-ALPHA-ALANINE','L-ASPARTATE','SER','TYR','LYS','PHE',
#          'ARG','TRP','GLT','ASN','THR']

# #transport AA from M1 to M2 LIGHT
# for met in AA_met:
#     m.AddReaction(met+'_Light_M1M2',{met+'_Light_c_M1':-1,met+'_Light_c_M2':1},True)

# #transport AA from M1 to M2 DARK
# for met in AA_met:
#     m.AddReaction(met+'_Dark_M1M2',{met+'_Dark_c_M1':-1,met+'_Dark_c_M2':1},True)

# m.PrintReaction('GLN_Light_M1M2')
# m.PrintReaction('GLN_Dark_M1M2')
# m.PrintReaction('Sucrose_Light_M1M2')

# %%
## # m.WriteModel('AraLightDarkCore_DbMesophyll_v1.xls', 'excel')
# m.WriteModel('AraLightDarkCore_DbMesophyll_v3.xls', 'excel')
