# %%
import scobra
from cobra import Metabolite
m = scobra.Model('AraLightDarkCore_ScrumPy.xls')

# %% [markdown]
# ### zero flux constraints (except for photon_light)

# %%
#constraint list

constraints_list = {'Photon_Light_tx':(0,None),
                   'Photon_Dark_tx':(0,0),
                   'GLC_Dark_tx':(0,0),
                   'GLC_Light_tx':(0,0),
                   'Sucrose_Dark_tx':(0,0),
                   'Sucrose_Light_tx':(0,0),
                   'TAG_Dark_tx':(0,0),
                   'TAG_Light_tx':(0,0),
                   'Starch_Dark_tx':(0,0),
                   'Starch_Light_tx':(0,0),
                   'NADPH_Dehydrogenase_Dark_p':(0,0),
                   'NADPH_Dehydrogenase_Light_p':(0,0),
                   'NADPHoxx_Light_tx':(0,0),
                    'NADPHoxx_Dark_tx':(0,0),
                    'Plastoquinol_Oxidase_Dark_p':(0,0),
                    'Plastoquinol_Oxidase_Light_p':(0,0),
                    'NH4_Light_tx':(0,0),
                    'NH4_Dark_tx':(0,0)
                   }

m.SetConstraints(constraints_list)

# %% [markdown]
# ### Setting all biomass to 0 except for sucrose and amino acids

# %%
lightdic = {'Alanine_Light_biomass':-9.7,'Arginine_Light_biomass':-1.6,'Asparagine_Light_biomass':-10.1,'Aspartate_Light_biomass':-9.5,
'Glutamate_Light_biomass':-11.4,'Glutamine_Light_biomass':-33.2,'Glycine_Light_biomass':-0.7,'Serine_Light_biomass':-7.7,
'Tyrosine_Light_biomass':-0.6,'Histidine_Light_biomass':-0.4,'Isoleucine_Light_biomass':-1.2,'Leucine_Light_biomass':-1.2,
'Lysine_Light_biomass':-1.8,'Methionine_Light_biomass':-0.7,'Phenylalanine_Light_biomass':-1.1,'Threonine_Light_biomass':-5.6,
'Tryptophan_Light_biomass':-0.9,'Valine_Light_biomass':-2.4}

darkdic = {'Alanine_Dark_biomass':-9.7,'Arginine_Dark_biomass':-1.6,'Asparagine_Dark_biomass':-10.1,'Aspartate_Dark_biomass':-9.5,
'Glutamate_Dark_biomass':-11.4,'Glutamine_Dark_biomass':-33.2,'Glycine_Dark_biomass':-0.7,'Serine_Dark_biomass':-7.7,
'Tyrosine_Dark_biomass':-0.6,'Histidine_Dark_biomass':-0.4,'Isoleucine_Dark_biomass':-1.2,'Leucine_Dark_biomass':-1.2,
'Lysine_Dark_biomass':-1.8,'Methionine_Dark_biomass':-0.7,'Phenylalanine_Dark_biomass':-1.1,'Threonine_Dark_biomass':-5.6,
'Tryptophan_Dark_biomass':-0.9,'Valine_Dark_biomass':-2.4}

def notInList(element, alist):
    for i in alist:
        if element == i:
            return False
    return True

exclude_list = []

for i in lightdic.keys():
    exclude_list.append(i)

for i in darkdic.keys():
    exclude_list.append(i)

exclude_list.append('Sucrose_Light_biomass')
exclude_list.append('Sucrose_Dark_biomass')

list_b = m.Reactions('_biomass')

for i in list_b:
    check = notInList(i, exclude_list)
    if check:
        m.SetConstraint(i,0,0)

# %% [markdown]
# ### Setting photorespiration/carboxylation and NO3 ratios

# %%
m.SetReacsFixedRatio({"RXN-961_Dark_p":1, "RIBULOSE-BISPHOSPHATE-CARBOXYLASE-RXN_Dark_p":3})
m.SetReacsFixedRatio({"RXN-961_Light_p":1, "RIBULOSE-BISPHOSPHATE-CARBOXYLASE-RXN_Light_p":3})
m.SetReacsFixedRatio({"NO3_Light_tx":3, 'NO3_Dark_tx':2})

# %% [markdown]
# ### Setting amino acid and sucrose requirements

# %%
sucrose_light = 0.515625
sucrose_dark = sucrose_light/3
aaSucrose_ratio = 2.2


#takes into consideration day/night, aa/sucrose, aa percentage ratios.

for reac in lightdic:
    aa_ratio = lightdic[reac]
    m.SetConstraints({reac:((sucrose_light/aaSucrose_ratio)*aa_ratio/100,
                            (sucrose_light/aaSucrose_ratio)*aa_ratio/100)})

for reac in darkdic:
    aa_ratio = darkdic[reac]
    m.SetConstraints({reac:((sucrose_dark/aaSucrose_ratio)*aa_ratio/100,
                            (sucrose_dark/aaSucrose_ratio)*aa_ratio/100)})

# %% [markdown]
# ### ATP and NADPH ratios

# %%
# Setting ratios for NADPH and ATPase "The ratio of ATP maintenance cost:NADPH maintenance cost was as- sumed to be 3:1 "
#  'NADPHoxx' should be 0

#Set ATP and NADPH rxn to be None to 0. 
ATP_constraints = ['NADPHoxc', 'NADPHoxm', 'NADPHoxp']

for reac in ATP_constraints:
    nadph_d = reac+'_Light_tx'
    nadph_n = reac+'_Dark_tx'
    
    m.SetReacsFixedRatio({nadph_d:1,'ATPase_Light_tx':9})
    m.SetReacsFixedRatio({nadph_n:1,'ATPase_Dark_tx':9})

# %% [markdown]
# ### Setting outflux constraints

# %%
# m.SetReacsFixedRatio({"Sucrose_Light_biomass":3, 'Sucrose_Dark_biomass':1})
m.SetConstraints({'Sucrose_Light_biomass':(-sucrose_light,-sucrose_light)})
m.SetConstraints({'Sucrose_Dark_biomass':(-sucrose_dark,-sucrose_dark)})
m.SetConstraints({'ATPase_Light_tx':(-7.5,-7.5)})
m.SetConstraints({'ATPase_Dark_tx':(-7.5,-7.5)})



#ATP maintenance should go in the direction that consumes ATP

# %% [markdown]
# ### Setting Objectives

# %%
#e.g. minimizing photon 
m.SetObjDirec('Min')
# m.SetObjective('Photon_Light_tx')
m.MinFluxSolve()
# Out:
# optimal

# %%
m.PrintSol('CO2_Light_tx')
m.PrintSol('CO2_Dark_tx')
m.PrintSol('NO3_Light_tx')
m.PrintSol('NO3_Dark_tx')
m.PrintSol('SO4_Dark_tx')
m.PrintSol('SO4_Light_tx')
m.PrintSol('Starch_LightDark')
m.PrintSol('Nitrate_LightDark')
m.PrintSol('Phloem_Loading_Dark_c')
m.PrintSol('Phloem_Loading_Light_c')
print '\n'
m.PrintSol()

#to access the numbers use m.GetSol() = gives you a dictionary with the rxn name and flux values.
# Out:
# CO2_Light_tx: 12.5537861343
# CO2_Dark_tx: -2.80355175931
# NO3_Light_tx: 0.28378125
# NO3_Dark_tx: 0.1891875
# SO4_Light_tx: 0.006015625
# Starch_LightDark: 0.680331543218
# Nitrate_LightDark: -0.1891875
# Phloem_Loading_Dark_c: 0.250625
# Phloem_Loading_Light_c: 0.74953125
#
#
# Photon_Light_tx: 196.295702438
# RXN490-3650_Light_p: 98.1478512191
# PLASTOQUINOL--PLASTOCYANIN-REDUCTASE-RX
# GCVMULTI-RXN_Light_m: 2.49864785186
# GLUTAMINESYN-RXN_Light_m: 2.49864785186
# GLN_GLU_Light_mc: 2.49864785186
# GLYOHMETRANS-RXN_Light_c: -2.48731972686
# SER_Light_xc: -2.42872597686
# SERINE-GLYOXYLATE-AMINOTRANSFERASE-RXN_Light_x: 2.42872597686
# HYDROXYPYRUVATE-REDUCTASE-RXN-(NAD)_Light_x: 2.42872597686
# Glycerate_Light_xc: 2.42872597686
# GLYCERATE_Light_pc: -2.42872597686
# GLY3KIN-RXN_Light_p: 2.42872597686
# MAL_Light_xc: -2.42872597686
# MALATE-DEH-RXN_Light_x: 2.42872597686
# OAA_Light_xc: 2.42872597686
# GLN_GLU_Light_pc: -2.42083535186
# CYTOCHROME-C-OXIDASE-RXN_Light_m: 2.30942061489
# Mitochondrial_ATP_Synthase_Dark_m: 2.19310901645
# MALATE-DEH-RXN_Light_m: 2.12019337791
# CO2_Dark_mc: 2.09083099078
# O2_Dark_mc: -2.01779655097
# OAA_MAL_Light_mc: 2.00753712791
# CYTOCHROME-C-OXIDASE-RXN_Dark_m: 1.60112988431
# 1.2.1.9-RXN_Light_c: 1.54869791667
# MALATE-DEH-RXN_Dark_m: 1.37890390745
# H+_ATPase_Light_c: 1.335140625
# GAP_3PGA_Light_pc: 1.33049479167
# PGLUCISOM-RXN_Light_p: -1.19595654322
# GAP_Pi_Light_pc: 0.905703125
# G6P_Pi_Dark_pc: 0.889779231472
# ISOCITDEH-RXN_Light_m: 0.833333333333
# NADPHoxp_Light_tx: -0.833333333333
# NADPHoxp_Dark_tx: -0.833333333333
# NADPHoxm_Light_tx: -0.833333333333
# NADPHoxm_Dark_tx: -0.833333333333
# NADPHoxc_Light_tx: -0.833333333333
# NADPHoxc_Dark_tx: -0.833333333333
# ISOCITDEH-RXN_Dark_m: 0.833333333333
# Phloem_Loading_Light_c: 0.74953125
# 2KG_ISOCITRATE_Light_mc: 0.720677083333
# ISOCITDEH-RXN_Light_c: -0.720677083333
# INORGPYROPHOSPHAT-RXN_Light_p: 0.712284668218
# OAA_MAL_Dark_mc: 0.691639453723
# PHOSGLYPHOS-RXN_Dark_c: -0.68817299847
# PEPDEPHOS-RXN_Dark_c: 0.68817299847
# GAPOXNPHOSPHN-RXN_Dark_c: 0.68817299847
# 3PGAREARR-RXN_Dark_c: 0.68817299847
# 2PGADEHYDRAT-RXN_Dark_c: 0.68817299847
# MALATE-DEH-RXN_Dark_c: -0.68817299847
# SUCROSE-PHOSPHATE-SYNTHASE-RXN_Light_c: 0.6875
# SUCROSE-PHOSPHATASE-RXN_Light_c: 0.6875
# F16BDEPHOS-RXN_Light_c: 0.6875
# F16ALDOLASE-RXN_Light_c: -0.6875
# DHAP_Pi_Light_pc: 0.6875
# PYRUVDEH-RXN_Dark_m: 0.687264453723
# PYRUVATE_H+_Dark_mc: -0.687264453723
# NITRATE_Light_vc: 0.1891875
# TRIOSEPISOMERIZATION-RXN_Dark_c: -0.187557910505
# UDPKIN-RXN_Dark_c: 0.171875
# Sucrose_Dark_biomass: -0.171875
# SUCROSE-SYNTHASE-RXN_Light_c: -0.171875
# SUCROSE-SYNTHASE-RXN_Dark_c: 0.171875
# PHOSPHOGLUCMUT-RXN_Dark_c: -0.171875
# PGLUCISOM-RXN_Dark_c: 0.171875
# GLUC1PURIDYLTRANS-RXN_Dark_c: 0.171875
# Fructose_LightDark: 0.171875
# FRU_H+_rev_Light_vc: 0.171875
# FRU_Dark_vc: 0.171875
# F16ALDOLASE-RXN_Dark_c: 0.171875
# 2.7.1.90-RXN_Dark_c: 0.171875
# INORGPYROPHOSPHAT-RXN_Light_c: 0.163359375
# ASPAMINOTRANS-RXN_Light_c: -0.131484375
# 2KG_MAL_Light_mc: 0.11265625
# OAA_CIT_Light_mc: 0.11265625
# ACONITATEHYDR-RXN_Light_m: 0.11265625
# ACONITATEDEHYDR-RXN_Light_m: 0.11265625
# MAL_CIT_Dark_mc: -0.11265625
# Citrate_LightDark: -0.11265625
# CIT_H+_rev_Dark_vc: 0.11265625
# CIT_H+_Light_vc: 0.11265625
# Malate_LightDark: 0.10828125
# MAL_H+_rev_Light_vc: 0.10828125
# MAL_H+_Dark_vc: 0.10828125
# RIBULP3EPIM-RXN_Dark_p: 0.0957680339538
# NITRATE_H+_rev_Dark_vc: 0.09459375
# Glutamine_Light_biomass: -0.0778125
# 3PGAREARR-RXN_Light_p: 0.07078125
# 2PGADEHYDRAT-RXN_Light_p: 0.07078125
# L-ASPARTATE_Light_pc: -0.055546875
# ASPARTATEKIN-RXN_Light_p: 0.042109375
# ASPARTATE-SEMIALDEHYDE-DEHYDROGENASE-RXN_Light_p: 0.042109375
# ATP_AMP_Light_mc: 0.036171875
# ADENYL-KIN-RXN_Light_m: 0.036171875
# HOMOSERKIN-RXN_Light_p: 0.033515625
# HOMOSERDEHYDROG-RXN-(NADP)_Light_p: 0.033515625
# PEPDEPHOS-RXN_Light_p: 0.03234375
# ADENYL-KIN-RXN_Light_p: 0.031953125
# ASNSYNA-RXN_Light_c: 0.028046875
# DSERDEAM-RXN_Light_c: 0.028046875
# 5.1.1.18-RXN_Light_c: 0.028046875
# Glutamate_Light_biomass: -0.02671875
# Asparagine_Light_biomass: -0.023671875
# Alanine_Light_biomass: -0.022734375
# ALANINE-AMINOTRANSFERASE-RXN_Light_c: -0.022734375
# Aspartate_Light_biomass: -0.022265625
# THR_Light_pc: 0.0203125
# THRESYN-RXN_Light_p: 0.0203125
# SHIKIMATE-KINASE-RXN_Light_p: 0.01921875
# SHIKIMATE-5-DEHYDROGENASE-RXN_Light_p: 0.01921875
# DAHPSYN-RXN_Light_p: 0.01921875
# CHORISMATE-SYNTHASE-RXN_Light_p: 0.01921875
# ARG_LightDark: 0.004375
# TYR_LightDark: 0.004375
# LYS_LightDark: 0.004375
# Valine_Dark_biomass: -0.004375
# VAL_Dark_pc: -0.004375
# Tyrosine_Dark_biomass: -0.004375
# Tryptophan_Dark_biomass: -0.004375
# Threonine_Dark_biomass: -0.004375
# TRP_LightDark: 0.004375
# THR_LightDark: 0.004375
# Serine_Dark_biomass: -0.004375
# RXN-8991_Dark_p: 0.004375
# RXN-7800_Dark_p: 0.004375
# Phenylalanine_Dark_biomass: -0.004375
# PYRUVDEH-RXN_Dark_p: 0.004375
# PHE_LightDark: 0.004375
# Methionine_Dark_biomass: -0.004375
# MET_LightDark: 0.004375
# Lysine_Dark_biomass: -0.004375
# Leucine_Dark_biomass: -0.004375
# LEU_Dark_pc: 0.004375
# Isoleucine_Dark_biomass: -0.004375
# ILE_LightDark: 0.004375
# Histidine_Dark_biomass: -0.004375
# HIS_LightDark: 0.004375
# Glycine_Dark_biomass: -0.004375
# Glutamine_Dark_biomass: -0.004375
# Glutamate_Dark_biomass: -0.004375
# GLUTAMINESYN-RXN_Dark_m: 0.004375
# GLN_GLU_Dark_mc: 0.004375
# BRANCHED-CHAINAMINOTRANSFERVAL-RXN_Dark_p: 0.004375
# BRANCHED-CHAINAMINOTRANSFERLEU-RXN_Dark_p: -0.004375
# Aspartate_Dark_biomass: -0.004375
# Asparagine_Dark_biomass: -0.004375
# Arginine_Dark_biomass: -0.004375
# Alanine_Dark_biomass: -0.004375
# ASN_LightDark: 0.004375
# ALANINE-AMINOTRANSFERASE-RXN_Dark_c: -0.004375
# 3-ISOPROPYLMALISOM-RXN_Dark_p: 0.004375
# 3-ISOPROPYLMALDEHYDROG-RXN_Dark_p: 0.004375
# 2-ISOPROPYLMALATESYN-RXN_Dark_p: 0.004375
# Lysine_Light_biomass: -0.00421875
# Arginine_Light_biomass: -0.00375
# PYRUVATE_Dark_pc: 0.00346645525242
# THREONINE-ALDOLASE-RXN_Light_c: 0.0028125
# ACET_Light_pc: -0.0028125
# RXN-8991_Light_p: 0.0028125
# RXN-7800_Light_p: 0.0028125
# Leucine_Light_biomass: -0.0028125
# LEU_Light_pc: 0.0028125
# Isoleucine_Light_biomass: -0.0028125
# BRANCHED-CHAINAMINOTRANSFERLEU-RXN_Light_p: -0.0028125
# 3-ISOPROPYLMALISOM-RXN_Light_p: 0.0028125
# 3-ISOPROPYLMALDEHYDROG-RXN_Light_p: 0.0028125
# 2-ISOPROPYLMALATESYN-RXN_Light_p: 0.0028125
# RXN66-3_Light_c: 0.0028125
# Phenylalanine_Light_biomass: -0.002578125
# Tryptophan_Light_biomass: -0.002109375
# Methionine_Light_biomass: -0.001640625
# Glycine_Light_biomass: -0.001640625
# Tyrosine_Light_biomass: -0.00140625
# Histidine_Light_biomass: -0.0009375

# %% [markdown]
# ### Duplicating model into 2 mesophylls

# %%
list_d = ['_M1','_M2']
